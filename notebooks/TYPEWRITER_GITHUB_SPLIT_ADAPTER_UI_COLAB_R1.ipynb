# %% [markdown]
# # TYPEWRITER_GITHUB_SPLIT_ADAPTER_UI_COLAB_R1
#
# TypeWriter_Rebirth full E2E Colab notebook.
#
# This notebook is for the next step after V146BQ adoption.
#
# ## Locked execution rule
#
# ```text
# execution adapter = V146BF R2E only
# runner/gate/repair = V146BQ
# new training = disabled
# forbidden adapter = V146BE / V146BH / V146BI
# BP/BM/BN/BO/BQ result ZIPs are not adapters
# ```
#
# ## Full flow
#
# ```text
# 사용자 입력
# → 장르 태그 + 문맥 태그 추출
# → pack 생성
#    ├─ genre_data
#    ├─ contextual_data
#    ├─ event_flow_rails
#    ├─ materiality_rails
#    ├─ prompt_contract
#    └─ gate_contract
# → 레일 따라서 프롬프트 생성
# → V146BF R2E 본문 생성
# → V146BQ salvage repair
# → final gate
# → 결과 저장 / ZIP 패키징
# ```
#
#
#
#
# ## AF1D runtime guard fix
#
# ```text
# - Adds global default initialization for optional result variables.
# - Packaging no longer fails when blind stress / Tower stress cells were skipped.
# - Packaging requires at least one result instead of throwing NameError.
# - Gate and model-load cells include defensive default values for AF1C variables.
# - Summary/report writes are guarded when only stress results exist.
# ```
#
# ## AF1C hardening
#
# ```text
# - Tower lore scanner added.
# - Tower short-output gate raised to 700 chars.
# - Tower forbidden surface catches red-line residue, Tower-issued request language, merchant ticket sales, castle-key bleed, and combat status-window misuse.
# - Tower salvage repair attempts lore cleanup before fallback.
# - Drive/cache-first tokenizer and base-model loading added. Download is fallback only.
# ```
#
# ## AF1B Tower lore fix
#
# ```text
# - Tower does not issue requests; it grants rewards for floor clear/climb.
# - Remove internal red-ink Tower imagery.
# - Deadline pressure is external: guild/association/city notices.
# - Tower deadline limits must include highest-floor record renewal.
# - Upper floors have more lenient deadlines.
# - In urgent combat, status UI is usually turned off.
# - Cleared floors are hard to revisit to prevent farming/stagnation.
# - Tower entry permits come from guilds/associations, not merchants.
# - Conflicting strategy records may imply hidden pieces.
# ```
#
# ## Important design
#
# `rail` is not only a ban list.
# Here, **event_flow_rails** carry genre context and incident progression:
#
# ```text
# initial pressure
# → disruption / incident
# → evidence or material anchor
# → choice cost
# → consequence
# → next scene hook
# ```
#
#
# ## AF1E fallback diversity and length-gate patch
#
# ```text
# - Keeps V146BF R2E adapter lock.
# - Keeps V146BQ runner/gate/repair.
# - Keeps AF1C Tower lore gate.
# - Keeps AF1D runtime guards.
# - Adds genre-specific long fallback templates.
# - Adds input-dependent fallback variant selection.
# - Adds sentence/phrase repetition and grammar-residue scanner.
# - Removes salvage length-extension from normal salvage path and moves length recovery to fallback.
# ```
#
#
#
# ## AF1F Drive asset installer
#
# ```text
# - Adds a canonical Drive install path for the base model/tokenizer.
# - If the base model is missing, installs Qwen/Qwen2.5-7B-Instruct into Drive.
# - Uses Drive-installed model with local_files_only=True after install.
# - Sets HF_HOME / TRANSFORMERS_CACHE / HF_HUB_CACHE to Drive cache paths.
# - Keeps V146BF R2E adapter lock and does not train.
# ```
#
#
#
# ## AF1G min-length enforcer
#
# ```text
# - Keeps V146BF R2E adapter lock.
# - Keeps V146BQ runner/gate/repair.
# - Keeps AF1C Tower lore gate.
# - Keeps AF1D runtime guards.
# - Keeps AF1E fallback diversity.
# - Keeps AF1F Drive asset installer.
# - Raises generation budget.
# - Adds ensure_min_length() after salvage and after fallback.
# - If output is too short, appends genre-correct event-flow paragraphs until the gate can pass.
# ```
#
#
#
# ## AF1H quality gate and length control
#
# ```text
# - Keeps V146BF R2E adapter lock.
# - Keeps V146BQ runner/gate/repair.
# - Keeps AF1C Tower lore gate.
# - Keeps AF1D runtime guards.
# - Keeps AF1E fallback diversity.
# - Keeps AF1F Drive asset installer.
# - Keeps AF1G min-length enforcer.
# - Adds user-editable length controls.
# - Adds pack-aware quality gate calibration.
# - Quality-only phrase issues can be repaired and rechecked instead of immediate hard reject.
# ```
#
#
#
# ## AF1I overfit diagnostic
#
# ```text
# - Keeps AF1H pipeline unchanged.
# - Adds an overfit judgment cell.
# - Separates calibration-like result pools from blind result pools.
# - Measures intervention dependency, route miss, duplicate prefix/exact text, n-gram overlap, and blind-vs-calibration drop.
# - Produces PASS / WATCH / FAIL style overfit verdicts.
# ```
#
#
#
# ## AF1J naturalization / anti-template
#
# ```text
# - Keeps AF1I diagnostic.
# - Adds model-continuation-first min-length recovery.
# - Uses deterministic extension only as final fallback, not the default path.
# - Raises normal generation attempts before deterministic fallback.
# - Adds duplicate-prefix/prefix-memory repair.
# - Adds balanced blind pool including RETURN_FANTASY and GENERAL_WEBNOVEL.
# - Tracks naturalization metrics separately from deterministic min-length extension.
# ```
#
#
#
# ## R3 cell order fix
#
# ```text
# This notebook is rebuilt into a top-to-bottom runnable order.
# 13A/13C/13D are no longer before Runtime config.
# 13B overfit diagnostic is included before the handler.
# 0C runtime import/name guard remains near the top.
# ```
#
#
#
# ## R4 quality scanner hardening
#
# ```text
# - Adds grammar/josa checks missed by AF1K_R3.
# - Adds repeated noun/long phrase/lead phrase density checks.
# - Adds Tower-specific dungeon/castle residue checks.
# - Adds repair rules for 표시을/표시은, 공략 공략, odd phrase collisions, repeated Tower anchors.
# - Keeps AF1K_R3 cell order.
# ```
#
#
#
# ## R4_R2 pack guard fix
#
# ```text
# - Fixes KeyError: 'pack_id' in 13E quality scanner smoke test.
# - Smoke test now wraps PACK_REGISTRY spec into an executable pack dict.
# - final_gate now uses a defensive expected-pack resolver.
# ```
#
#
#
# ## R5 repair / diagnostic recalibration
#
# ```text
# - Keeps R4 quality scanner, but adds stronger repair before final REJECT.
# - Repairs mixed surface/lore/quality failures when they are known-repairable.
# - Recalibrates overfit diagnostic so model-continuation minlen is not treated like deterministic template minlen.
# - Packages handler report when available.
# ```
#
#
#
# ## R5_R2 smoke fix
#
# ```text
# - Fixes AssertionError in 13F R5 repair smoke test.
# - Root cause: the smoke sample was too short, so final_gate set too_short_final=True and repair loop correctly refused to run.
# - The smoke sample is now padded with safe Tower prose above min length before testing repair.
# - Adds explicit assertion that the smoke precondition is not too_short.
# ```
#
#
#
# ## R7 batched full validation
#
# ```text
# - Full validation row count is preserved.
# - Duplicate inputs are cached per validation phase.
# - First-pass body generation can be prefilled in GPU batches.
# - Post-handler validation uses a separate cache phase so handler effect is not hidden.
# - Runtime/cache profiler is packaged.
# ```
#
#
#
# ## R7_R3 strict cache key
#
# ```text
# - Same exact input still uses cache.
# - Cache key now includes phase + normalized input + pack_id + prompt hash + runtime fingerprint.
# - Prevents stale cache reuse when prompt/pack/model/generation settings change.
# ```
#
#
#
# ## R7_R4 strict cache warning fix
#
# ```text
# - Same as R7_R3 strict cache key.
# - Adds missing import json in generation cell.
# - Static warning count is now zero.
# ```
#
#
#
# ## R8 shared raw / continuation cache
#
# ```text
# - Keeps strict final-result cache.
# - Adds raw generation cache shared across pre/post handler phases.
# - Adds model continuation cache keyed by current-text hash.
# - Goal: same input reuses GPU-generated raw text, while repair/gate still reruns under current handler settings.
# ```
#
#
#
# ## R9 ultrafast duplicate result cache
#
# ```text
# - Treats same input as cached validation data.
# - Reuses final result across pre/post handler phases by default.
# - Keeps raw/continuation caches from R8.
# - Adds aggressive runtime budget for A100: larger batch, one model continuation round, deterministic tail fill.
# ```
#
#
#
# ## R10 guaranteed dedup balanced-fast
#
# ```text
# - Fixes RUN guard indentation bugs in 13A/13D.
# - Guarantees same-input duplicate rows are cloned without rerunning e2e.
# - Keeps row count while executing unique cases only.
# - Restores balanced continuation settings to recover quality after R9 deterministic-minlen failure.
# ```
#
#
#
# ## R10_R2 warning fix
#
# ```text
# - Same as R10.
# - Adds missing import json in gate/R10 helper cell.
# - Static warning count is now zero.
# ```
#
#
#
# ## R11 today-finish hardened
#
# ```text
# - Built for today's finish, not another open-ended tuning loop.
# - Runs the balanced blind path by default.
# - Uses a global duplicate cache across cells so repeated inputs are cloned, not generated.
# - Fail-soft runner keeps packaging alive even if one row errors.
# - Packaging includes R11 finish report.
# ```
#
#
#
# ## R12 today-finish acceptance
#
# ```text
# - Adds post-handler diagnostic refresh.
# - Adds final acceptance gate before packaging.
# - Final summary includes explicit ADOPT / WATCH / REJECT_NEXT_PATCH decision.
# - Keeps R11 global dedup and fail-soft finish behavior.
# ```
#
#
#
# ## R13 router / return-focus final
#
# ```text
# - Fixes regression false-positive routing from plain "다시".
# - Adds router smoke tests for the known mystery-vs-return collision.
# - Adds RETURN_FANTASY first-beat focus repair to reduce fallback/minlen weirdness.
# - Keeps R12 today-finish acceptance and R11 global dedup.
# ```
#
#
#
# ## R14 rotating blind holdout
#
# ```text
# - Keeps fixed regression tests for stability.
# - Adds a rotating blind holdout generated from shuffled genre fragments.
# - Logs the seed so each run is reproducible, but not always the same.
# - Acceptance/report packaging includes rotating-blind results.
# ```
#
#
#
# ## R14_R2 warning fix
#
# ```text
# - Same as R14 rotating blind holdout.
# - Splits combined imports for static checker.
# - Static warning count is now zero.
# ```
#
#
#
# ## R15 dynamic pack regeneration front-half
#
# ```text
# - Existing PACK_REGISTRY remains the base skeleton.
# - Each input now gets a generated pack instance with input-specific material/event rails.
# - Pack QA runs before backend generation.
# - Prompt includes generated pack overlay and QA summary.
# - R14 rotating blind and R12 acceptance are preserved.
# ```
#
#
#
# ## R16 max diversity front stress
#
# ```text
# - Adds a large no-duplicate diversity suite.
# - Covers pack families, overlays, ambiguity traps, tone/scene formats, and negative controls.
# - Fixes rotating-blind Korean particle generation.
# - Adds Tower short-output guard margin after R14_R2 found 2 too-short Tower rows.
# ```
#
#
#
# ## R17 Tower no-reentry lore lock
#
# ```text
# - Tower default: cleared floors cannot be re-entered.
# - Removes routine "lower-floor re-entry restriction" framing.
# - Re-entry is allowed only as exceptional anomaly/special exception, not normal optimization.
# - Replaces test/input materials with floor progression, ascent lock, record, permit, and route-change pressure.
# ```
#
#
#
# ## R18 genre-knowledge max inputs
#
# ```text
# - Builds a genre knowledge reservoir from all available internal data.
# - Uses PACK_REGISTRY, genre conventions, rotating/diversity banks, HTML genre pages, title corpus, and body corpus if present.
# - Human corpus is used for term/pattern extraction only, not direct copying.
# - Generates a much wider default input suite with pack coverage, ambiguity traps, negative controls, and mined terms.
# ```
#
#
#
# ## R18_R2 warning fix
#
# ```text
# - Same as R18.
# - Splits combined imports so the static checker sees zipfile imports.
# - Static warning count is now zero.
# ```
#
#
#
# ## R18_R3 import fix
#
# ```text
# - Same as R18_R2.
# - Adds explicit zipfile imports in adapter verification/extraction cells.
# - Static warning count is now zero.
# ```
#
#
#
# ## R18_R4 final import fix
#
# ```text
# - Same as R18_R3.
# - Adds explicit shutil/os imports in legacy utility cells.
# - Static warning count is now zero.
# ```
#
#
#
# ## R19 fast frontend default
#
# ```text
# - Default top-to-bottom run is short.
# - No automatic single model generation.
# - Heavy diversity/stress cells are OFF by default.
# - R18 knowledge diversity remains available as an explicit optional run.
# - Fixes R17 smoke false-positive scope.
# ```
#
#
#
# ## R19_R2 smoke fix
#
# ```text
# - Fixes stale R5 smoke assertion: repair no longer has to change text if final gate is clean.
# - Preserves fast frontend default and opt-in heavy stress.
# ```
#
#
# ## R19_R3 non-blocking smoke
#
# ```text
# - Replaces the R5 repair/recalibration smoke cell entirely.
# - Smoke no longer asserts or blocks full stress.
# - It reports before/after gate, remaining hits, repair events, and recommendation.
# - Full stress can continue even when the smoke sample no longer matches current scanner assumptions.
# ```
#
#
#
# ## R20 cost guard + source precheck
#
# ```text
# - Prevents another accidental A100 full-stress burn.
# - Source files are prechecked before R18 frontier runs.
# - If no external sources are mounted, R18 is capped/downgraded.
# - Removes Tower self-hit phrase `이미 깬 층 귀환 불가` from banned terms/materials.
# ```
#
#
#
# ## Minimal GitHub UI build
#
# ```text
# Purpose: open from GitHub in Colab, load the fixed V146BF R2E adapter from Drive, and run only an input/output Gradio UI.
# Heavy stress tests are OFF by default.
# ```
#
#
# ## GitHub Release model mode
#
# ```text
# This notebook can download the fixed V146BF R2E adapter ZIP from a GitHub Release asset.
# Do not commit the adapter ZIP as a normal git file.
# ```
#
#
# ## GitHub split-adapter mode
#
# ```text
# Colab clones https://github.com/centinal235-lang/TypeWriter,
# rejoins adapter_parts/adapter.part000... into the fixed V146BF R2E adapter ZIP,
# verifies SHA256, loads the adapter, then launches the minimal input/output Gradio UI.
# ```

# %%
#@title 0A. GitHub repo checkout for Colab

from pathlib import Path
import subprocess

REPO_URL = "https://github.com/centinal235-lang/TypeWriter.git"
REPO_DIR = Path("/content/TypeWriter")

if not REPO_DIR.exists():
    subprocess.check_call(["git", "clone", REPO_URL, str(REPO_DIR)])
else:
    print("Repo already exists:", REPO_DIR)
    try:
        subprocess.check_call(["git", "-C", str(REPO_DIR), "pull", "origin", "main"])
    except Exception as e:
        print("git pull skipped:", repr(e))

print("repo dir =", REPO_DIR)
print("top files =", sorted([p.name for p in REPO_DIR.iterdir()])[:30])

# %%
#@title 0B. Rejoin split V146BF R2E adapter parts

from pathlib import Path
import hashlib
import json
import shutil

STABLE_ADAPTER_FILENAME = "TYPEWRITER_V146BF_R2E_LOW_RAM_SMALL_RECOVERY_AF1_RESULT_20260610_203138_KST.zip"
EXPECTED_ADAPTER_SHA256 = "2fa988154c9a2a0eb93fe4850e64dc3241bc4d4bb959593444d9cb26aee65368"
EXPECTED_ADAPTER_SIZE_BYTES = 300_968_235

REPO_DIR = Path("/content/TypeWriter")
PARTS_DIR = REPO_DIR / "adapter_parts"
OUT_DIR = REPO_DIR / "artifacts"
OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_ZIP = OUT_DIR / STABLE_ADAPTER_FILENAME

def sha256_file(path, chunk_size=1024 * 1024):
    h = hashlib.sha256()
    with open(path, "rb") as f:
        while True:
            b = f.read(chunk_size)
            if not b:
                break
            h.update(b)
    return h.hexdigest()

parts = sorted(PARTS_DIR.glob("adapter.part*"))
assert parts, f"No adapter parts found in {PARTS_DIR}. Push adapter_parts/ to GitHub first."

print("parts_count =", len(parts))
print("first_part =", parts[0].name, parts[0].stat().st_size)
print("last_part =", parts[-1].name, parts[-1].stat().st_size)

needs_rebuild = True
if OUT_ZIP.exists():
    size = OUT_ZIP.stat().st_size
    digest = sha256_file(OUT_ZIP)
    if size == EXPECTED_ADAPTER_SIZE_BYTES and digest == EXPECTED_ADAPTER_SHA256:
        needs_rebuild = False
        print("Existing adapter zip already valid:", OUT_ZIP)
    else:
        print("Existing adapter zip invalid; rebuilding.")
        OUT_ZIP.unlink()

if needs_rebuild:
    with open(OUT_ZIP, "wb") as w:
        for p in parts:
            print("joining", p.name, p.stat().st_size)
            with open(p, "rb") as r:
                shutil.copyfileobj(r, w, length=1024 * 1024)

size = OUT_ZIP.stat().st_size
digest = sha256_file(OUT_ZIP)

report = {
    "out_zip": str(OUT_ZIP),
    "size": size,
    "sha256": digest,
    "parts_count": len(parts),
    "expected_size": EXPECTED_ADAPTER_SIZE_BYTES,
    "expected_sha256": EXPECTED_ADAPTER_SHA256,
}
print(json.dumps(report, ensure_ascii=False, indent=2))

assert size == EXPECTED_ADAPTER_SIZE_BYTES, f"adapter size mismatch: {size}"
assert digest == EXPECTED_ADAPTER_SHA256, "adapter sha256 mismatch"

START_ADAPTER_ZIP = OUT_ZIP
CANDIDATE_ADAPTER_PATHS = [OUT_ZIP]

print("adapter rejoin OK")
print("START_ADAPTER_ZIP =", START_ADAPTER_ZIP)

# %%
#@title 0. Runtime config
import datetime

from pathlib import Path
import os, sys, json, re, time, zipfile, hashlib, shutil, subprocess, random, textwrap, datetime
from collections import Counter, defaultdict

VERSION = "TYPEWRITER_GITHUB_SPLIT_ADAPTER_UI_COLAB_R1_R3_NONBLOCKING_SMOKE_R4_STRICT_CACHE_WARNFIX_R3_STRICT_CACHE_KEY_R3_CELL_ORDER_FIX"
KST_NOW = datetime.datetime.utcnow() + datetime.timedelta(hours=9)

BASE_MODEL_ID = "Qwen/Qwen2.5-7B-Instruct"
STABLE_ADAPTER_FILENAME = "TYPEWRITER_V146BF_R2E_LOW_RAM_SMALL_RECOVERY_AF1_RESULT_20260610_203138_KST.zip"
EXPECTED_ADAPTER_SHA256 = "2fa988154c9a2a0eb93fe4850e64dc3241bc4d4bb959593444d9cb26aee65368"
EXPECTED_ADAPTER_SIZE_BYTES = 300_968_235

# GitHub Release asset mode.
# Upload the adapter ZIP to:
# https://github.com/centinal235-lang/TypeWriter/releases/tag/v146bf-r2e
GITHUB_REPO = "centinal235-lang/TypeWriter"
ADAPTER_RELEASE_TAG = "v146bf-r2e"
ADAPTER_RELEASE_URL = f"https://github.com/{GITHUB_REPO}/releases/download/{ADAPTER_RELEASE_TAG}/{STABLE_ADAPTER_FILENAME}"


DRIVE_ROOT = Path("/content/drive/MyDrive/TypeWriter")
RESULTS_ROOT = DRIVE_ROOT / "results_v146br_full_e2e_event_rail"
LOCAL_RESULTS_ROOT = Path("/content/typewriter_v146br_full_e2e_event_rail_outputs")
LOCAL_RESULTS_ROOT.mkdir(parents=True, exist_ok=True)

CANDIDATE_ADAPTER_PATHS = [
    Path("/content/TypeWriter/artifacts") / STABLE_ADAPTER_FILENAME,
    Path("/content/artifacts") / STABLE_ADAPTER_FILENAME,
    DRIVE_ROOT / "results_v146bf_r2e_lowram" / STABLE_ADAPTER_FILENAME,
    DRIVE_ROOT / STABLE_ADAPTER_FILENAME,
    Path("/content") / STABLE_ADAPTER_FILENAME,
    Path("/mnt/data") / STABLE_ADAPTER_FILENAME,
]
START_ADAPTER_ZIP = next((p for p in CANDIDATE_ADAPTER_PATHS if p.exists()), CANDIDATE_ADAPTER_PATHS[0])

# True: 모델을 안 불러오고 파이프라인/패키징만 점검.
# False: 실제 V146BF R2E adapter로 생성.
DRY_RUN_WITH_DETERMINISTIC_TEXT = False

MAX_NEW_TOKENS = 960  #@param {type:"integer"}
TEMPERATURE = 0.78
TOP_P = 0.90
REPETITION_PENALTY = 1.10
MAX_ATTEMPTS = 3

# AF1G length enforcement.
ENABLE_MINLEN_ENFORCER = True
MINLEN_EXTENSION_MAX_ROUNDS = 4
MINLEN_TARGET_MARGIN_CHARS = 60
MINLEN_EXTEND_BEFORE_FALLBACK = True
MINLEN_EXTEND_AFTER_FALLBACK = True


# AF1H: user-editable length controls.
# Use "custom" to control each pack manually.
OUTPUT_LENGTH_PRESET = "standard"  #@param ["short", "standard", "long", "custom"]
CUSTOM_TOWER_MIN_CHARS = 700  #@param {type:"integer"}
CUSTOM_AETHER_MIN_CHARS = 600  #@param {type:"integer"}
CUSTOM_ROMANTASY_MIN_CHARS = 600  #@param {type:"integer"}
CUSTOM_MYSTERY_MIN_CHARS = 600  #@param {type:"integer"}
CUSTOM_RETURN_MIN_CHARS = 600  #@param {type:"integer"}
CUSTOM_GENERAL_MIN_CHARS = 500  #@param {type:"integer"}

LENGTH_PRESETS = {
    "short": {
        "TOWER_SYSTEM_RULE": 520,
        "AETHER_WHALERS": 460,
        "ROMANTASY_HOUSE_CONTRACT": 440,
        "CLOSED_CIRCLE_MYSTERY": 440,
        "RETURN_FANTASY": 440,
        "GENERAL_WEBNOVEL": 420,
    },
    "standard": {
        "TOWER_SYSTEM_RULE": 700,
        "AETHER_WHALERS": 600,
        "ROMANTASY_HOUSE_CONTRACT": 600,
        "CLOSED_CIRCLE_MYSTERY": 600,
        "RETURN_FANTASY": 600,
        "GENERAL_WEBNOVEL": 500,
    },
    "long": {
        "TOWER_SYSTEM_RULE": 950,
        "AETHER_WHALERS": 850,
        "ROMANTASY_HOUSE_CONTRACT": 850,
        "CLOSED_CIRCLE_MYSTERY": 850,
        "RETURN_FANTASY": 850,
        "GENERAL_WEBNOVEL": 750,
    },
}

CUSTOM_MIN_FINAL_CHARS_BY_PACK = {
    "TOWER_SYSTEM_RULE": CUSTOM_TOWER_MIN_CHARS,
    "AETHER_WHALERS": CUSTOM_AETHER_MIN_CHARS,
    "ROMANTASY_HOUSE_CONTRACT": CUSTOM_ROMANTASY_MIN_CHARS,
    "CLOSED_CIRCLE_MYSTERY": CUSTOM_MYSTERY_MIN_CHARS,
    "RETURN_FANTASY": CUSTOM_RETURN_MIN_CHARS,
    "GENERAL_WEBNOVEL": CUSTOM_GENERAL_MIN_CHARS,
}

def apply_length_preset():
    global MIN_FINAL_CHARS_BY_PACK
    if OUTPUT_LENGTH_PRESET == "custom":
        MIN_FINAL_CHARS_BY_PACK = dict(CUSTOM_MIN_FINAL_CHARS_BY_PACK)
    else:
        MIN_FINAL_CHARS_BY_PACK = dict(LENGTH_PRESETS.get(OUTPUT_LENGTH_PRESET, LENGTH_PRESETS["standard"]))
    return MIN_FINAL_CHARS_BY_PACK

MIN_FINAL_CHARS_BY_PACK = apply_length_preset()

# AF1H: quality-gate calibration.
ENABLE_QUALITY_LIGHT_REPAIR = True
QUALITY_ONLY_REPAIR_MAX_ROUNDS = 2
REPEATED_PHRASE_DEFAULT_LIMIT = 4
REPEATED_PHRASE_LIMIT_BY_PACK = {
    "TOWER_SYSTEM_RULE": {
        "보상함": 5,
        "보상": 8,
        "최고층 갱신표": 4,
        "협회 공시판": 4,
        "입장 통행증": 4,
        "이미 깬 층 귀환 불가": 4,
    },
    "AETHER_WHALERS": {
        "천해석": 6,
        "천령석": 5,
        "부력낭": 5,
    },
    "ROMANTASY_HOUSE_CONTRACT": {
        "계약서": 5,
        "봉랍": 5,
        "연회장": 5,
    },
    "CLOSED_CIRCLE_MYSTERY": {
        "찻잔": 5,
        "촛대": 5,
        "알리바이": 5,
    },
}


print("VERSION =", VERSION)
print("KST_NOW =", KST_NOW.isoformat(timespec="seconds"))
print("START_ADAPTER_ZIP =", START_ADAPTER_ZIP)
print("DRY_RUN_WITH_DETERMINISTIC_TEXT =", DRY_RUN_WITH_DETERMINISTIC_TEXT)

FALLBACK_VARIANT_COUNT_BY_PACK = {
    "TOWER_SYSTEM_RULE": 4,
    "AETHER_WHALERS": 3,
    "ROMANTASY_HOUSE_CONTRACT": 3,
    "CLOSED_CIRCLE_MYSTERY": 3,
    "RETURN_FANTASY": 3,
    "GENERAL_WEBNOVEL": 3,
}
QUALITY_GATE_ENABLE = True
MAX_REPEATED_SENTENCE_COUNT = 1
MAX_REPEATED_PHRASE_COUNT = 3


# AF1F: install/cache base model assets directly into Drive.
DRIVE_BASE_MODEL_DIR = DRIVE_ROOT / "models" / "Qwen2.5-7B-Instruct"
DRIVE_HF_HOME = DRIVE_ROOT / "hf_home"
DRIVE_HF_HUB_CACHE = DRIVE_HF_HOME / "hub"
INSTALL_BASE_MODEL_TO_DRIVE_IF_MISSING = True
FORCE_REINSTALL_BASE_MODEL_TO_DRIVE = False
BASE_MODEL_ALLOW_PATTERNS = [
    "config.json",
    "generation_config.json",
    "tokenizer.json",
    "tokenizer.model",
    "tokenizer_config.json",
    "special_tokens_map.json",
    "vocab.json",
    "merges.txt",
    "*.safetensors",
    "*.safetensors.index.json",
]
BASE_MODEL_IGNORE_PATTERNS = [
    "*.h5",
    "*.ot",
    "*.msgpack",
    "*.onnx",
    "*.tflite",
    "*.gguf",
    "*.bin",
    "flax_model*",
    "tf_model*",
    "onnx/*",
]


# AF1I: overfit diagnostic thresholds.
OVERFIT_KEEP_DROP_WARN = 0.08
OVERFIT_KEEP_DROP_FAIL = 0.15
OVERFIT_FALLBACK_WARN = 0.35
OVERFIT_FALLBACK_FAIL = 0.55
OVERFIT_MINLEN_WARN = 0.60
OVERFIT_MINLEN_FAIL = 0.85
OVERFIT_DUP_PREFIX_WARN = 0.12
OVERFIT_DUP_PREFIX_FAIL = 0.25
OVERFIT_NGRAM_OVERLAP_WARN = 0.38
OVERFIT_NGRAM_OVERLAP_FAIL = 0.52
OVERFIT_REQUIRE_BLIND_FOR_PASS = True



# AF1J: naturalization / anti-template controls.
ENABLE_MODEL_CONTINUATION_FOR_MINLEN = True
MODEL_CONTINUATION_MAX_ROUNDS = 2
MODEL_CONTINUATION_MAX_NEW_TOKENS = 260
MODEL_CONTINUATION_TEMPERATURE = 0.82
MODEL_CONTINUATION_TOP_P = 0.92

# Deterministic extension remains available, but only after model continuation fails.
ALLOW_DETERMINISTIC_MINLEN_EXTENSION = True
DETERMINISTIC_MINLEN_ONLY_AFTER_MODEL_CONTINUATION = True

# Avoid early fallback. Try natural repair first.
ENABLE_NATURAL_RETRY_BEFORE_FALLBACK = True
MINLEN_EXTEND_BEFORE_FALLBACK = True
MINLEN_EXTEND_AFTER_FALLBACK = True

# Duplicate/prefix controls.
ENABLE_DUPLICATE_PREFIX_GUARD = True
DUPLICATE_PREFIX_CHARS = 180
DUPLICATE_PREFIX_MAX_SEEN = 1
DUPLICATE_PREFIX_REPAIR_MAX_ROUNDS = 2

# Diagnostic targets for AF1J.
TARGET_FALLBACK_RATE = 0.35
TARGET_DETERMINISTIC_MINLEN_RATE = 0.60
TARGET_DUP_PREFIX_RATE = 0.12



# AF1K: integrated overfit handler controls.
OVERFIT_HANDLER_MODE = "balanced"  #@param ["conservative", "balanced", "aggressive"]
APPLY_OVERFIT_HANDLER = True  #@param {type:"boolean"}
RESET_PREFIX_MEMORY_AFTER_HANDLER = True  #@param {type:"boolean"}
TARGET_FALLBACK_RATE_HANDLER = 0.35
TARGET_MINLEN_RATE_HANDLER = 0.60
TARGET_DUP_PREFIX_RATE_HANDLER = 0.12
TARGET_NGRAM_OVERLAP_HANDLER = 0.38



# AF1K R5: repair/recalibration controls.
QUALITY_SCANNER_VERSION = "AF1K_R5_REPAIR_RECALIBRATE"
ENABLE_R5_MIXED_HIT_REPAIR = True
R5_TOTAL_REPAIR_MAX_ROUNDS = 4
R5_SURFACE_LORE_REPAIR_MAX_ROUNDS = 2
R5_REPEATED_SENTENCE_KEEP_FIRST = True
R5_TOWER_ANCHOR_DENSITY_REPAIR = True
R5_DIAGNOSTIC_MINLEN_FAILS_ON_DETERMINISTIC_ONLY = True
R5_TOTAL_MINLEN_RATE_WATCH_ONLY = True



# AF1K R7: A100/full validation acceleration controls.
R7_ENABLE_EXACT_RESULT_CACHE = True
R7_ENABLE_BATCH_INITIAL_PREFILL = True
R7_BATCH_SIZE = 8
R7_BATCH_PADDING_SIDE = "left"
R7_PREFILL_UNIQUE_ONLY = True
R7_CACHE_PHASE = "pre_handler"
R7_RESET_CACHE_ON_HANDLER = True
R7_TRACK_RUNTIME = True
R7_USE_TORCH_INFERENCE_MODE = True
R7_ENABLE_TF32 = True
R7_MAX_PREFILL_CASES_PER_CALL = 256



# AF1K R7_R3 strict cache-key controls.
R7_STRICT_CACHE_KEY = True
R7_CACHE_INCLUDE_PROMPT_HASH = True
R7_CACHE_INCLUDE_RUNTIME_FINGERPRINT = True
R7_CACHE_NORMALIZE_INPUT = True



# AF1K R8: shared raw/continuation cache for speed.
R8_ENABLE_SHARED_RAW_GENERATION_CACHE = True
R8_ENABLE_CONTINUATION_CACHE = True
R8_RAW_CACHE_IGNORE_REPAIR_PHASE = True
R8_CONTINUATION_CACHE_IGNORE_REASON = True
R8_REPORT_CACHE_KEYS = False



# AF1K R9: ultrafast full validation controls.
R9_ULTRAFAST_MODE = True
R9_ENABLE_SHARED_FINAL_RESULT_CACHE = True
R9_FINAL_CACHE_IGNORE_PHASE = True
R9_FINAL_CACHE_IGNORE_HANDLER_SETTINGS = True
R9_FINAL_CACHE_INCLUDE_PROMPT_HASH = True
R9_COLLAPSE_DUPLICATE_INPUTS_AS_VALIDATION_DATA = True
R9_REPORT_DUPLICATE_CACHE = True

# A100-oriented aggressive defaults. These keep row count, but reduce repeat GPU calls.
if R9_ULTRAFAST_MODE:
    R7_BATCH_SIZE = 16
    MAX_ATTEMPTS = 2
    MODEL_CONTINUATION_MAX_ROUNDS = 1
    MODEL_CONTINUATION_MAX_NEW_TOKENS = 200
    MINLEN_EXTENSION_MAX_ROUNDS = 2
    MINLEN_TARGET_MARGIN_CHARS = 0
    R7_CONTINUATION_CONTEXT_CHARS = 700



# AF1K R10: guaranteed duplicate runner + balanced-fast quality restore.
R10_GUARANTEED_DEDUP_RUNNER = True
R10_DEDUP_KEY_MODE = "normalized_input_pack_prompt"
R10_CLONE_DUPLICATE_ROWS = True
R10_BALANCED_FAST_MODE = True

if R10_BALANCED_FAST_MODE:
    # Keep A100 batch acceleration, but undo the harsh R9 quality cuts.
    R7_BATCH_SIZE = 16
    MAX_ATTEMPTS = 3
    MODEL_CONTINUATION_MAX_ROUNDS = 2
    MODEL_CONTINUATION_MAX_NEW_TOKENS = 260
    MINLEN_EXTENSION_MAX_ROUNDS = 3
    MINLEN_TARGET_MARGIN_CHARS = 40
    R7_CONTINUATION_CONTEXT_CHARS = 1000



# AF1K R11: today-finish hardening.
R11_TODAY_FINISH_MODE = True
R11_GLOBAL_DEDUP_ACROSS_CELLS = True
R11_FAIL_SOFT_ROW_ERRORS = True
R11_DEFAULT_RUN_BALANCED_BLIND = True
R11_DEFAULT_RUN_POST_HANDLER_BLIND = True
R11_PACKAGE_EVEN_WITH_ERRORS = True
R11_TARGET_PROFILE = "today_finish_full_fast"

if R11_TODAY_FINISH_MODE:
    # Keep speed from R10 while avoiding the R9 quality collapse.
    R7_BATCH_SIZE = 16
    MAX_ATTEMPTS = 3
    MODEL_CONTINUATION_MAX_ROUNDS = 2
    MODEL_CONTINUATION_MAX_NEW_TOKENS = 260
    MINLEN_EXTENSION_MAX_ROUNDS = 3
    MINLEN_TARGET_MARGIN_CHARS = 40
    R7_CONTINUATION_CONTEXT_CHARS = 1000



# AF1K R12: today-finish acceptance thresholds.
R12_USE_POST_HANDLER_DIAG_AS_FINAL = True
R12_ACCEPT_MAX_REJECT_RATE = 0.06
R12_ACCEPT_MAX_ERROR_ROWS = 0
R12_ACCEPT_MAX_ROUTE_MISS_RATE = 0.08
R12_ACCEPT_MAX_DETERMINISTIC_MINLEN_RATE = 0.55
R12_WATCH_MAX_DETERMINISTIC_MINLEN_RATE = 0.75
R12_ACCEPT_REQUIRE_DEDUP_HITS = True



# AF1K R13: router and return-fantasy focus correction.
R13_STRICT_REGRESSION_ROUTER = True
R13_ENABLE_ROUTER_DISAMBIGUATION = True
R13_ENABLE_RETURN_FOCUS_REPAIR = True
R13_RETURN_FOCUS_FIRST_CHARS = 520
R13_RETURN_FOCUS_MIN_ANCHORS_FIRST = 1
R13_RETURN_FOCUS_MAX_BLEED_FIRST = 3
R13_ROUTER_SMOKE_REQUIRED = True



# AF1K R14: rotating blind holdout.
R14_ENABLE_ROTATING_BLIND_HOLDOUT = True
R14_ROTATING_BLIND_CASES_N = 12
R14_ROTATING_BLIND_SEED = None  # None means new timestamp seed each run.
R14_ROTATING_BLIND_REQUIRE_PACK_COVERAGE = True
R14_ROTATING_BLIND_INCLUDE_IN_ACCEPTANCE = True



# AF1K R15: dynamic pack regeneration front-half.
R15_ENABLE_DYNAMIC_PACK_REGEN = True
R15_PACK_REGEN_MODE = "deterministic_input_instance"
R15_PACK_QA_REQUIRED = True
R15_PACK_QA_FAIL_HARD = False
R15_PACK_REGEN_MATERIAL_LIMIT = 5
R15_PACK_REGEN_EVENT_LIMIT = 2
R15_INCLUDE_PACK_REGEN_IN_PROMPT = True
R15_PACK_REGEN_SMOKE_REQUIRED = True



# AF1K R16: maximum diversity front stress.
R16_ENABLE_MAX_DIVERSITY_SUITE = True
R16_DIVERSITY_PROFILE = "frontier_48"  # options: quick_24, frontier_48, max_72
R16_DIVERSITY_SEED = None
R16_INCLUDE_AMBIGUITY_TRAPS = True
R16_REQUIRE_NO_DUPLICATE_INPUTS = True
R16_DIVERSITY_INCLUDE_IN_ACCEPTANCE = True
R16_FIX_ROTATING_JOSA = True

# R14_R2 found two Tower rows at 677/700. Add a small Tower-specific cushion.
if "MIN_FINAL_CHARS_BY_PACK" in globals():
    MIN_FINAL_CHARS_BY_PACK["TOWER_SYSTEM_RULE"] = max(MIN_FINAL_CHARS_BY_PACK.get("TOWER_SYSTEM_RULE", 700), 720)
R16_TOWER_MINLEN_TARGET_MARGIN = 70



# AF1K R17: Tower no-reentry lore lock.
R17_TOWER_NO_REENTRY_DEFAULT = True
R17_ALLOW_TOWER_REENTRY_ONLY_EXCEPTIONAL = True
R17_TOWER_REENTRY_TERMS_BANNED_IN_NORMAL = ["재입장 제한", "재방문 제한", "하층 재입장", "반복 파밍 대신", "쉬운 반복 파밍"]
R17_TOWER_EXCEPTION_TERMS = ["예외", "이례", "특수 허가", "균열", "오류", "붕괴", "비정상"]



# AF1K R18: genre-knowledge max input diversity.
R18_ENABLE_GENRE_KNOWLEDGE_RESERVOIR = True
R18_RUN_GENRE_KNOWLEDGE_MAX_INPUTS = False
R18_KNOWLEDGE_DIVERSITY_PROFILE = "quick_24"  # quick_48 / frontier_120 / max_240
R18_KNOWLEDGE_DIVERSITY_SEED = None
R18_REQUIRE_PACK_COVERAGE = True
R18_REQUIRE_NO_DUPLICATE_INPUTS = True
R18_INCLUDE_IN_ACCEPTANCE = True

# Optional source paths. If present, R18 mines genre terms/patterns from them.
R18_GENRE_KNOWLEDGE_SOURCE_PATHS = [
    "/content/HTML.zip",
    "/content/HTML_FIle.zip",
    "/content/title_corpus.csv",
    "/content/master_articles.csv",
    "/mnt/data/HTML.zip",
    "/mnt/data/HTML_FIle.zip",
    "/mnt/data/title_corpus.csv",
    "/mnt/data/master_articles.csv",
    "/content/genre_knowledge.zip",
    "/content/genre_knowledge",
    "/content/drive/MyDrive/TypeWriter/genre_knowledge",
    "/content/drive/MyDrive/TypeWriter/HTML.zip",
]
R18_SOURCE_TEXT_MAX_CHARS = 700000
R18_MAX_TERMS_PER_PACK_FROM_SOURCES = 90
R18_HUMAN_CORPUS_TERM_ONLY = True



# AF1K R19: fast frontend default.
R19_FAST_FRONTEND_DEFAULT = True
R19_DEFAULT_RUN_NO_MODEL_GENERATION = True
R19_ENABLE_HEAVY_STRESS_BY_DEFAULT = False

if R19_FAST_FRONTEND_DEFAULT:
    # Keep knowledge/diversity machinery installed, but do not run expensive generation suites by default.
    R18_RUN_GENRE_KNOWLEDGE_MAX_INPUTS = False
    R16_ENABLE_MAX_DIVERSITY_SUITE = False
    R14_ENABLE_ROTATING_BLIND_HOLDOUT = False
    R11_DEFAULT_RUN_BALANCED_BLIND = False
    R11_DEFAULT_RUN_POST_HANDLER_BLIND = False



# AF1K R20: cost guard + source precheck.
R20_COST_GUARD_ENABLED = True
R20_DEFAULT_MAX_GENERATED_CASES = 24
R20_FRONTIER_MAX_GENERATED_CASES = 60
R20_HARD_MAX_GENERATED_CASES = 72
R20_REQUIRE_EXTERNAL_SOURCES_FOR_FRONTIER = True
R20_NO_SOURCE_PROFILE_FALLBACK = "quick_24"
R20_NO_SOURCE_MAX_CASES = 24
R20_ABORT_ON_NO_SOURCE_FRONTIER = False
R20_PRINT_CASE_LIST_ONLY_FIRST = 30
R20_SOURCE_PREFLIGHT_REPORT = None

# %%
#@title GitHub minimal UI defaults: keep every stress run OFF

# This notebook is for interactive UI use, not batch validation.
RUN_SINGLE_FULL_E2E = False
RUN_R14_ROTATING_BLIND = False
RUN_R16_MAX_DIVERSITY_STRESS = False
RUN_R18_GENRE_KNOWLEDGE_MAX_INPUTS = False
RUN_AF1J_BALANCED_BLIND = False
RUN_AF1K_POST_HANDLER_BLIND = False

# Smoke cells can stay on if they are cheap/non-blocking, but no generation suite runs by default.
print("GitHub minimal UI mode: heavy generation/stress cells are OFF.")

# %%
#@title 0C. AF1K R2 runtime import/name guard

# This cell is safe to run any time.
# It prevents common notebook-order NameError cases in stress/diagnostic cells.

from collections import Counter, defaultdict
from pathlib import Path
import json, re, hashlib, random, math, os, sys, time, datetime, zipfile, shutil, subprocess, textwrap

if "blind_results" not in globals():
    blind_results = []
if "tower_focused_results" not in globals():
    tower_focused_results = []
if "af1h_quick_results" not in globals():
    af1h_quick_results = []
if "af1i_blind_results" not in globals():
    af1i_blind_results = []
if "af1j_quick_results" not in globals():
    af1j_quick_results = []
if "af1k_post_handler_blind_results" not in globals():
    af1k_post_handler_blind_results = []
if "SEEN_FINAL_PREFIXES" not in globals():
    SEEN_FINAL_PREFIXES = Counter()
if "OVERFIT_DIAGNOSTIC_REPORT" not in globals():
    OVERFIT_DIAGNOSTIC_REPORT = None
if "OVERFIT_HANDLER_REPORT" not in globals():
    OVERFIT_HANDLER_REPORT = None

print("AF1K R2 runtime guard ready.")

# %%
#@title 0B. Runtime guard defaults

# Prevents NameError when optional stress cells are skipped or cells are rerun out of order.

from pathlib import Path
import datetime, json, re, os, sys, zipfile, hashlib, shutil, subprocess, random, textwrap
from collections import Counter, defaultdict

if "VERSION" not in globals():
    VERSION = "TYPEWRITER_GITHUB_SPLIT_ADAPTER_UI_COLAB_R1_R3_NONBLOCKING_SMOKE_R4_STRICT_CACHE_WARNFIX_R3_STRICT_CACHE_KEY_R3_CELL_ORDER_FIX"
if "KST_NOW" not in globals():
    KST_NOW = datetime.datetime.utcnow() + datetime.timedelta(hours=9)
if "BASE_MODEL_ID" not in globals():
    BASE_MODEL_ID = "Qwen/Qwen2.5-7B-Instruct"
if "DRIVE_ROOT" not in globals():
    DRIVE_ROOT = Path("/content/drive/MyDrive/TypeWriter")
if "RESULTS_ROOT" not in globals():
    RESULTS_ROOT = DRIVE_ROOT / "results_v146br_full_e2e_event_rail"
if "LOCAL_RESULTS_ROOT" not in globals():
    LOCAL_RESULTS_ROOT = Path("/content/typewriter_v146br_full_e2e_event_rail_outputs")
LOCAL_RESULTS_ROOT.mkdir(parents=True, exist_ok=True)

if "DRY_RUN_WITH_DETERMINISTIC_TEXT" not in globals():
    DRY_RUN_WITH_DETERMINISTIC_TEXT = False
if "MAX_ATTEMPTS" not in globals():
    MAX_ATTEMPTS = 2
if "PACK_SCHEMA_VERSION" not in globals():
    PACK_SCHEMA_VERSION = "v146br_event_rail_pack_schema_af1"

if "USE_DRIVE_CACHE_FIRST" not in globals():
    USE_DRIVE_CACHE_FIRST = True
if "ALLOW_DOWNLOAD_FALLBACK" not in globals():
    ALLOW_DOWNLOAD_FALLBACK = True

if "DRIVE_BASE_MODEL_DIR" not in globals():
    DRIVE_BASE_MODEL_DIR = DRIVE_ROOT / "models" / "Qwen2.5-7B-Instruct"
if "DRIVE_HF_HOME" not in globals():
    DRIVE_HF_HOME = DRIVE_ROOT / "hf_home"
if "DRIVE_HF_HUB_CACHE" not in globals():
    DRIVE_HF_HUB_CACHE = DRIVE_HF_HOME / "hub"
if "INSTALL_BASE_MODEL_TO_DRIVE_IF_MISSING" not in globals():
    INSTALL_BASE_MODEL_TO_DRIVE_IF_MISSING = True
if "FORCE_REINSTALL_BASE_MODEL_TO_DRIVE" not in globals():
    FORCE_REINSTALL_BASE_MODEL_TO_DRIVE = False
if "BASE_MODEL_ALLOW_PATTERNS" not in globals():
    BASE_MODEL_ALLOW_PATTERNS = [
        "config.json",
        "generation_config.json",
        "tokenizer.json",
        "tokenizer.model",
        "tokenizer_config.json",
        "special_tokens_map.json",
        "vocab.json",
        "merges.txt",
        "*.safetensors",
        "*.safetensors.index.json",
    ]
if "BASE_MODEL_IGNORE_PATTERNS" not in globals():
    BASE_MODEL_IGNORE_PATTERNS = [
        "*.h5", "*.ot", "*.msgpack", "*.onnx", "*.tflite", "*.gguf",
        "*.bin", "flax_model*", "tf_model*", "onnx/*",
    ]

if "DRIVE_MODEL_CACHE_CANDIDATES" not in globals():
    DRIVE_MODEL_CACHE_CANDIDATES = [
        DRIVE_BASE_MODEL_DIR,
        DRIVE_ROOT / "model_cache" / "Qwen2.5-7B-Instruct",
        DRIVE_ROOT / "hf_cache" / "models--Qwen--Qwen2.5-7B-Instruct",
        Path("/content/drive/MyDrive/huggingface/hub/models--Qwen--Qwen2.5-7B-Instruct"),
        Path("/content/drive/MyDrive/Models/Qwen2.5-7B-Instruct"),
    ]

if "MIN_FINAL_CHARS_BY_PACK" not in globals():
    MIN_FINAL_CHARS_BY_PACK = {
        "TOWER_SYSTEM_RULE": 700,
        "AETHER_WHALERS": 600,
        "ROMANTASY_HOUSE_CONTRACT": 600,
        "CLOSED_CIRCLE_MYSTERY": 600,
        "RETURN_FANTASY": 600,
        "GENERAL_WEBNOVEL": 500,
    }


if "FALLBACK_VARIANT_COUNT_BY_PACK" not in globals():
    FALLBACK_VARIANT_COUNT_BY_PACK = {
        "TOWER_SYSTEM_RULE": 4,
        "AETHER_WHALERS": 3,
        "ROMANTASY_HOUSE_CONTRACT": 3,
        "CLOSED_CIRCLE_MYSTERY": 3,
        "RETURN_FANTASY": 3,
        "GENERAL_WEBNOVEL": 3,
    }
if "QUALITY_GATE_ENABLE" not in globals():
    QUALITY_GATE_ENABLE = True
if "MAX_REPEATED_SENTENCE_COUNT" not in globals():
    MAX_REPEATED_SENTENCE_COUNT = 1
if "MAX_REPEATED_PHRASE_COUNT" not in globals():
    MAX_REPEATED_PHRASE_COUNT = 3


if "ENABLE_MINLEN_ENFORCER" not in globals():
    ENABLE_MINLEN_ENFORCER = True
if "MINLEN_EXTENSION_MAX_ROUNDS" not in globals():
    MINLEN_EXTENSION_MAX_ROUNDS = 4
if "MINLEN_TARGET_MARGIN_CHARS" not in globals():
    MINLEN_TARGET_MARGIN_CHARS = 60
if "MINLEN_EXTEND_BEFORE_FALLBACK" not in globals():
    MINLEN_EXTEND_BEFORE_FALLBACK = True
if "MINLEN_EXTEND_AFTER_FALLBACK" not in globals():
    MINLEN_EXTEND_AFTER_FALLBACK = True


if "OUTPUT_LENGTH_PRESET" not in globals():
    OUTPUT_LENGTH_PRESET = "standard"
if "LENGTH_PRESETS" not in globals():
    LENGTH_PRESETS = {
        "short": {
            "TOWER_SYSTEM_RULE": 520,
            "AETHER_WHALERS": 460,
            "ROMANTASY_HOUSE_CONTRACT": 440,
            "CLOSED_CIRCLE_MYSTERY": 440,
            "RETURN_FANTASY": 440,
            "GENERAL_WEBNOVEL": 420,
        },
        "standard": {
            "TOWER_SYSTEM_RULE": 700,
            "AETHER_WHALERS": 600,
            "ROMANTASY_HOUSE_CONTRACT": 600,
            "CLOSED_CIRCLE_MYSTERY": 600,
            "RETURN_FANTASY": 600,
            "GENERAL_WEBNOVEL": 500,
        },
        "long": {
            "TOWER_SYSTEM_RULE": 950,
            "AETHER_WHALERS": 850,
            "ROMANTASY_HOUSE_CONTRACT": 850,
            "CLOSED_CIRCLE_MYSTERY": 850,
            "RETURN_FANTASY": 850,
            "GENERAL_WEBNOVEL": 750,
        },
    }
if "CUSTOM_MIN_FINAL_CHARS_BY_PACK" not in globals():
    CUSTOM_MIN_FINAL_CHARS_BY_PACK = {
        "TOWER_SYSTEM_RULE": 700,
        "AETHER_WHALERS": 600,
        "ROMANTASY_HOUSE_CONTRACT": 600,
        "CLOSED_CIRCLE_MYSTERY": 600,
        "RETURN_FANTASY": 600,
        "GENERAL_WEBNOVEL": 500,
    }
if "apply_length_preset" not in globals():
    def apply_length_preset():
        global MIN_FINAL_CHARS_BY_PACK
        if globals().get("OUTPUT_LENGTH_PRESET", "standard") == "custom":
            MIN_FINAL_CHARS_BY_PACK = dict(globals().get("CUSTOM_MIN_FINAL_CHARS_BY_PACK", {}))
        else:
            presets = globals().get("LENGTH_PRESETS", {})
            MIN_FINAL_CHARS_BY_PACK = dict(presets.get(globals().get("OUTPUT_LENGTH_PRESET", "standard"), presets.get("standard", {})))
        return MIN_FINAL_CHARS_BY_PACK
if "MIN_FINAL_CHARS_BY_PACK" not in globals() or not MIN_FINAL_CHARS_BY_PACK:
    MIN_FINAL_CHARS_BY_PACK = apply_length_preset()

if "ENABLE_QUALITY_LIGHT_REPAIR" not in globals():
    ENABLE_QUALITY_LIGHT_REPAIR = True
if "QUALITY_ONLY_REPAIR_MAX_ROUNDS" not in globals():
    QUALITY_ONLY_REPAIR_MAX_ROUNDS = 2
if "REPEATED_PHRASE_DEFAULT_LIMIT" not in globals():
    REPEATED_PHRASE_DEFAULT_LIMIT = 4
if "REPEATED_PHRASE_LIMIT_BY_PACK" not in globals():
    REPEATED_PHRASE_LIMIT_BY_PACK = {
        "TOWER_SYSTEM_RULE": {"보상함": 5, "보상": 8}
    }

if "blind_results" not in globals():
    blind_results = []
if "af1h_quick_results" not in globals():
    af1h_quick_results = []
if "af1g_minlen_results" not in globals():
    af1g_minlen_results = []
if "af1e_mixed_results" not in globals():
    af1e_mixed_results = []
if "tower_focused_results" not in globals():
    tower_focused_results = []
if "single_result" not in globals():
    single_result = None
if "ADAPTER_AUDIT" not in globals():
    ADAPTER_AUDIT = {}
if "RESOLVED_BASE_MODEL_SOURCE" not in globals():
    RESOLVED_BASE_MODEL_SOURCE = BASE_MODEL_ID

print("runtime guards ready")
print("VERSION =", VERSION)
print("blind_results initialized =", isinstance(blind_results, list))
print("tower_focused_results initialized =", isinstance(tower_focused_results, list))
print("single_result exists =", single_result is not None)

if "OVERFIT_KEEP_DROP_WARN" not in globals():
    OVERFIT_KEEP_DROP_WARN = 0.08
if "OVERFIT_KEEP_DROP_FAIL" not in globals():
    OVERFIT_KEEP_DROP_FAIL = 0.15
if "OVERFIT_FALLBACK_WARN" not in globals():
    OVERFIT_FALLBACK_WARN = 0.35
if "OVERFIT_FALLBACK_FAIL" not in globals():
    OVERFIT_FALLBACK_FAIL = 0.55
if "OVERFIT_MINLEN_WARN" not in globals():
    OVERFIT_MINLEN_WARN = 0.60
if "OVERFIT_MINLEN_FAIL" not in globals():
    OVERFIT_MINLEN_FAIL = 0.85
if "OVERFIT_DUP_PREFIX_WARN" not in globals():
    OVERFIT_DUP_PREFIX_WARN = 0.12
if "OVERFIT_DUP_PREFIX_FAIL" not in globals():
    OVERFIT_DUP_PREFIX_FAIL = 0.25
if "OVERFIT_NGRAM_OVERLAP_WARN" not in globals():
    OVERFIT_NGRAM_OVERLAP_WARN = 0.38
if "OVERFIT_NGRAM_OVERLAP_FAIL" not in globals():
    OVERFIT_NGRAM_OVERLAP_FAIL = 0.52
if "OVERFIT_REQUIRE_BLIND_FOR_PASS" not in globals():
    OVERFIT_REQUIRE_BLIND_FOR_PASS = True



if "ENABLE_MODEL_CONTINUATION_FOR_MINLEN" not in globals():
    ENABLE_MODEL_CONTINUATION_FOR_MINLEN = True
if "MODEL_CONTINUATION_MAX_ROUNDS" not in globals():
    MODEL_CONTINUATION_MAX_ROUNDS = 2
if "MODEL_CONTINUATION_MAX_NEW_TOKENS" not in globals():
    MODEL_CONTINUATION_MAX_NEW_TOKENS = 260
if "MODEL_CONTINUATION_TEMPERATURE" not in globals():
    MODEL_CONTINUATION_TEMPERATURE = 0.82
if "MODEL_CONTINUATION_TOP_P" not in globals():
    MODEL_CONTINUATION_TOP_P = 0.92
if "ALLOW_DETERMINISTIC_MINLEN_EXTENSION" not in globals():
    ALLOW_DETERMINISTIC_MINLEN_EXTENSION = True
if "DETERMINISTIC_MINLEN_ONLY_AFTER_MODEL_CONTINUATION" not in globals():
    DETERMINISTIC_MINLEN_ONLY_AFTER_MODEL_CONTINUATION = True
if "ENABLE_NATURAL_RETRY_BEFORE_FALLBACK" not in globals():
    ENABLE_NATURAL_RETRY_BEFORE_FALLBACK = True
if "ENABLE_DUPLICATE_PREFIX_GUARD" not in globals():
    ENABLE_DUPLICATE_PREFIX_GUARD = True
if "DUPLICATE_PREFIX_CHARS" not in globals():
    DUPLICATE_PREFIX_CHARS = 180
if "DUPLICATE_PREFIX_MAX_SEEN" not in globals():
    DUPLICATE_PREFIX_MAX_SEEN = 1
if "DUPLICATE_PREFIX_REPAIR_MAX_ROUNDS" not in globals():
    DUPLICATE_PREFIX_REPAIR_MAX_ROUNDS = 2
if "SEEN_FINAL_PREFIXES" not in globals():
    SEEN_FINAL_PREFIXES = Counter()

# %%
#@title 1. Install dependencies

RUN_INSTALL = True  #@param {type:"boolean"}

if RUN_INSTALL:
    pkgs = [
        "transformers>=4.42.0",
        "accelerate>=0.30.0",
        "peft>=0.11.0",
        "bitsandbytes>=0.43.1",
        "safetensors>=0.4.3",
        "pandas>=2.0.0",
        "huggingface_hub>=0.23.0",
    ]
    print("Installing packages...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "-U"] + pkgs)
else:
    print("Install skipped.")

# %%
#@title 2. Mount Drive and verify stable V146BF R2E adapter
import json
from pathlib import Path
import hashlib
import zipfile

MOUNT_DRIVE = False  #@param {type:"boolean"}

if MOUNT_DRIVE:
    try:
        from google.colab import drive
        drive.mount("/content/drive")
    except Exception as e:
        print("Drive mount skipped or unavailable:", repr(e))

START_ADAPTER_ZIP = next((p for p in CANDIDATE_ADAPTER_PATHS if p.exists()), START_ADAPTER_ZIP)

if not START_ADAPTER_ZIP.exists():
    print("Stable adapter ZIP not found in default paths. Upload it now.")
    try:
        from google.colab import files
        uploaded = files.upload()
        for name in uploaded.keys():
            if name == STABLE_ADAPTER_FILENAME:
                START_ADAPTER_ZIP = Path("/content") / name
    except Exception as e:
        print("Upload helper unavailable:", repr(e))

# GitHub Release download fallback.
# Normal git should not carry this 287MB adapter file; use Release asset or Git LFS.
if not START_ADAPTER_ZIP.exists():
    try:
        import urllib.request
        release_target = Path("/content/TypeWriter/artifacts") / STABLE_ADAPTER_FILENAME
        release_target.parent.mkdir(parents=True, exist_ok=True)
        print("Downloading stable adapter from GitHub Release:")
        print(ADAPTER_RELEASE_URL)
        urllib.request.urlretrieve(ADAPTER_RELEASE_URL, release_target)
        START_ADAPTER_ZIP = release_target
    except Exception as e:
        print("GitHub Release adapter download failed:", repr(e))

assert START_ADAPTER_ZIP.exists(), f"Missing stable adapter ZIP: {STABLE_ADAPTER_FILENAME}"

FORBIDDEN_ADAPTER_MARKERS = [
    "V146BE", "V146BH", "V146BI",
    "V146BP_PROMPT_RESIDUE_CUT_AND_FALLBACK_TRACE_AUDIT",
    "V146BM", "V146BN", "V146BO",
    "V146BQ_FALLBACK_DEPENDENCY_REDUCTION_SALVAGE_REPAIR_AF1_RESULT",
]

def sha256_file(path: Path, chunk_size=1024 * 1024):
    h = hashlib.sha256()
    with open(path, "rb") as f:
        while True:
            b = f.read(chunk_size)
            if not b:
                break
            h.update(b)
    return h.hexdigest()

def verify_adapter_zip(path: Path):
    path = Path(path)
    for marker in FORBIDDEN_ADAPTER_MARKERS:
        assert marker not in path.name, f"Forbidden adapter/result ZIP used as START_ADAPTER_ZIP: {marker}"

    size = path.stat().st_size
    digest = sha256_file(path)
    print("START_ADAPTER_ZIP =", path)
    print("size_bytes =", size)
    print("sha256 =", digest)

    if path.name == STABLE_ADAPTER_FILENAME:
        assert size == EXPECTED_ADAPTER_SIZE_BYTES, f"Stable adapter size mismatch: {size}"
        assert digest == EXPECTED_ADAPTER_SHA256, "Stable adapter SHA256 mismatch."

    with zipfile.ZipFile(path) as z:
        names = z.namelist()
        adapter_models = [n for n in names if n.endswith("adapter_model.safetensors")]
        adapter_configs = [n for n in names if n.endswith("adapter_config.json")]
        assert adapter_models, "adapter_model.safetensors not found. This is not an execution adapter."
        assert adapter_configs, "adapter_config.json not found. This is not an execution adapter."
        root_configs = [n for n in adapter_configs if "checkpoint-" not in n]
        chosen = sorted(root_configs or adapter_configs, key=len)[0]
        cfg = json.loads(z.read(chosen).decode("utf-8"))
        print("zip_entries =", len(names))
        print("chosen_config =", chosen)
        print("base_model =", cfg.get("base_model_name_or_path"))
        print("peft_type =", cfg.get("peft_type"))
        print("r =", cfg.get("r"), "lora_alpha =", cfg.get("lora_alpha"))
        print("target_modules =", cfg.get("target_modules"))

    return {"path": str(path), "size": size, "sha256": digest}

ADAPTER_AUDIT = verify_adapter_zip(START_ADAPTER_ZIP)

# %%
#@title 2B. AF1F install base model/tokenizer into Drive if missing
import json

# This cell makes Drive the canonical home for the base model/tokenizer.
# It does not train anything. It only installs/caches Qwen/Qwen2.5-7B-Instruct assets.

from pathlib import Path
import os, json, shutil
import shutil

# Defensive defaults in case this cell is run directly.
if "BASE_MODEL_ID" not in globals():
    BASE_MODEL_ID = "Qwen/Qwen2.5-7B-Instruct"
if "DRIVE_ROOT" not in globals():
    DRIVE_ROOT = Path("/content/drive/MyDrive/TypeWriter")
if "DRIVE_BASE_MODEL_DIR" not in globals():
    DRIVE_BASE_MODEL_DIR = DRIVE_ROOT / "models" / "Qwen2.5-7B-Instruct"
if "DRIVE_HF_HOME" not in globals():
    DRIVE_HF_HOME = DRIVE_ROOT / "hf_home"
if "DRIVE_HF_HUB_CACHE" not in globals():
    DRIVE_HF_HUB_CACHE = DRIVE_HF_HOME / "hub"
if "INSTALL_BASE_MODEL_TO_DRIVE_IF_MISSING" not in globals():
    INSTALL_BASE_MODEL_TO_DRIVE_IF_MISSING = True
if "FORCE_REINSTALL_BASE_MODEL_TO_DRIVE" not in globals():
    FORCE_REINSTALL_BASE_MODEL_TO_DRIVE = False
if "BASE_MODEL_ALLOW_PATTERNS" not in globals():
    BASE_MODEL_ALLOW_PATTERNS = [
        "config.json", "generation_config.json",
        "tokenizer.json", "tokenizer.model", "tokenizer_config.json",
        "special_tokens_map.json", "vocab.json", "merges.txt",
        "*.safetensors", "*.safetensors.index.json",
    ]
if "BASE_MODEL_IGNORE_PATTERNS" not in globals():
    BASE_MODEL_IGNORE_PATTERNS = [
        "*.h5", "*.ot", "*.msgpack", "*.onnx", "*.tflite", "*.gguf",
        "*.bin", "flax_model*", "tf_model*", "onnx/*",
    ]

DRIVE_ROOT.mkdir(parents=True, exist_ok=True)
DRIVE_BASE_MODEL_DIR.mkdir(parents=True, exist_ok=True)
DRIVE_HF_HOME.mkdir(parents=True, exist_ok=True)
DRIVE_HF_HUB_CACHE.mkdir(parents=True, exist_ok=True)

# Make Hugging Face use Drive cache.
os.environ["HF_HOME"] = str(DRIVE_HF_HOME)
os.environ["HF_HUB_CACHE"] = str(DRIVE_HF_HUB_CACHE)
os.environ["TRANSFORMERS_CACHE"] = str(DRIVE_HF_HUB_CACHE)
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

def model_dir_status(path: Path):
    path = Path(path)
    has_config = (path / "config.json").exists()
    has_tokenizer = (
        (path / "tokenizer.json").exists()
        or (path / "tokenizer.model").exists()
        or (path / "tokenizer_config.json").exists()
    )
    has_weights = bool(list(path.glob("*.safetensors"))) or bool(list(path.glob("model-*.safetensors")))
    shard_count = len(list(path.glob("*.safetensors")))
    size_bytes = sum(p.stat().st_size for p in path.rglob("*") if p.is_file()) if path.exists() else 0
    return {
        "path": str(path),
        "exists": path.exists(),
        "has_config": has_config,
        "has_tokenizer": has_tokenizer,
        "has_weights": has_weights,
        "shard_count": shard_count,
        "size_gb": round(size_bytes / (1024 ** 3), 3),
        "ready": has_config and has_tokenizer and has_weights,
    }

def print_status(label, status):
    print(label)
    print(json.dumps(status, ensure_ascii=False, indent=2))

status_before = model_dir_status(DRIVE_BASE_MODEL_DIR)
print_status("DRIVE_BASE_MODEL_DIR status before", status_before)

if FORCE_REINSTALL_BASE_MODEL_TO_DRIVE and DRIVE_BASE_MODEL_DIR.exists():
    print("FORCE_REINSTALL_BASE_MODEL_TO_DRIVE=True. Removing existing directory:")
    print(DRIVE_BASE_MODEL_DIR)
    shutil.rmtree(DRIVE_BASE_MODEL_DIR)
    DRIVE_BASE_MODEL_DIR.mkdir(parents=True, exist_ok=True)
    status_before = model_dir_status(DRIVE_BASE_MODEL_DIR)

if status_before["ready"]:
    print("Base model/tokenizer already installed in Drive. Download skipped.")
else:
    if not INSTALL_BASE_MODEL_TO_DRIVE_IF_MISSING:
        print("Base model/tokenizer is missing, but INSTALL_BASE_MODEL_TO_DRIVE_IF_MISSING=False.")
        print("The loader may still use another cache candidate or download fallback.")
    else:
        print("Installing base model/tokenizer into Drive.")
        print("This can be large. Make sure Drive has enough free space.")
        try:
            from huggingface_hub import snapshot_download
        except Exception as e:
            raise RuntimeError(
                "huggingface_hub is missing. Run the install-dependencies cell first."
            ) from e

        snapshot_download(
            repo_id=BASE_MODEL_ID,
            local_dir=str(DRIVE_BASE_MODEL_DIR),
            local_dir_use_symlinks=False,
            allow_patterns=BASE_MODEL_ALLOW_PATTERNS,
            ignore_patterns=BASE_MODEL_IGNORE_PATTERNS,
            resume_download=True,
        )

status_after = model_dir_status(DRIVE_BASE_MODEL_DIR)
print_status("DRIVE_BASE_MODEL_DIR status after", status_after)

if status_after["ready"]:
    RESOLVED_BASE_MODEL_SOURCE = str(DRIVE_BASE_MODEL_DIR)
    USE_DRIVE_CACHE_FIRST = True
    ALLOW_DOWNLOAD_FALLBACK = True
    # Ensure the canonical installed dir is first.
    DRIVE_MODEL_CACHE_CANDIDATES = [DRIVE_BASE_MODEL_DIR] + [
        p for p in globals().get("DRIVE_MODEL_CACHE_CANDIDATES", [])
        if str(p) != str(DRIVE_BASE_MODEL_DIR)
    ]
    print("RESOLVED_BASE_MODEL_SOURCE =", RESOLVED_BASE_MODEL_SOURCE)
else:
    print("WARNING: Drive model directory is not ready yet.")
    print("Check free space, Hugging Face auth/network, or allow_patterns.")

# %%
#@title 3. Extract adapter
from pathlib import Path
import zipfile
import shutil

EXTRACT_ROOT = Path("/content/typewriter_v146bf_r2e_adapter")
if EXTRACT_ROOT.exists():
    shutil.rmtree(EXTRACT_ROOT)
EXTRACT_ROOT.mkdir(parents=True, exist_ok=True)

with zipfile.ZipFile(START_ADAPTER_ZIP) as z:
    z.extractall(EXTRACT_ROOT)

adapter_dirs = []
for p in EXTRACT_ROOT.rglob("adapter_config.json"):
    if (p.parent / "adapter_model.safetensors").exists() and "checkpoint-" not in str(p.parent):
        adapter_dirs.append(p.parent)

if not adapter_dirs:
    for p in EXTRACT_ROOT.rglob("adapter_config.json"):
        if (p.parent / "adapter_model.safetensors").exists():
            adapter_dirs.append(p.parent)

assert adapter_dirs, "No extracted adapter directory found."
ADAPTER_DIR = sorted(adapter_dirs, key=lambda p: len(str(p)))[0]
print("ADAPTER_DIR =", ADAPTER_DIR)
print("adapter files =", sorted([p.name for p in ADAPTER_DIR.iterdir() if p.name.startswith("adapter_")]))

# %%
#@title 4. Pack registry: genre_data + event_flow_rails

PACK_SCHEMA_VERSION = "v146br_event_rail_pack_schema_af1"

PACK_REGISTRY = {
    "TOWER_SYSTEM_RULE": {
        "genre_data": {
            "primary_genre": "tower_system_fantasy",
            "subgenres": ["growth", "trial", "competition", "guild", "association", "party", "survival"],
            "positive_signals": ["탑", "층", "시스템", "시험", "공략", "보상", "길드", "협회", "상태창", "랭커", "던전", "입장권", "통행증", "이미 깬 층 귀환 불가"],
            "roles": ["climber", "ranker", "guild_operator", "association_clerk", "record_keeper"],
            "genre_conventions": [
                "탑은 의뢰를 내지 않는다",
                "층을 오르거나 돌파하면 보상을 준다",
                "공략 기한 압력은 탑 내부 문구가 아니라 외부 협회/길드/도시 공시로 묘사한다",
                "기한 제한은 최고 공략층 갱신과 연결한다",
                "상층으로 갈수록 기한이 더 널널해진다",
                "긴박한 전투 중 상태창/UI 상시 노출은 페널티이므로 보통 끈다",
                "한번 클리어한 층은 이례적 예외가 아니면 다시 갈 수 없으므로, 등반 압력은 다음 층 선택과 최고층 기록 갱신에서 온다",
                "입장권/통행증은 상인이 아니라 길드나 협회가 발급한다",
                "특정 층 소재 채집 의뢰는 탑 바깥 길드/협회 의뢰로만 다룬다"
            ],
            "material_pool": ["협회 공시판", "길드 접수증", "입장 통행증", "최고층 갱신표", "공략 기록", "돌파 이력 봉인", "층 돌파 보상함", "상태창 차단 설정"],
            "forbidden_bleed": [
                "탑이 직접 의뢰를 내는 표현",
                "탑 내부 붉은 잉크/의뢰지/기한표",
                "상인이 탑 입장권을 판매하는 표현",
                "보스전 중 상태창을 계속 켜고 싸우는 연출",
                "로판 찻잔 표면어 과다",
                "천해 물성 혼입",
                "코드/XML/UI 로그 폭주",
                "일반적인 하층 재입장/재방문 제한 최적화"
            ],
        },
        "event_flow_rails": {
            "initial_pressure": ["외부 협회/길드/도시 공시가 최고 공략층 갱신 기한을 압박한다."],
            "disruption_event": ["새 최고층 기록, 상승 경로 잠금, 층 돌파 보상, 길드 소재 의뢰 중 하나가 예상과 어긋난다."],
            "material_anchor": ["협회 공시판, 길드 접수증, 입장 통행증, 최고층 갱신표, 공략 기록, 돌파 이력 봉인 중 하나를 사건의 증거로 둔다."],
            "choice_cost": ["무리하게 상층을 노리면 즉시 위험해지고, 낮은 층 반복을 택하면 이미 깬 층으로 돌아갈 수 없는 원칙과 상승 강제 규칙에 막힌다."],
            "consequence": ["선택이 최고층 갱신 순위, 협회 평가, 파티 신뢰, 길드 의뢰 책임 중 하나에 흔적을 남긴다."],
            "next_hook": ["기한이 더 널널한 상층 조건이나 서로 다른 공략 기록이 히든피스를 암시하며 장면을 닫는다."],
        },
    },
        "AETHER_WHALERS": {
        "genre_data": {
            "primary_genre": "aether_whaling_sky_maritime_fantasy",
            "subgenres": ["sky_maritime", "frontier", "industrial_fantasy", "war_technology_intrusion"],
            "positive_signals": ["천해", "비공선", "고래", "천령석", "천해석", "부력낭", "증기", "공어", "암괴", "하늘바다"],
            "roles": ["captain", "engineer", "harpooner", "navigator", "stranded_soldier"],
            "genre_conventions": ["천해 항해", "비공선 운용", "천령석/천해석 분리", "부력낭", "증기기관", "고래잡이", "지상 전쟁 기술 유입"],
            "material_pool": ["천령석", "천해석", "부력낭", "증기 압력계", "권양기", "포경창", "공어", "부유암괴"],
            "forbidden_bleed": ["하르피아 약탈 단정", "석유 내연기관 보편화", "이미지 생성 지시"],
        },
        "event_flow_rails": {
            "initial_pressure": ["항로, 부력, 증기 압력, 고래 출몰 중 하나가 출항 목적을 압박한다."],
            "disruption_event": ["천해석 부력 또는 증기 장치가 흔들려 배의 균형이 깨진다."],
            "material_anchor": ["천령석/천해석의 역할 차이, 부력낭, 권양기, 포경 장비를 사건 해결 도구로 쓴다."],
            "choice_cost": ["고래를 쫓으면 배가 위험해지고, 배를 살리면 임무/수익/전쟁 정보가 사라진다."],
            "consequence": ["선택이 항로, 선원 신뢰, 기관 상태, 지상 기술의 한계 중 하나를 바꾼다."],
            "next_hook": ["천해의 기상/암괴/공어 떼/낯선 지상 장비가 다음 장면의 위험을 예고한다."],
        },
    },
    "ROMANTASY_HOUSE_CONTRACT": {
        "genre_data": {
            "primary_genre": "romantasy_house_contract",
            "subgenres": ["aristocratic_politics", "engagement_contract", "public_reputation", "succession"],
            "positive_signals": ["로판", "악역영애", "공작", "후작", "황녀", "약혼", "혼인", "연회장", "가문", "계약", "귀족"],
            "roles": ["villainess", "duke_heir", "princess", "guardian", "fiance"],
            "genre_conventions": ["가문 계약", "연회장", "계승권", "혼인/약혼 압력", "평판", "귀족 정치"],
            "material_pool": ["초대장", "봉랍", "좌석 배치", "호칭", "계약서", "가문 문장", "장갑", "잔"],
            "forbidden_bleed": ["탑 시스템 표면어 과다", "추리 사건 단서 구조 과다"],
        },
        "event_flow_rails": {
            "initial_pressure": ["연회장/응접실/계약 자리에서 공개 체면과 가문 이해가 인물을 묶는다."],
            "disruption_event": ["약혼, 후견, 계승, 초대장, 좌석 배치 중 하나가 예상과 다르게 공개된다."],
            "material_anchor": ["봉랍, 계약서, 좌석표, 호칭, 가문 문장 같은 사회적 물성을 사건 중심에 둔다."],
            "choice_cost": ["침묵하면 평판이 죽고, 반박하면 가문 거래/혼인/후견 관계가 흔들린다."],
            "consequence": ["선택이 공개 소문, 가문 동맹, 후계 순위, 상대의 태도 중 하나를 바꾼다."],
            "next_hook": ["다음 초대/계약 조항/비밀 증인의 등장이 압력으로 남는다."],
        },
    },
    "CLOSED_CIRCLE_MYSTERY": {
        "genre_data": {
            "primary_genre": "closed_circle_mystery",
            "subgenres": ["classic_detective", "mansion_mystery", "alibi_puzzle", "fair_clue"],
            "positive_signals": ["추리", "미스터리", "살인", "탐정", "알리바이", "용의자", "밀실", "저택", "단서", "범인", "크리스티"],
            "roles": ["detective", "suspect", "host", "servant", "witness"],
            "genre_conventions": ["폐쇄 공간", "다중 용의자", "알리바이", "동기", "수단", "공정한 단서", "진술 균열"],
            "material_pool": ["시간표", "열쇠", "찻잔", "촛대", "서재", "창문", "젖은 발자국", "장갑"],
            "forbidden_bleed": ["작가만 아는 해답", "현대 수사 장비 만능", "탑 시스템 로그 혼입"],
        },
        "event_flow_rails": {
            "initial_pressure": ["폭풍/고립/잠긴 문/저택 규칙이 인물들을 한 장소에 묶는다."],
            "disruption_event": ["시체, 사라진 물건, 어긋난 알리바이, 거짓 진술 중 하나가 드러난다."],
            "material_anchor": ["시간표, 열쇠, 찻잔, 촛대, 발자국 같은 공정한 단서를 장면에 심는다."],
            "choice_cost": ["탐정이 질문을 바꾸면 용의자 관계가 흔들리고, 침묵하면 단서가 사라진다."],
            "consequence": ["진술 하나가 깨지며 용의자 구도가 재배열된다."],
            "next_hook": ["사소한 물건의 위치나 시간 차이가 다음 조사 질문을 만든다."],
        },
    },
    "RETURN_FANTASY": {
        "genre_data": {
            "primary_genre": "return_fantasy",
            "subgenres": ["regression", "ruin_prevention", "future_knowledge", "second_chance"],
            "positive_signals": ["회귀", "다시", "과거", "파멸", "멸망", "미래", "두 번째", "복수", "후회"],
            "roles": ["regressor", "failed_heir", "survivor", "ruined_protagonist"],
            "genre_conventions": ["파멸 직전 회귀", "미래 지식", "선택 변경", "오차", "대가"],
            "material_pool": ["낯익은 상처", "과거 날짜", "바뀐 선택", "예정된 사건의 어긋남", "오래된 편지"],
            "forbidden_bleed": ["미래지식 만능", "연표 설명 과식"],
        },
        "event_flow_rails": {
            "initial_pressure": ["인물은 이미 실패를 알고 있으며, 같은 장면의 작은 차이를 감지한다."],
            "disruption_event": ["미래 기억과 다른 사소한 오차가 발생한다."],
            "material_anchor": ["상처, 날짜, 편지, 낡은 물건, 반복된 대사 같은 기억 증거를 둔다."],
            "choice_cost": ["미래를 바꾸는 선택은 즉시 의심/손실/예상 밖 반작용을 낳는다."],
            "consequence": ["예정된 사건 하나가 어긋나며 주인공의 지식 신뢰도가 흔들린다."],
            "next_hook": ["알고 있던 미래가 더 이상 완전히 맞지 않는다는 압력으로 닫는다."],
        },
    },
    "GENERAL_WEBNOVEL": {
        "genre_data": {
            "primary_genre": "general_webnovel_scene",
            "subgenres": ["fallback_general"],
            "positive_signals": [],
            "roles": [],
            "genre_conventions": ["장면 중심", "선택 압력", "행동/대사/감각 혼합"],
            "material_pool": ["장소", "목적", "장애물", "선택 비용"],
            "forbidden_bleed": ["메타 해설", "프롬프트 노출"],
        },
        "event_flow_rails": {
            "initial_pressure": ["첫 문단에서 장소, 목적, 장애물을 고정한다."],
            "disruption_event": ["예상과 다른 사소한 변화가 인물의 계획을 바꾼다."],
            "material_anchor": ["손에 잡히는 물건, 문, 장부, 흔적 중 하나를 중심에 둔다."],
            "choice_cost": ["선택은 즉시 비용을 갖는다."],
            "consequence": ["인물의 행동이 다음 관계나 장소의 압력을 바꾼다."],
            "next_hook": ["요약 대신 다음 장면의 갈고리로 닫는다."],
        },
    },
}

print("PACK_SCHEMA_VERSION =", PACK_SCHEMA_VERSION)
print("pack_count =", len(PACK_REGISTRY))
print("packs =", list(PACK_REGISTRY))

# %%
#@title 5. Input → genre/context tags
import json
import re

def norm_text(s: str) -> str:
    return re.sub(r"\s+", " ", str(s or "")).strip()

def has_any(text: str, words):
    low = text.lower()
    return any(str(w).lower() in low for w in words)

def matched_words(text: str, words):
    low = text.lower()
    return [w for w in words if str(w).lower() in low]


# AF1K R13: strict regression intent.
# Plain "다시" is too broad: e.g. "다시 묻는" in mystery should not route to RETURN_FANTASY.
def is_explicit_regression_signal(text: str) -> bool:
    t = norm_text(text)
    if has_any(t, ["회귀", "두 번째 삶", "두 번째 생", "두번째 삶", "두번째 생", "첫 번째 삶", "첫번째 삶", "전생", "파멸 직전", "멸망 직전"]):
        return True
    if has_any(t, ["미래 지식", "미래를", "미래가", "미래와"]) and has_any(t, ["어긋", "바꾸", "달라", "흔들"]):
        return True
    if has_any(t, ["예정된"]) and has_any(t, ["암살", "모욕", "사건"]) and has_any(t, ["나타나지", "사라", "달라"]):
        return True
    return False

def is_plain_again_false_positive(text: str) -> bool:
    t = norm_text(text)
    return ("다시" in t) and not is_explicit_regression_signal(t)


def infer_contextual_data(user_input: str):
    text = norm_text(user_input)
    contextual_data = {
        "scene_intent": "establish_pressure",
        "output_type": "prose_scene",
        "temporal_position": "present_scene",
        "knowledge_source": "user_input_only",
        "protagonist_position": "active_agent",
        "situation": "open_scene",
        "conflict_pressure": "medium",
        "emotional_temperature": "restrained",
        "pov": "third_limited",
        "relationship_pressure": "implicit",
        "constraint_ban": [],
        "material_objects": [],
        "location_pressure": "undefined",
        "stakes": "choice_cost",
    }

    if has_any(text, ["시놉", "줄거리", "개요", "플롯"]):
        contextual_data["output_type"] = "synopsis_or_plot"
    if has_any(text, ["대사", "말싸움", "문답"]):
        contextual_data["output_type"] = "dialogue_scene"
    if has_any(text, ["첫화", "1화", "프롤로그", "도입"]):
        contextual_data["output_type"] = "opening_scene"

    if has_any(text, ["위기", "추궁", "살인", "파멸", "실패", "처형", "기한", "고립", "붕괴"]):
        contextual_data["conflict_pressure"] = "high"
    if has_any(text, ["차분", "냉정", "건조"]):
        contextual_data["emotional_temperature"] = "cool"
    if has_any(text, ["분노", "격정", "공포", "절박"]):
        contextual_data["emotional_temperature"] = "hot"
    if has_any(text, ["1인칭", "일인칭"]):
        contextual_data["pov"] = "first_person"
    if has_any(text, ["3인칭", "삼인칭"]):
        contextual_data["pov"] = "third_limited"

    if has_any(text, ["연회장", "약혼", "혼인", "가문", "계약"]):
        contextual_data["relationship_pressure"] = "public_social_pressure"
        contextual_data["location_pressure"] = "aristocratic_public_room"
    if has_any(text, ["밀실", "저택", "폭풍", "고립", "폐쇄"]):
        contextual_data["situation"] = "closed_circle"
        contextual_data["location_pressure"] = "sealed_location"
    if has_any(text, ["탑", "층", "시스템", "기한", "공략", "협회", "최고층", "재입장", "통행증"]):
        contextual_data["situation"] = "rule_bound_trial"
        contextual_data["location_pressure"] = "system_floor"
    if has_any(text, ["천해", "비공선", "고래", "부력낭", "암괴"]):
        contextual_data["situation"] = "aerial_maritime_operation"
        contextual_data["location_pressure"] = "unstable_sky_route"

    material_candidates = sorted(set(sum([v["genre_data"]["material_pool"] for v in PACK_REGISTRY.values()], [])))
    contextual_data["material_objects"] = matched_words(text, material_candidates)

    bans = []
    if has_any(text, ["코드 금지", "code 금지"]):
        bans.append("NO_CODE")
    if has_any(text, ["외국어 금지", "영어 금지", "중국어 금지"]):
        bans.append("NO_FOREIGN_LANGUAGE")
    if has_any(text, ["설명 금지", "메타 금지", "프롬프트 노출 금지"]):
        bans.append("NO_META_EXPLANATION")
    contextual_data["constraint_ban"] = bans

    if has_any(text, ["조연", "엑스트라", "단역", "npc"]):
        contextual_data["protagonist_position"] = "side_character_or_npc"
    if is_explicit_regression_signal(text):
        contextual_data["temporal_position"] = "post_regression"

    return contextual_data

def extract_tag_bundle(user_input: str):
    text = norm_text(user_input)

    genre_scores = {}
    genre_signal_hits = {}
    for pack_id, spec in PACK_REGISTRY.items():
        hits = matched_words(text, spec["genre_data"]["positive_signals"])
        genre_scores[pack_id] = len(hits)
        genre_signal_hits[pack_id] = hits

    overlay_tags = []
    if has_any(text, ["게임빙의", "빙의", "플레이어", "npc", "상태창", "호감도", "루트"]):
        overlay_tags.append("game_possession")
    if has_any(text, ["조연", "엑스트라", "단역", "npc"]):
        overlay_tags.append("side_character")
    if is_explicit_regression_signal(text):
        overlay_tags.append("regression")
    if has_any(text, ["악역영애"]):
        overlay_tags.append("villainess")

    role_tags = []
    if has_any(text, ["악역영애"]):
        role_tags.append("otome_villainess")
    if has_any(text, ["npc", "상인 npc"]):
        role_tags.append("rpg_npc")
    if has_any(text, ["탐정"]):
        role_tags.append("detective")
    if has_any(text, ["공작", "후작", "황녀", "왕녀"]):
        role_tags.append("aristocratic_actor")
    if has_any(text, ["랭커", "공략자", "헌터"]):
        role_tags.append("system_climber")

    return {
        "raw_input": text,
        "genre_scores": genre_scores,
        "genre_signal_hits": genre_signal_hits,
        "overlay_tags": sorted(set(overlay_tags)),
        "role_tags": sorted(set(role_tags)),
        "contextual_data": infer_contextual_data(text),
    }

demo = extract_tag_bundle("게임빙의 조연 NPC가 탑 17층 공략 뒤 외부 협회 공시의 최고층 갱신 기한을 보고 루트를 바꾸는 장면")
print(json.dumps(demo, ensure_ascii=False, indent=2))

# %%
#@title 6. Tag bundle → pack generation
import json
import re
import hashlib


# AF1K R13: router disambiguation.
def r13_apply_router_disambiguation(raw, scores):
    if not globals().get("R13_ENABLE_ROUTER_DISAMBIGUATION", True):
        return scores

    scores = dict(scores)
    mystery_strong = ["탐정", "알리바이", "용의자", "밀실", "별장", "저택", "찻잔", "남작", "발자국", "열쇠", "촛불", "창틀", "손잡이"]
    if has_any(raw, mystery_strong):
        scores["CLOSED_CIRCLE_MYSTERY"] = scores.get("CLOSED_CIRCLE_MYSTERY", 0) + 2
    if has_any(raw, ["탐정"]) and has_any(raw, ["찻잔", "남작", "손잡이", "알리바이", "발자국", "열쇠"]):
        scores["CLOSED_CIRCLE_MYSTERY"] = scores.get("CLOSED_CIRCLE_MYSTERY", 0) + 2

    if globals().get("R13_STRICT_REGRESSION_ROUTER", True):
        if "is_explicit_regression_signal" in globals() and not is_explicit_regression_signal(raw):
            if is_plain_again_false_positive(raw) if "is_plain_again_false_positive" in globals() else ("다시" in raw):
                scores["RETURN_FANTASY"] = max(0, scores.get("RETURN_FANTASY", 0) - 2)

    if "is_explicit_regression_signal" in globals() and is_explicit_regression_signal(raw):
        scores["RETURN_FANTASY"] = scores.get("RETURN_FANTASY", 0) + 2
        if has_any(raw, ["두 번째 삶", "첫 번째 삶", "회귀", "파멸 직전", "멸망 직전"]):
            scores["RETURN_FANTASY"] = scores.get("RETURN_FANTASY", 0) + 2

    return scores


def choose_primary_pack(tag_bundle):
    scores = dict(tag_bundle["genre_scores"])
    raw = tag_bundle["raw_input"]
    overlays = set(tag_bundle["overlay_tags"])

    # 게임빙의는 단독 장르가 아니라 overlay. 하위 장르를 밀어준다.
    if "game_possession" in overlays:
        if has_any(raw, ["탑", "층", "상태창", "공략", "퀘스트", "rpg"]):
            scores["TOWER_SYSTEM_RULE"] += 2
        if has_any(raw, ["악역영애", "미연시", "호감도", "약혼", "연회장"]):
            scores["ROMANTASY_HOUSE_CONTRACT"] += 2
        if has_any(raw, ["추리", "알리바이", "용의자", "밀실", "단서"]):
            scores["CLOSED_CIRCLE_MYSTERY"] += 2
        scores["GENERAL_WEBNOVEL"] = 0

    if "side_character" in overlays:
        if has_any(raw, ["npc", "상인 npc", "공략"]):
            scores["TOWER_SYSTEM_RULE"] += 1
        if has_any(raw, ["악역영애", "연회장", "가문"]):
            scores["ROMANTASY_HOUSE_CONTRACT"] += 1
        if has_any(raw, ["저택", "용의자", "탐정"]):
            scores["CLOSED_CIRCLE_MYSTERY"] += 1

    if "regression" in overlays and ("is_explicit_regression_signal" not in globals() or is_explicit_regression_signal(raw)):
        scores["RETURN_FANTASY"] += 2

    scores = r13_apply_router_disambiguation(raw, scores)

    ranked = sorted(scores.items(), key=lambda kv: (-kv[1], kv[0]))
    non_general = [(k, v) for k, v in ranked if k != "GENERAL_WEBNOVEL" and v > 0]
    primary = non_general[0][0] if non_general else "GENERAL_WEBNOVEL"
    top_score = scores.get(primary, 0)
    confidence = "high" if top_score >= 3 else "medium" if top_score >= 1 else "low"

    return {"primary_pack_id": primary, "confidence": confidence, "ranked_scores": ranked}

def overlay_event_rails(tag_bundle, primary_pack):
    rails = []
    overlays = set(tag_bundle["overlay_tags"])
    if "game_possession" in overlays:
        rails.append({
            "overlay_type": "game_possession",
            "flow_rule": "게임빙의는 단독 장르가 아니라 선택지/정보 비대칭/시스템 인식이 사건 흐름에 얹히는 layer다.",
            "initial_pressure": "인물은 자신이 원래 주역이 아니거나 규칙 밖 정보를 안다는 압력을 가진다.",
            "disruption_event": "원작/게임 지식과 실제 장면 사이에 작은 오차가 생긴다.",
            "choice_cost": "정해진 루트를 따르면 안전하지만 주변 인물이 피해를 보고, 벗어나면 시스템/관계가 반응한다.",
            "next_hook": "빙의자가 알고 있던 정보의 신뢰도가 흔들린다.",
        })
    if "regression" in overlays and primary_pack != "RETURN_FANTASY":
        rails.append({
            "overlay_type": "regression",
            "flow_rule": "회귀는 미래 지식이 장르 사건을 앞당기거나 비트는 layer다.",
            "initial_pressure": "인물은 이미 한번 실패한 사건의 초입에 서 있다.",
            "disruption_event": "미래와 다른 물성 하나가 발견된다.",
            "choice_cost": "미래를 바꾸는 행동이 즉각 반작용을 만든다.",
            "next_hook": "알던 미래가 더 이상 완전한 지도는 아니라는 압력을 남긴다.",
        })
    return rails


# AF1K R15: dynamic pack regeneration front-half.
def r15_short_hash(obj, n=12):
    data = json.dumps(obj, ensure_ascii=False, sort_keys=True) if not isinstance(obj, str) else obj
    return hashlib.sha256(data.encode("utf-8")).hexdigest()[:n]

def r15_stable_pick(items, key, k=1):
    items = list(items or [])
    if not items:
        return []
    ranked = sorted(items, key=lambda x: r15_short_hash(str(key) + "::" + str(x), 16))
    return ranked[:max(0, min(k, len(ranked)))]

def r15_input_tokens(user_input):
    t = norm_text(user_input)
    # Korean-friendly rough material chunks: keep nouns/signal chunks without requiring morphological analyzer.
    chunks = re.findall(r"[가-힣A-Za-z0-9]{2,}", t)
    stop = {"장면", "주인공", "때문", "먼저", "다시", "보고", "확인", "하는", "에서", "에게", "보다", "것을"}
    return [c for c in chunks if c not in stop][:18]

def r15_synthesize_materials(user_input, pack_id, base_materials, contextual_data):
    input_objs = list(contextual_data.get("material_objects") or [])
    tokens = r15_input_tokens(user_input)
    token_objs = []
    material_signals = {
        "TOWER_SYSTEM_RULE": ["공시", "통행증", "기록", "층", "도장", "의뢰", "접수증", "상태창", "보상"],
        "AETHER_WHALERS": ["천해", "부력낭", "권양기", "공어", "난류", "정찰", "비공선", "천해석"],
        "ROMANTASY_HOUSE_CONTRACT": ["계약", "장갑", "봉랍", "좌석표", "연회", "약혼", "조항", "서명"],
        "CLOSED_CIRCLE_MYSTERY": ["탐정", "알리바이", "찻잔", "열쇠", "촛불", "발자국", "창틀", "남작", "서랍"],
        "RETURN_FANTASY": ["회귀", "미래", "편지", "암살", "모욕", "첫", "두", "파멸", "기억", "오차"],
        "GENERAL_WEBNOVEL": ["단추", "서랍", "문틈", "발소리", "비", "시선", "물건", "비용"],
    }.get(pack_id, [])

    for tok in tokens:
        if any(sig in tok for sig in material_signals):
            token_objs.append(tok)

    merged = []
    for x in input_objs + token_objs:
        if x and x not in merged:
            merged.append(x)

    limit = int(globals().get("R15_PACK_REGEN_MATERIAL_LIMIT", 5))
    base_pick = r15_stable_pick(base_materials, user_input + pack_id, max(0, limit - len(merged)))
    for x in base_pick:
        if x not in merged:
            merged.append(x)
    return merged[:limit]

def r15_genre_boundary_for_pack(pack_id):
    boundaries = {
        "TOWER_SYSTEM_RULE": "탑은 명령/의뢰를 내리지 않고, 한번 클리어한 층은 이례적 예외가 아니면 다시 갈 수 없으며, 바깥 협회/길드가 기록/통행증/의뢰를 다룬다.",
        "AETHER_WHALERS": "천해 항해/부력/증기/천해석 물성이 중심이며 지상 전쟁 기술은 낯선 외부 요소로만 둔다.",
        "ROMANTASY_HOUSE_CONTRACT": "감정 선언보다 계약 조항, 증언 순서, 가문 체면의 거래 비용이 중심이다.",
        "CLOSED_CIRCLE_MYSTERY": "탐정식 공정 단서, 알리바이/배치/물성 모순이 중심이며 회귀/계약 로맨스가 중심을 뺏지 않는다.",
        "RETURN_FANTASY": "첫 번째 삶의 기억과 현재의 오차, 미래 지식의 불안정성, 선택 비용이 중심이다.",
        "GENERAL_WEBNOVEL": "장르 표면어보다 방 안의 물성, 선택 비용, 시선 변화로 사건을 밀어간다.",
    }
    return boundaries.get(pack_id, "입력 물성과 선택 비용을 중심으로 장면을 구성한다.")

def r15_synthesize_event_delta(user_input, pack_id, contextual_data, selected_materials):
    mats = selected_materials or ["작은 단서"]
    main_mat = mats[0]
    second_mat = mats[1] if len(mats) > 1 else mats[0]

    by_pack = {
        "TOWER_SYSTEM_RULE": {
            "initial_pressure": f"입력의 핵심 물성인 {main_mat}이 외부 협회/길드 절차와 연결되어 장면 압력을 만든다.",
            "disruption_event": f"{second_mat}의 조건이 예상과 어긋나 하층 귀환이 불가능해 다음 층 선택을 강제한다.",
            "material_anchor": f"{main_mat}을 단순 장식이 아니라 판단 증거로 사용한다.",
            "choice_cost": "다음 층 도전, 의뢰 거절, 통행증 보류 중 하나가 즉시 비용으로 돌아온다.",
            "next_hook": "서로 다른 기록 또는 완화된 상층 기한이 다음 선택을 암시한다.",
        },
        "AETHER_WHALERS": {
            "initial_pressure": f"{main_mat}이 천해 항로의 안전보다 먼저 흔들리며 선체 위험을 만든다.",
            "disruption_event": f"{second_mat}이 고래/전투보다 긴급한 항해 문제로 떠오른다.",
            "material_anchor": f"{main_mat}의 물리적 변화로 천해석/부력/증기 체계를 드러낸다.",
            "choice_cost": "사냥을 계속하면 선체를 잃고, 항로를 포기하면 목표를 놓친다.",
            "next_hook": "천해 조류나 지상 기술 오인이 다음 항로의 불안을 남긴다.",
        },
        "ROMANTASY_HOUSE_CONTRACT": {
            "initial_pressure": f"{main_mat}이 가문 체면보다 계약 조건을 먼저 흔든다.",
            "disruption_event": f"{second_mat}의 위치나 순서가 증언/조항 해석을 바꾼다.",
            "material_anchor": f"{main_mat}을 관계 감정이 아니라 법적/사회적 비용의 증거로 둔다.",
            "choice_cost": "체면을 지키면 불리한 조항을 삼키고, 조항을 묻자니 공개 균열을 만든다.",
            "next_hook": "서명/날짜/증언 순서 중 하나가 다음 협상장을 연다.",
        },
        "CLOSED_CIRCLE_MYSTERY": {
            "initial_pressure": f"{main_mat}이 증언보다 먼저 모순을 드러낸다.",
            "disruption_event": f"{second_mat}이 알리바이의 순서를 뒤집는 작은 단서가 된다.",
            "material_anchor": f"{main_mat}을 공정 단서로 제시하고 독자가 따라잡을 수 있게 둔다.",
            "choice_cost": "범인을 단정하면 단서 하나를 잃고, 질문을 미루면 다음 증언이 오염된다.",
            "next_hook": "배치/습관/시간 차 중 하나가 다음 질문을 강제한다.",
        },
        "RETURN_FANTASY": {
            "initial_pressure": f"{main_mat}이 첫 번째 삶의 기억과 다른 오차로 나타난다.",
            "disruption_event": f"{second_mat} 때문에 미래 지식의 신뢰가 흔들린다.",
            "material_anchor": f"{main_mat}을 회귀 사실의 설명이 아니라 현재가 달라졌다는 증거로 쓴다.",
            "choice_cost": "복수를 앞당기면 더 큰 변수가 생기고, 확인을 택하면 원래 기회를 놓친다.",
            "next_hook": "기억과 다른 빈칸이 다음 선택의 비용을 예고한다.",
        },
        "GENERAL_WEBNOVEL": {
            "initial_pressure": f"{main_mat}이 방 안의 시선과 선택 압력을 바꾼다.",
            "disruption_event": f"{second_mat}이 누가 먼저 움직였는지에 대한 판단을 흔든다.",
            "material_anchor": f"{main_mat}을 추상 감정 대신 장면을 움직이는 증거로 둔다.",
            "choice_cost": "큰 선택을 미루고 작은 단서를 택하는 순간 더 위험한 비용이 생긴다.",
            "next_hook": "숨긴 물건/문밖 기척/남은 비용 중 하나로 장면을 닫는다.",
        },
    }
    return by_pack.get(pack_id, by_pack["GENERAL_WEBNOVEL"])

def r15_apply_event_delta(event_flow_rails, delta):
    out = json.loads(json.dumps(event_flow_rails, ensure_ascii=False))
    for key, val in delta.items():
        if key in out:
            out[key] = [val] + list(out.get(key, []))[:int(globals().get("R15_PACK_REGEN_EVENT_LIMIT", 2))]
    return out

def r15_pack_qa(pack):
    issues = []
    warnings = []
    pack_id = pack.get("pack_id")
    gd = pack.get("genre_data", {})
    cd = pack.get("contextual_data", {})
    er = pack.get("event_flow_rails", {})
    overlay = pack.get("generated_pack_overlay", {})
    mats = (pack.get("materiality_rails", {}) or {}).get("selected_materials", [])

    required = ["initial_pressure", "disruption_event", "material_anchor", "choice_cost", "consequence", "next_hook"]
    for k in required:
        if not er.get(k):
            issues.append(f"MISSING_EVENT_RAIL:{k}")
    if not mats:
        warnings.append("NO_SELECTED_MATERIALS")
    if not gd.get("genre_boundary"):
        warnings.append("NO_GENRE_BOUNDARY")
    if not overlay.get("pack_instance_id"):
        issues.append("NO_PACK_INSTANCE_ID")
    if pack_id == "TOWER_SYSTEM_RULE":
        txt = " ".join(sum([er.get(k, []) for k in er], []))
        if "탑이 직접 의뢰" in txt or "붉은 잉크" in txt:
            issues.append("TOWER_LORE_BLEED_IN_PACK")
    if pack_id == "RETURN_FANTASY":
        if cd.get("temporal_position") != "post_regression" and "regression" not in gd.get("overlay_tags", []):
            warnings.append("RETURN_WITHOUT_TEMPORAL_CONTEXT")

    verdict = "PASS" if not issues else "FAIL"
    if warnings and verdict == "PASS":
        verdict = "WATCH"
    return {
        "verdict": verdict,
        "issues": issues,
        "warnings": warnings,
        "pack_id": pack_id,
        "pack_instance_id": overlay.get("pack_instance_id"),
        "selected_materials": mats,
    }

def r15_regenerate_pack_instance(pack, user_input, tag_bundle, selection):
    if not globals().get("R15_ENABLE_DYNAMIC_PACK_REGEN", True):
        pack["pack_generation_mode"] = "base_registry_only"
        return pack

    pack_id = pack["pack_id"]
    contextual_data = pack["contextual_data"]
    base_materials = pack["genre_data"].get("material_pool", [])
    selected_materials = r15_synthesize_materials(user_input, pack_id, base_materials, contextual_data)
    event_delta = r15_synthesize_event_delta(user_input, pack_id, contextual_data, selected_materials)
    pack["event_flow_rails"] = r15_apply_event_delta(pack["event_flow_rails"], event_delta)

    pack_instance_id = f"{pack_id}__{r15_short_hash({'input': user_input, 'pack': pack_id, 'materials': selected_materials}, 10)}"
    pack["generated_pack_overlay"] = {
        "pack_instance_id": pack_instance_id,
        "base_pack_id": pack_id,
        "generation_mode": globals().get("R15_PACK_REGEN_MODE", "deterministic_input_instance"),
        "input_focus_tokens": r15_input_tokens(user_input)[:10],
        "selected_materials": selected_materials,
        "event_delta": event_delta,
        "genre_boundary": r15_genre_boundary_for_pack(pack_id),
        "route_confidence": selection.get("confidence"),
        "selection_scores": selection.get("scores", {}),
    }

    pack["genre_data"]["genre_boundary"] = pack["generated_pack_overlay"]["genre_boundary"]
    pack["materiality_rails"]["selected_materials"] = selected_materials
    pack["materiality_rails"]["rule"] += " R15에서는 selected_materials를 우선 사용한다."
    pack["prompt_contract"]["pack_instance_rule"] = "이 입력을 위해 재생성된 generated_pack_overlay를 우선 따른다."

    qa = r15_pack_qa(pack)
    pack["pack_qa_report"] = qa
    if qa["verdict"] == "FAIL" and globals().get("R15_PACK_QA_FAIL_HARD", False):
        raise AssertionError("R15 pack QA failed: " + json.dumps(qa, ensure_ascii=False))
    return pack


def make_pack(user_input, tag_bundle, selection):
    primary_id = selection["primary_pack_id"]
    base = PACK_REGISTRY[primary_id]
    genre_data = json.loads(json.dumps(base["genre_data"], ensure_ascii=False))
    contextual_data = dict(tag_bundle["contextual_data"])

    genre_data["selected_pack_id"] = primary_id
    genre_data["selection_confidence"] = selection["confidence"]
    genre_data["matched_signals"] = tag_bundle["genre_signal_hits"].get(primary_id, [])
    genre_data["overlay_tags"] = tag_bundle["overlay_tags"]
    genre_data["role_tags"] = tag_bundle["role_tags"]

    event_flow_rails = json.loads(json.dumps(base["event_flow_rails"], ensure_ascii=False))
    overlay_rails = overlay_event_rails(tag_bundle, primary_id)

    materiality_rails = {
        "material_pool": genre_data["material_pool"],
        "input_material_objects": contextual_data["material_objects"],
        "rule": "입력 물성이 있으면 우선 사용하고, 없으면 장르 material_pool에서 1~3개를 골라 사건의 증거/도구/비용으로 쓴다.",
    }

    prompt_contract = {
        "language": "ko",
        "final_output": "본문만 출력",
        "target_length_chars": [900, 1800],
        "must_not_include": ["Human:", "Assistant:", "System:", "User:", "<|im_start|>", "<|im_end|>", "```", "XML", "JSON", "코드", "프롬프트", "태그 설명"],
        "style_rule": "설명보다 장면, 선언보다 물성, 감정명보다 행동.",
        "ending_rule": "요약 대신 next_hook 압력으로 닫기.",
    }

    gate_contract = {
        "runner_gate": "V146BQ",
        "fallback_policy": "salvage_repair → final_gate → deterministic_fallback",
        "hard_fail_patterns": ["prompt_residue", "foreign_or_code", "broken_char", "repetition_run", "empty_final"],
    }

    pack = {
        "pack_schema_version": PACK_SCHEMA_VERSION,
        "pack_id": primary_id,
        "source_user_input": user_input,
        "genre_data": genre_data,
        "contextual_data": contextual_data,
        "event_flow_rails": event_flow_rails,
        "overlay_event_rails": overlay_rails,
        "materiality_rails": materiality_rails,
        "prompt_contract": prompt_contract,
        "gate_contract": gate_contract,
    }
    pack = r15_regenerate_pack_instance(pack, user_input, tag_bundle, selection)
    return pack

def front_half(user_input):
    tag_bundle = extract_tag_bundle(user_input)
    selection = choose_primary_pack(tag_bundle)
    pack = make_pack(user_input, tag_bundle, selection)
    return {"input": user_input, "tag_bundle": tag_bundle, "selection": selection, "pack": pack}

demo_front = front_half("악역영애가 연회장에서 약혼 계약을 뒤집는 게임빙의 장면")
print(json.dumps(demo_front["selection"], ensure_ascii=False, indent=2))
print(json.dumps(demo_front["pack"], ensure_ascii=False, indent=2)[:5000])

# %%
#@title 7. Pack → event rail prompt

def lines(items):
    return "\n".join("- " + x for x in items)

def build_event_rail_prompt(pack):
    gd = pack["genre_data"]
    cd = pack["contextual_data"]
    er = pack["event_flow_rails"]
    mr = pack["materiality_rails"]
    pc = pack["prompt_contract"]
    gpo = pack.get("generated_pack_overlay", {}) or {}
    pqa = pack.get("pack_qa_report", {}) or {}

    overlay_lines = []
    for o in pack["overlay_event_rails"]:
        overlay_lines.append(f"- [{o['overlay_type']}] {o['flow_rule']}")
        overlay_lines.append(f"  initial_pressure: {o['initial_pressure']}")
        overlay_lines.append(f"  disruption_event: {o['disruption_event']}")
        overlay_lines.append(f"  choice_cost: {o['choice_cost']}")
        overlay_lines.append(f"  next_hook: {o['next_hook']}")

    prompt = f"""
너는 한국어 웹소설 본문 생성 엔진이다.
아래 pack을 실행한다. 최종 출력에는 pack, 태그, 프롬프트, 해설을 절대 노출하지 않는다.

[USER_INPUT]
{pack["source_user_input"]}

[GENRE_DATA]
selected_pack_id = {pack["pack_id"]}
primary_genre = {gd["primary_genre"]}
subgenres = {", ".join(gd["subgenres"])}
role_tags = {", ".join(gd["role_tags"]) if gd["role_tags"] else "none"}
overlay_tags = {", ".join(gd["overlay_tags"]) if gd["overlay_tags"] else "none"}
genre_conventions = {", ".join(gd["genre_conventions"])}
matched_signals = {", ".join(gd["matched_signals"]) if gd["matched_signals"] else "none"}
forbidden_bleed = {", ".join(gd["forbidden_bleed"])}

[CONTEXTUAL_DATA]
scene_intent = {cd["scene_intent"]}
output_type = {cd["output_type"]}
temporal_position = {cd["temporal_position"]}
protagonist_position = {cd["protagonist_position"]}
situation = {cd["situation"]}
conflict_pressure = {cd["conflict_pressure"]}
emotional_temperature = {cd["emotional_temperature"]}
pov = {cd["pov"]}
relationship_pressure = {cd["relationship_pressure"]}
location_pressure = {cd["location_pressure"]}
stakes = {cd["stakes"]}

[GENERATED_PACK_INSTANCE]
pack_instance_id = {gpo.get("pack_instance_id", "base_registry_only")}
generation_mode = {gpo.get("generation_mode", "base_registry_only")}
selected_materials = {", ".join(gpo.get("selected_materials", [])) if gpo.get("selected_materials") else "none"}
genre_boundary = {gpo.get("genre_boundary", gd.get("genre_boundary", "none"))}
input_focus_tokens = {", ".join(gpo.get("input_focus_tokens", [])) if gpo.get("input_focus_tokens") else "none"}
pack_qa_verdict = {pqa.get("verdict", "UNKNOWN")}
pack_qa_warnings = {", ".join(pqa.get("warnings", [])) if pqa.get("warnings") else "none"}

[EVENT_FLOW_RAILS]
initial_pressure:
{lines(er["initial_pressure"])}
disruption_event:
{lines(er["disruption_event"])}
material_anchor:
{lines(er["material_anchor"])}
choice_cost:
{lines(er["choice_cost"])}
consequence:
{lines(er["consequence"])}
next_hook:
{lines(er["next_hook"])}

[OVERLAY_EVENT_RAILS]
{chr(10).join(overlay_lines) if overlay_lines else "- none"}

[MATERIALITY_RAILS]
material_pool = {", ".join(mr["material_pool"])}
input_material_objects = {", ".join(mr["input_material_objects"]) if mr["input_material_objects"] else "none"}
rule = {mr["rule"]}

[OUTPUT_CONTRACT]
- 한국어 본문만 출력한다.
- 제목, 목록, 작가 메모, 분석, 태그 설명을 출력하지 않는다.
- Human:, Assistant:, System:, User:, XML, JSON, 코드블록을 출력하지 않는다.
- 목표 분량은 {pc["target_length_chars"][0]}~{pc["target_length_chars"][1]}자.
- 첫 문단에서 initial_pressure를 장면으로 고정한다.
- 중간에는 disruption_event → material_anchor → choice_cost가 사건으로 이어져야 한다.
- 끝은 consequence를 남기고 next_hook 압력으로 닫는다.
- 문장 운용: {pc["style_rule"]}
""".strip()

    if pack.get("pack_id") == "RETURN_FANTASY" and globals().get("R13_ENABLE_RETURN_FOCUS_REPAIR", True):
        prompt += """

[R13_RETURN_FANTASY_FOCUS]
- 첫 2문장 안에 회귀/두 번째 삶/첫 번째 삶/미래 오차/파멸 기억 중 하나를 장면으로 드러낸다.
- 연회장/찻잔/계약/탐정/증언 소재가 입력에 있어도 중심축은 반드시 '기억과 현재의 차이 → 선택 비용'이다.
- 로맨스 계약물/폐쇄 추리물 소재는 보조 물성으로만 쓰고 장르 중심을 빼앗지 않는다.
- 결말은 복수 선언이 아니라, 미래 지식의 신뢰가 흔들리는 next_hook으로 닫는다.
""".strip()
    return prompt

demo_prompt = build_event_rail_prompt(demo_front["pack"])
print(demo_prompt[:6000])

# %%
#@title 8. Load model + V146BF R2E adapter, Drive cache first

# Defensive defaults for rerunning this cell directly.
from pathlib import Path
import os
if "BASE_MODEL_ID" not in globals():
    BASE_MODEL_ID = "Qwen/Qwen2.5-7B-Instruct"
if "DRIVE_ROOT" not in globals():
    DRIVE_ROOT = Path("/content/drive/MyDrive/TypeWriter")
if "USE_DRIVE_CACHE_FIRST" not in globals():
    USE_DRIVE_CACHE_FIRST = True
if "ALLOW_DOWNLOAD_FALLBACK" not in globals():
    ALLOW_DOWNLOAD_FALLBACK = True
if "DRIVE_MODEL_CACHE_CANDIDATES" not in globals():
    DRIVE_MODEL_CACHE_CANDIDATES = [
        DRIVE_ROOT / "models" / "Qwen2.5-7B-Instruct",
        DRIVE_ROOT / "model_cache" / "Qwen2.5-7B-Instruct",
        DRIVE_ROOT / "hf_cache" / "models--Qwen--Qwen2.5-7B-Instruct",
        Path("/content/drive/MyDrive/huggingface/hub/models--Qwen--Qwen2.5-7B-Instruct"),
        Path("/content/drive/MyDrive/Models/Qwen2.5-7B-Instruct"),
    ]
if "DRY_RUN_WITH_DETERMINISTIC_TEXT" not in globals():
    DRY_RUN_WITH_DETERMINISTIC_TEXT = False

if "DRIVE_BASE_MODEL_DIR" not in globals():
    DRIVE_BASE_MODEL_DIR = DRIVE_ROOT / "models" / "Qwen2.5-7B-Instruct"
if "DRIVE_HF_HOME" not in globals():
    DRIVE_HF_HOME = DRIVE_ROOT / "hf_home"
if "DRIVE_HF_HUB_CACHE" not in globals():
    DRIVE_HF_HUB_CACHE = DRIVE_HF_HOME / "hub"
os.environ["HF_HOME"] = str(DRIVE_HF_HOME)
os.environ["HF_HUB_CACHE"] = str(DRIVE_HF_HUB_CACHE)
os.environ["TRANSFORMERS_CACHE"] = str(DRIVE_HF_HUB_CACHE)


model = None
tokenizer = None
RESOLVED_BASE_MODEL_SOURCE = BASE_MODEL_ID

def _looks_like_hf_model_dir(path: Path):
    path = Path(path)
    if not path.exists() or not path.is_dir():
        return False
    has_config = (path / "config.json").exists()
    has_tokenizer = (
        (path / "tokenizer.json").exists()
        or (path / "tokenizer.model").exists()
        or (path / "tokenizer_config.json").exists()
    )
    has_weights = bool(list(path.glob("*.safetensors"))) or bool(list(path.glob("pytorch_model*.bin")))
    # HF hub cache snapshot directory can be nested under snapshots.
    if has_config and has_tokenizer:
        return True
    if has_config and has_weights:
        return True
    return False

def resolve_base_model_source():
    if not USE_DRIVE_CACHE_FIRST:
        return BASE_MODEL_ID, False

    candidates = [DRIVE_BASE_MODEL_DIR]
    for c in DRIVE_MODEL_CACHE_CANDIDATES:
        c = Path(c)
        candidates.append(c)
        if c.exists():
            candidates += list(c.glob("snapshots/*"))
            candidates += list(c.glob("**/snapshots/*"))

    seen = set()
    for c in candidates:
        c = Path(c)
        if str(c) in seen:
            continue
        seen.add(str(c))
        if _looks_like_hf_model_dir(c):
            print("Using cached base model/tokenizer:", c)
            return str(c), True

    print("No usable Drive/local model cache found.")
    if ALLOW_DOWNLOAD_FALLBACK:
        print("Falling back to Hugging Face model id:", BASE_MODEL_ID)
        return BASE_MODEL_ID, False

    raise FileNotFoundError(
        "No local base model/tokenizer cache found and ALLOW_DOWNLOAD_FALLBACK=False. "
        "Add Qwen2.5-7B-Instruct to Drive cache or enable download fallback."
    )

def load_model_and_adapter():
    global model, tokenizer, RESOLVED_BASE_MODEL_SOURCE
    if DRY_RUN_WITH_DETERMINISTIC_TEXT:
        print("DRY_RUN_WITH_DETERMINISTIC_TEXT=True. Model loading skipped.")
        return None, None

    import torch
    from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
    from peft import PeftModel

    RESOLVED_BASE_MODEL_SOURCE, local_only = resolve_base_model_source()

    print("Loading tokenizer from:", RESOLVED_BASE_MODEL_SOURCE)
    tokenizer = AutoTokenizer.from_pretrained(
        RESOLVED_BASE_MODEL_SOURCE,
        trust_remote_code=True,
        local_files_only=local_only,
    )
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.bfloat16,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
    )

    print("Loading base model from:", RESOLVED_BASE_MODEL_SOURCE)
    base = AutoModelForCausalLM.from_pretrained(
        RESOLVED_BASE_MODEL_SOURCE,
        quantization_config=bnb,
        device_map="auto",
        trust_remote_code=True,
        local_files_only=local_only,
    )

    print("Attaching adapter:", ADAPTER_DIR)
    model = PeftModel.from_pretrained(base, str(ADAPTER_DIR))
    model.eval()
    print("Model ready.")
    return model, tokenizer

model, tokenizer = load_model_and_adapter()


# AF1K R7 speed knobs.
try:
    import torch
    if globals().get("R7_ENABLE_TF32", True) and torch.cuda.is_available():
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
        try:
            torch.set_float32_matmul_precision("high")
        except Exception:
            pass
except Exception as e:
    print("R7 TF32 setup skipped:", repr(e))

try:
    if tokenizer.pad_token_id is None:
        tokenizer.pad_token = tokenizer.eos_token
    tokenizer.padding_side = globals().get("R7_BATCH_PADDING_SIDE", "left")
except Exception as e:
    print("R7 tokenizer pad setup skipped:", repr(e))

# %%
#@title 9. Generate body

import hashlib
import re
import json
from collections import Counter

def _fallback_variant(pack, modulo=None):
    pack_id = pack.get("pack_id", "GENERAL_WEBNOVEL")
    if modulo is None:
        modulo = FALLBACK_VARIANT_COUNT_BY_PACK.get(pack_id, 3) if "FALLBACK_VARIANT_COUNT_BY_PACK" in globals() else 3
    raw = (pack.get("source_user_input", "") + "|" + pack_id).encode("utf-8")
    return int(hashlib.sha256(raw).hexdigest(), 16) % max(1, modulo)

def _join_paras(*paras):
    return "\n\n".join(p.strip() for p in paras if p and p.strip())

def deterministic_body(pack):
    """AF1E: long, genre-specific, input-dependent safe fallback.

    This is used only after gate failure. It is deliberately lore-correct,
    longer than min length gates, and varied by user input hash.
    """
    pack_id = pack["pack_id"]
    v = _fallback_variant(pack)
    user_input = pack.get("source_user_input", "")

    if pack_id == "TOWER_SYSTEM_RULE":
        variants = [
            _join_paras(
                "협회 공시판 앞은 탑 입구보다 더 붐볐다. 4층을 돌파한 하급 공략자들은 보상함보다 먼저 최고층 갱신표를 보았다. 어제까지는 11층 기록만 유지하면 되었지만, 오늘 새벽 12층 돌파자가 나오면서 하층 공략자들의 갱신 기한이 사흘 앞당겨졌다. 상층으로 갈수록 기한은 널널해졌고, 아래에 머문 사람들만 더 좁은 칸으로 밀려났다.",
                "나는 상태창을 켜지 않았다. 보스전에서 눈앞에 숫자를 띄우는 건 방패를 얼굴에 붙이고 뛰는 짓이었다. 대신 협회 접수증의 작은 도장부터 확인했다. 이미 돌파한 3층에는 돌파 이력이 봉인되어 있었다. 쉬운 층을 반복해 보상을 긁어모으는 길은 막혔고, 길드 공시판의 12층 소재 채집 의뢰는 우리 실력으로 받기엔 목숨값이 더 비쌌다.",
                "그때 공략 기록 두 장이 서로 다른 문장을 품고 있다는 걸 보았다. 같은 7층, 같은 문, 같은 보상함. 그런데 한 기록에는 없던 측면 계단이 다른 기록에는 있었다. 나는 보상함의 잠금쇠에서 손을 떼고, 최고층 갱신표 아래 비어 있는 칸을 다시 읽었다. 그 칸은 실패 비용이 아니라 아직 아무도 확인하지 못한 길의 모양을 하고 있었다."
            ),
            _join_paras(
                "협회 접수대의 종이 울리자 대기 줄이 한 칸씩 줄었다. 탑이 의뢰를 내린 것은 아니었다. 탑은 언제나처럼 층을 오르는 자에게 보상만 주었고, 바깥의 협회가 그 보상을 기준으로 기한과 통행증을 조정했다. 오늘 공시에는 새 최고 공략층이 적혀 있었다. 기록이 갱신되자 하층 공략자들에게 남은 시간은 줄었고, 상층 공략자들의 기한은 오히려 넓어졌다.",
                "주인공은 입장 통행증을 받아 들고도 곧장 문으로 가지 않았다. 이미 돌파한 2층과 3층에는 돌파 이력 봉인이 찍혀 있었다. 쉬운 층을 다시 밟아 양민학살처럼 보상을 쓸어 담는 짓은 애초에 막혀 있었다. 길드의 소재 채집 접수증은 12층을 요구했지만, 접수원은 우리 파티의 최고 기록을 보고 한참 동안 펜을 움직이지 않았다.",
                "그 사이 기록관에서 복사된 공략 기록 하나가 책상 아래로 미끄러졌다. 공식 기록에는 없는 우회 계단이 사본에는 남아 있었다. 히든피스라면 보상함이 아니라 경로의 차이에 숨었을 것이다. 주인공은 상태창 차단 설정을 확인하고, 갱신 기한보다 먼저 그 사본의 접힌 모서리를 펼쳤다."
            ),
            _join_paras(
                "탑 안쪽은 조용했지만 바깥의 공시는 시끄러웠다. 협회는 새 최고층 기록을 갱신하자마자 하층 등반자들의 통행증 유효 시간을 다시 계산했다. 이상한 규칙은 아니었다. 더 높은 층을 밟을수록 기한은 널널해지고, 낮은 층에 오래 머문 사람일수록 정체 방지 규정에 밀려났다. 탑은 의뢰를 하지 않는다. 다만 올라간 만큼 보상하고, 바깥의 사람들은 그 보상표로 질서를 만든다.",
                "하급 공략자는 보상함의 은색 손잡이를 보면서도 손을 뻗지 못했다. 이미 돌파한 층으로 돌아가는 길은 이미 깬 층으로 돌아갈 수 없어서 닫혔고, 길드의 12층 소재 채집 의뢰는 이름만 그럴듯할 뿐 실제로는 실력 부족한 파티를 걸러내는 칼날에 가까웠다. 상태창을 열어 숫자를 확인하고 싶은 유혹이 있었지만, 곧 보스방 문이 열릴 상황에서 시야를 가리는 창은 독이나 다름없었다.",
                "그는 대신 두 장의 공략 기록을 나란히 놓았다. 하나에는 계단이 없고, 다른 하나에는 짧은 측면 계단이 있었다. 같은 층에서 기록이 갈라졌다면, 그 차이는 실수가 아니라 숨겨진 조건일 가능성이 컸다. 통행증의 시간이 줄어드는 동안, 그는 보상보다 먼저 그 조건을 찾기로 했다."
            ),
            _join_paras(
                "길드 회관의 공시판은 탑보다 먼저 사람을 시험했다. 새벽에 최고 공략층이 갱신되자 협회는 하층 등반자들의 갱신 기한을 다시 붙였다. 상층 기록을 가진 자들은 더 긴 유예를 받았고, 낮은 층에서 머무는 자들은 돌파 이력 봉인과 짧은 통행증 사이에 끼었다. 탑이 준 것은 층 돌파 보상뿐이었다. 나머지 압력은 모두 바깥에서 만들어졌다.",
                "주인공은 보스전 직전 상태창 차단 설정을 눌렀다. 능력치 숫자가 시야를 가리면 피할 수 있는 첫 공격도 놓친다. 길드 접수증에는 12층 소재 채집 의뢰가 적혀 있었지만, 파티의 실제 최고 기록은 7층이었다. 보상 분배를 논하기 전에 살아서 돌아올 수 있는지부터 따져야 했다.",
                "그때 기록관의 낡은 공략 기록이 문제를 일으켰다. 협회 사본과 길드 사본의 문장 하나가 달랐다. 공식 기록에는 직진 통로만 있었고, 길드 사본에는 닫힌 보상함 뒤쪽의 좁은 계단이 적혀 있었다. 주인공은 통행증을 접어 넣었다. 다음 선택은 더 높은 층이 아니라, 기록이 갈라진 바로 그 지점에서 시작될 것이다."
            ),
        ]
        return variants[v % len(variants)]

    if pack_id == "AETHER_WHALERS":
        variants = [
            _join_paras(
                "천해석 부력낭이 찢어진 것은 고래가 솟기 직전이었다. 갑판 아래의 증기 압력계가 붉은 눈금까지 밀려 올라갔고, 권양기에 걸린 사슬은 젖은 악기처럼 떨었다. 선장은 천령석 코어 쪽으로 뛰지 않았다. 먼저 부력낭을 붙잡은 견습 기관사의 손목을 보았다. 천령석이 흔들리면 배가 뒤집히지만, 천해석이 새면 배는 아주 천천히 죽는다.",
                "공어 떼가 비처럼 쏟아졌다. 지상에서 온 정찰병은 그 광경을 포탄 파편처럼 피했지만, 항해사는 고개를 저었다. 그건 포격이 아니라 조류였다. 하늘바다의 길은 물보다 느리고, 바람보다 고집이 세다. 고래를 쫓으면 오늘의 수익은 살릴 수 있었지만, 기관실 압력을 무시하면 선원 전체가 암괴 사이에 흩어질 것이다.",
                "선장은 포경창을 내리라고 명령했다. 고래를 잡기 위해서가 아니었다. 창끝에 묶은 밧줄로 오른쪽 부력낭을 갑판 난간에 임시 고정해야 했다. 권양기가 비명을 질렀고, 천령석실의 빛이 한 번 가늘어졌다. 그 짧은 흔들림 사이로, 정찰병의 지상식 나침반이 처음으로 북쪽이 아닌 고래의 그림자를 가리켰다."
            ),
            _join_paras(
                "부유암괴가 항로를 가로막자 선원들은 먼저 돛이 아니라 압력계를 보았다. 이 배는 낭만으로 뜨는 배가 아니었다. 천해석 부력층이 선체를 받치고, 증기기관이 권양기와 프로펠러를 밀며, 천령석 코어는 대형선의 마지막 균형을 잡아 주었다. 어느 하나가 자기 역할을 넘어서는 순간 하늘바다는 배를 곧장 삼켰다.",
                "기관사는 지상식 부품을 믿지 않았다. 전쟁에서 흘러온 프로펠러 축은 빠르고 날카로웠지만, 천해의 난류 앞에서는 너무 정직했다. 바람이 옆으로 흐르고 공어 떼가 아래에서 위로 튀어 오르자, 축은 계산보다 먼저 삐걱거렸다. 선장은 고래를 포기하면 항구의 빚을 감당해야 했고, 고래를 쫓으면 부력낭을 잃을 수 있었다.",
                "그는 포경창을 고래가 아니라 암괴 틈으로 쏘게 했다. 창줄이 걸리는 순간 권양기가 배를 옆으로 당겼고, 찢어진 부력낭을 임시로 눌러 붙일 시간이 생겼다. 선원들은 수익을 잃었다. 대신 배가 살았다. 그리고 암괴 뒤편에서, 방금 지나친 고래의 등에 박힌 낯선 금속 조각이 다시 햇빛을 받았다."
            ),
            _join_paras(
                "천해의 비는 물이 아니라 물고기로 내렸다. 공어 떼가 갑판을 때리는 동안, 조타수는 항로표를 접고 귀로 바람을 들었다. 지상에서 올라온 병사는 그 소리를 이해하지 못했다. 그의 세계에서 하늘은 비행기의 것이었고, 바다는 배의 것이었다. 이곳에서는 둘 다 틀렸다. 비공선은 천해석과 증기, 선원의 감각 사이에서 겨우 항로를 유지했다.",
                "고래기름 냄새가 기관실로 스며들자 견습 기관사가 기침을 삼켰다. 초기 내연기관은 실험품에 가까웠고, 이 배의 진짜 힘은 여전히 증기와 부력낭에 있었다. 선장은 전쟁 기술을 버리라고 하지 않았다. 다만 그것이 천해의 규칙을 대신할 수 없다는 걸 알고 있었다. 암괴 밀집 구역에서는 통신이 끊기고, 석 간섭은 나침반보다 먼저 사람의 속을 뒤집었다.",
                "고래가 구름 아래로 잠기자 포경창은 허공을 찢었다. 실패였다. 그러나 창줄 끝에 작은 천해석 파편이 걸려 올라왔다. 파편은 부력낭의 찢어진 가장자리에 붙자마자 미세하게 떨었다. 선장은 그 떨림을 보고 항로를 바꾸었다. 고래를 놓친 방향이 아니라, 천해가 방금 열어 보인 길 쪽으로."
            ),
        ]
        return variants[v % len(variants)]

    if pack_id == "ROMANTASY_HOUSE_CONTRACT":
        variants = [
            _join_paras(
                "연회장의 좌석표는 이미 그녀의 패배를 발표하고 있었다. 공작가의 문장이 새겨진 의자는 황태자의 오른편에서 두 자리 밀려나 있었고, 약혼 계약서에 쓰인 봉랍은 아직 따뜻했다. 사람들은 음악에 맞춰 웃었지만, 그 웃음은 누가 먼저 추락하는지 보기 위해 얇게 벌어진 틈에 가까웠다.",
                "그녀는 잔을 들지 않았다. 대신 계약서의 세 번째 조항, 후견권 양도 문장 위에 손끝을 얹었다. 전생의 기억인지 게임의 대사인지 모를 문장이 목 안쪽에서 먼저 올라왔지만, 그녀는 정해진 대사를 삼켰다. 악역영애가 해야 할 비명은 너무 일찍 준비되어 있었다.",
                "황태자가 이름을 부르기 전에 그녀가 먼저 고개를 들었다. 모두가 축배라고 믿은 순간, 그녀는 봉랍을 반으로 갈라 계약서 위에 떨어뜨렸다. 붉은 밀랍이 조항 하나를 완전히 덮었다. 침묵은 모욕보다 빠르게 번졌고, 공작가의 늙은 후견인은 처음으로 웃음을 거두었다."
            ),
            _join_paras(
                "초대장의 봉랍 색이 달랐다. 그 사소한 차이를 알아본 사람은 많지 않았지만, 연회장 문 앞의 시종은 손님 명부를 넘기다 한 박자 늦게 고개를 들었다. 주인공은 그 한 박자만으로도 오늘 밤의 좌석 배치가 누군가의 손에서 바뀌었다는 것을 알았다.",
                "약혼은 사랑의 문제가 아니었다. 가문이 누구의 이름으로 부채를 묶고, 누구의 후견권을 명분으로 궁정에 발을 들일지 정하는 계약이었다. 그녀가 침묵하면 평판은 죽는다. 반박하면 공작가와 황실 사이의 거래가 흔들린다. 어느 쪽이든 누군가는 이 밤을 기다리고 있었다.",
                "그녀는 장갑을 벗어 좌석표 위에 올렸다. 문장 반지가 촛불을 받아 짧게 빛났다. 황녀가 먼저 말을 꺼내기 전, 그녀는 자기 이름이 지워진 줄을 가리켰다. '실수라면 지금 고치시지요.' 낮은 목소리였지만, 그 말은 음악보다 멀리 갔다."
            ),
            _join_paras(
                "응접실의 차는 식지 않았고, 계약서는 이미 식어 있었다. 후견인은 잉크가 마른 문장만 믿었지만, 주인공은 종이 가장자리의 눌린 자국을 보았다. 같은 조항이 한 번 더 쓰였다가 지워진 흔적이었다. 가문 문장이 찍힌 봉랍은 완전했지만, 완전한 봉랍이 언제나 완전한 합의를 뜻하지는 않았다.",
                "상대는 그녀가 악역영애답게 분노하기를 기다렸다. 목소리를 높이면 예의가 무너지고, 침묵하면 권리가 사라진다. 그녀는 그 둘 사이에서 가장 느린 선택을 했다. 계약서를 읽었다. 한 문장씩, 시선이 지겨워질 만큼 천천히.",
                "세 번째 조항에 이르자 방 안의 공기가 바뀌었다. 후견권 양도 조건에 붙은 날짜가 초대장 발송일보다 하루 빨랐다. 그녀는 그 날짜를 손끝으로 눌렀다. '이 계약은 제 동의보다 먼저 태어났군요.' 그제야 상대의 잔받침이 아주 작게 흔들렸다."
            ),
        ]
        return variants[v % len(variants)]

    if pack_id == "CLOSED_CIRCLE_MYSTERY":
        variants = [
            _join_paras(
                "폭풍은 저택의 전화선을 먼저 끊었다. 식당 벽시계가 아홉 시 십칠 분에 멈춘 뒤, 은촛대 옆에 놓인 찻잔 하나만 식지 않은 채 남았다. 손님 여섯은 모두 같은 말을 했다. 자신은 서재에 가지 않았고, 죽은 남작과 마지막으로 다툰 사람은 다른 누군가였다고.",
                "탐정은 시체보다 먼저 의자를 보았다. 의자 다리 하나에 마른 진흙이 묻어 있었고, 창가의 양탄자는 눈에 띄지 않을 만큼 조금 밀려 있었다. 집사는 열쇠가 줄곧 자기 허리춤에 있었다고 맹세했지만, 그 맹세를 할 때마다 오른손 장갑의 단추를 만졌다.",
                "아무도 거짓말 전체를 말하지는 않았다. 다만 각자 진실의 가장 얇은 조각을 접어 숨겼다. 탐정은 식어 가는 찻잔의 손잡이를 돌려놓고, 손님들에게 한 사람씩 같은 질문을 다시 하기로 했다. 이번에는 살해 시각이 아니라, 촛대가 어느 손에 있었는지를 물을 생각이었다."
            ),
            _join_paras(
                "저택의 모든 문은 안에서 잠겨 있었다. 폭풍이 다리를 끊은 뒤라 손님들은 떠날 수도, 새 용의자를 들일 수도 없었다. 그런 밤에 서재에서 사람이 죽었다. 더 이상한 것은 시체가 아니었다. 책상 위 시간표가 모두에게 같은 알리바이를 주고 있다는 사실이었다.",
                "탐정은 열쇠를 찾지 않았다. 열쇠는 너무 쉽게 의심받는다. 대신 난로 옆 젖은 발자국과 창문 아래 마른 먼지를 비교했다. 누군가는 밖에서 들어온 척했고, 누군가는 안에 있었던 척했다. 두 거짓말은 서로 반대 방향으로 움직였지만, 양탄자 끝에서 같은 주름을 만들었다.",
                "하녀가 찻잔을 치우려 하자 탐정이 손을 들었다. 잔의 손잡이는 오른쪽을 향했지만, 죽은 남작은 왼손잡이였다. 손님들 중 그 사실을 아는 사람은 셋. 모르는 척할 이유가 있는 사람은 하나. 탐정은 시간표를 접고, 이번에는 차를 따른 순서를 물었다."
            ),
            _join_paras(
                "만찬이 끝난 뒤 촛불은 여덟 개에서 일곱 개로 줄었다. 아무도 그것을 이상하게 여기지 않았다. 사람들은 죽은 사람의 방과 사라진 열쇠를 보느라, 식당 중앙의 촛대가 한 번 옮겨졌다는 사실을 놓쳤다. 탐정은 그런 종류의 무심함을 좋아했다. 무심한 물건은 사람보다 오래 진실을 기억한다.",
                "용의자들은 모두 완벽한 알리바이를 갖고 있었다. 완벽하다는 점이 문제였다. 폭풍으로 고립된 저택에서 여섯 명이 같은 시간에 서로를 보았다는 진술은 너무 단정했다. 누군가 시간을 맞추었고, 누군가는 그 맞춘 시간을 믿어야만 했다.",
                "탐정은 서재의 창문을 열지 않았다. 대신 창가 바닥의 젖은 자국을 손수건으로 찍었다. 물은 바깥에서 온 것이 아니라, 녹은 얼음의 흔적이었다. 사라진 열쇠보다 먼저 사라진 것은 시간이었다. 그리고 시간을 훔친 사람은 아직 촛대 하나를 제자리에 돌려놓지 못했다."
            ),
        ]
        return variants[v % len(variants)]

    if pack_id == "RETURN_FANTASY":
        variants = [
            _join_paras(
                "날짜가 하루 어긋나 있었다. 주인공은 그 사실을 달력보다 먼저 손목의 상처로 알았다. 첫 번째 삶에서 이 흉터는 처형식 전날 생겼다. 그런데 지금은 같은 상처가 하루 일찍 벌어져 있었다. 과거로 돌아왔다는 확신은 있었지만, 돌아온 과거가 완전히 같은 길이라는 보장은 사라졌다.",
                "그는 복수를 미루었다. 쉬운 복수는 언제나 달콤했고, 첫 번째 삶에서 그 달콤함 때문에 가장 중요한 경고를 놓쳤다. 오래된 편지의 봉투를 뜯자 기억과 다른 문장이 보였다. 죽은 줄 알았던 사람이 보낸 문장이었다. 멸망은 왕궁에서 시작된 것이 아니라, 아무도 읽지 않은 이 편지에서 먼저 고개를 들었다.",
                "주인공은 예정된 결투장으로 가지 않았다. 대신 편지에 적힌 낡은 예배당으로 향했다. 그 선택 하나로 미래의 지도가 접혔다. 뒤에서 누군가 그의 옛 이름을 불렀지만, 그는 돌아보지 않았다. 알고 있던 미래가 흔들리기 시작했다면, 가장 먼저 버려야 할 것은 확신이었다."
            ),
            _join_paras(
                "두 번째 삶의 첫 아침은 너무 조용했다. 멸망을 겪은 사람은 평화를 믿지 못한다. 주인공은 창밖의 새소리보다 복도 끝 발걸음 수를 먼저 세었다. 첫 번째 삶에서는 이 시간에 암살자가 지나갔다. 이번에는 아무도 오지 않았다. 오지 않는다는 사실이 오히려 더 불길했다.",
                "그는 미래 지식을 만능 열쇠처럼 쓰지 않기로 했다. 한 번 실패한 기억은 지도이기도 하지만, 틀린 지도일 수도 있다. 예정된 모욕이 연회에서 사라지자 그는 박수를 받는 대신 의심을 골랐다. 누군가 미래를 앞당겼거나, 그의 회귀 자체가 이미 판을 바꾸었다.",
                "오래된 편지 한 장이 그 의심을 굳혔다. 날짜는 같았지만 서명이 달랐다. 그는 편지를 태우지 않고 품에 넣었다. 첫 번째 삶에서 불태웠던 증거가 두 번째 삶의 첫 무기가 될 수도 있었다. 문밖에서 시종이 연회 준비를 알렸고, 그는 거울 속의 자신에게 처음으로 거짓 미소를 연습했다."
            ),
            _join_paras(
                "파멸은 한 번 겪어도 익숙해지지 않는다. 주인공은 무너진 성벽과 불타던 깃발을 기억했다. 그래서 과거의 첫날로 돌아왔을 때, 그는 울지 않았다. 대신 탁자 위의 동전 위치를 보았다. 기억 속에서는 세 닢이었는데, 지금은 네 닢이었다. 사소한 차이였지만 사소하기 때문에 더 위험했다.",
                "미래를 바꾸려면 큰 사건을 먼저 막아야 한다고 생각했었다. 그러나 첫 번째 삶에서 큰 사건은 언제나 작은 오차가 쌓인 뒤에 터졌다. 그는 예정된 암살자를 기다리지 않고 하인들의 식사 명부를 확인했다. 명부 한 줄이 비어 있었다. 죽어야 할 사람의 이름도, 살아야 할 사람의 이름도 아니었다.",
                "그 빈칸이 새 미래의 입구였다. 주인공은 복수의 이름을 적어 둔 종이를 접었다. 오늘은 누군가를 죽이는 날이 아니라, 누가 기록에서 사라졌는지 찾는 날이었다. 창밖의 종이 울렸고, 그는 첫 번째 삶과 다른 방향으로 문을 열었다."
            ),
        ]
        return variants[v % len(variants)]

    variants = [
        _join_paras(
            "문은 예상보다 조용히 열렸다. 안쪽의 공기는 오래 닫아 둔 장부처럼 눅눅했고, 방 한가운데 놓인 물건 하나가 이 장면의 규칙을 바꾸고 있었다. 주인공은 곧장 손을 뻗지 않았다. 먼저 누가 그것을 보지 못한 척하는지, 누가 이미 잃어버린 것처럼 숨을 삼키는지 세었다.",
            "처음부터 큰 선택은 없었다. 작은 선택만 있었다. 한 걸음 물러날 것인지, 모르는 척 이름을 부를 것인지, 아니면 지금 이 순간부터 모든 계산을 새로 시작할 것인지. 바깥에서는 누군가 문고리를 잡았다. 그 소리는 재촉이 아니라 경고에 가까웠다.",
            "주인공은 대답 대신 손등의 먼지를 털었다. 그리고 아직 아무도 자기 차례라고 말하지 않은 순간에, 가장 위험한 물건을 품 안으로 밀어 넣었다. 뒤늦게 방 안의 시선들이 따라붙었다. 이제 다음 장면의 압력은 문밖이 아니라 그의 품속에서 시작될 것이다."
        ),
        _join_paras(
            "복도 끝의 불빛이 한 번 흔들렸다. 그 흔들림만으로도 주인공은 이곳에 자신보다 먼저 도착한 사람이 있다는 것을 알았다. 바닥에는 발자국 대신 밀린 먼지가 남아 있었고, 닫힌 문 손잡이는 방금 식은 금속처럼 미묘하게 따뜻했다.",
            "그는 이름을 부르지 않았다. 이름은 사람을 움직이지만, 때로는 숨어 있는 사람에게 시간을 준다. 대신 문틈 아래로 밀려 나온 종이 조각을 주웠다. 조각에는 목적지가 아니라 비용이 적혀 있었다. 누군가 이 방을 열기 전에 이미 대가를 계산해 둔 것이다.",
            "문 너머에서 낮은 숨소리가 들렸다. 주인공은 종이 조각을 접어 손바닥 안에 숨겼다. 이 방에 들어가면 답을 얻을 수 있다. 그러나 답을 얻는 순간, 자신도 누군가의 계산 속에 들어간다. 그는 문을 열었다."
        ),
        _join_paras(
            "비는 창문을 때리지 않고 벽을 타고 흘렀다. 이상한 방향의 빗물은 이 장소가 정상적인 규칙 위에 놓여 있지 않다는 첫 번째 증거였다. 주인공은 젖은 자국을 손끝으로 문지른 뒤 냄새를 맡았다. 물이 아니라 오래된 약품 냄새가 났다.",
            "방 안의 사람들은 각자 다른 이유로 침묵했다. 누군가는 두려워했고, 누군가는 계산했고, 누군가는 이미 답을 알고 있어서 말하지 않았다. 주인공은 그 침묵 사이에서 가장 작은 물건을 골랐다. 탁자 밑에 떨어진 낡은 단추 하나였다.",
            "단추는 문을 열 열쇠가 아니었다. 하지만 누가 거짓말을 했는지 알려 줄 수는 있었다. 주인공은 단추를 주머니에 넣고, 모두가 보고 있는 큰 문이 아니라 아무도 신경 쓰지 않은 작은 서랍을 열었다. 그 안에서 다음 선택의 비용이 모습을 드러냈다."
        ),
    ]
    return variants[v % len(variants)]

# AF1K R7 runtime/cache state.
if "R7_RUNTIME_STATS" not in globals():
    R7_RUNTIME_STATS = Counter()
if "R7_RESULT_CACHE" not in globals():
    R7_RESULT_CACHE = {}
if "R7_INITIAL_RAW_CACHE" not in globals():
    R7_INITIAL_RAW_CACHE = {}
if "R7_CACHE_PHASE" not in globals():
    R7_CACHE_PHASE = "pre_handler"

def r7_normalize_input(user_input):
    s = str(user_input or "")
    if globals().get("R7_CACHE_NORMALIZE_INPUT", True):
        s = re.sub(r"\s+", " ", s).strip()
    return s

def r7_short_hash(obj, n=16):
    try:
        payload = json.dumps(obj, ensure_ascii=False, sort_keys=True, default=str)
    except Exception:
        payload = str(obj)
    return hashlib.sha256(payload.encode("utf-8")).hexdigest()[:n]

def r7_runtime_fingerprint(pack=None, prompt=None):
    """Strict cache fingerprint.

    Same user input should use cache only when pack/prompt/runtime settings match.
    This prevents stale cache reuse after changing handler/generation/adapter settings.
    """
    adapter_sha = None
    try:
        adapter_sha = (globals().get("ADAPTER_AUDIT") or {}).get("adapter_sha256")
    except Exception:
        adapter_sha = None

    pack_id = None
    if isinstance(pack, dict):
        pack_id = pack.get("pack_id") or pack.get("selected_pack_id") or pack.get("id")

    prompt_hash = None
    if globals().get("R7_CACHE_INCLUDE_PROMPT_HASH", True) and prompt is not None:
        prompt_hash = r7_short_hash(prompt, 20)

    payload = {
        "version": globals().get("VERSION", None),
        "phase": globals().get("R7_CACHE_PHASE", "pre_handler"),
        "base_model": globals().get("BASE_MODEL_ID", None),
        "adapter_sha256": adapter_sha,
        "pack_schema": globals().get("PACK_SCHEMA_VERSION", None),
        "pack_id": pack_id,
        "prompt_hash": prompt_hash,
        "max_new_tokens": globals().get("MAX_NEW_TOKENS", None),
        "temperature": globals().get("TEMPERATURE", None),
        "top_p": globals().get("TOP_P", None),
        "repetition_penalty": globals().get("REPETITION_PENALTY", None),
        "model_cont_rounds": globals().get("MODEL_CONTINUATION_MAX_ROUNDS", None),
        "model_cont_tokens": globals().get("MODEL_CONTINUATION_MAX_NEW_TOKENS", None),
        "quality_scanner": globals().get("QUALITY_SCANNER_VERSION", None),
        "repair_rounds": globals().get("QUALITY_ONLY_REPAIR_MAX_ROUNDS", None),
    }
    if not globals().get("R7_CACHE_INCLUDE_RUNTIME_FINGERPRINT", True):
        payload = {
            "phase": payload["phase"],
            "pack_id": payload["pack_id"],
            "prompt_hash": payload["prompt_hash"],
        }
    return r7_short_hash(payload, 20), payload

def r7_cache_key(user_input, pack=None, prompt=None, phase=None):
    phase = phase or globals().get("R7_CACHE_PHASE", "pre_handler")
    norm_input = r7_normalize_input(user_input)
    if not globals().get("R7_STRICT_CACHE_KEY", True):
        return phase + "::" + norm_input
    fp, _payload = r7_runtime_fingerprint(pack=pack, prompt=prompt)
    input_hash = r7_short_hash(norm_input, 20)
    pack_id = "UNKNOWN"
    if isinstance(pack, dict):
        pack_id = pack.get("pack_id") or pack.get("selected_pack_id") or pack.get("id") or "UNKNOWN"
    return f"{phase}::input={input_hash}::pack={pack_id}::fp={fp}"

# AF1K R8: caches for GPU-generated raw text and continuations.
if "R8_RAW_GENERATION_CACHE" not in globals():
    R8_RAW_GENERATION_CACHE = {}
if "R8_CONTINUATION_CACHE" not in globals():
    R8_CONTINUATION_CACHE = {}

def r8_raw_generation_fingerprint(pack=None, prompt=None):
    adapter_sha = None
    try:
        adapter_sha = (globals().get("ADAPTER_AUDIT") or {}).get("adapter_sha256")
    except Exception:
        adapter_sha = None
    pack_id = None
    if isinstance(pack, dict):
        pack_id = pack.get("pack_id") or pack.get("selected_pack_id") or pack.get("id")
    payload = {
        "base_model": globals().get("BASE_MODEL_ID", None),
        "adapter_sha256": adapter_sha,
        "pack_schema": globals().get("PACK_SCHEMA_VERSION", None),
        "pack_id": pack_id,
        "prompt_hash": r7_short_hash(prompt, 20) if prompt is not None else None,
        "max_new_tokens": globals().get("MAX_NEW_TOKENS", None),
        "temperature": globals().get("TEMPERATURE", None),
        "top_p": globals().get("TOP_P", None),
        "repetition_penalty": globals().get("REPETITION_PENALTY", None),
    }
    return r7_short_hash(payload, 20), payload

def r8_raw_cache_key(user_input, pack=None, prompt=None):
    norm_input = r7_normalize_input(user_input)
    input_hash = r7_short_hash(norm_input, 20)
    pack_id = "UNKNOWN"
    if isinstance(pack, dict):
        pack_id = pack.get("pack_id") or pack.get("selected_pack_id") or pack.get("id") or "UNKNOWN"
    fp, _payload = r8_raw_generation_fingerprint(pack=pack, prompt=prompt)
    return f"raw::input={input_hash}::pack={pack_id}::fp={fp}"

def r8_continuation_fingerprint(pack=None, current_text="", reason="minlen"):
    adapter_sha = None
    try:
        adapter_sha = (globals().get("ADAPTER_AUDIT") or {}).get("adapter_sha256")
    except Exception:
        adapter_sha = None
    pack_id = pack.get("pack_id", "GENERAL_WEBNOVEL") if isinstance(pack, dict) else "GENERAL_WEBNOVEL"
    text_tail = re.sub(r"\s+", " ", current_text or "").strip()[-int(globals().get("R7_CONTINUATION_CONTEXT_CHARS", 1200)):]
    payload = {
        "base_model": globals().get("BASE_MODEL_ID", None),
        "adapter_sha256": adapter_sha,
        "pack_id": pack_id,
        "source_user_input": r7_normalize_input(pack.get("source_user_input", "")) if isinstance(pack, dict) else "",
        "current_text_tail_hash": r7_short_hash(text_tail, 20),
        "reason": None if globals().get("R8_CONTINUATION_CACHE_IGNORE_REASON", True) else reason,
        "max_new_tokens": globals().get("MODEL_CONTINUATION_MAX_NEW_TOKENS", None),
        "temperature": globals().get("MODEL_CONTINUATION_TEMPERATURE", None),
        "top_p": globals().get("MODEL_CONTINUATION_TOP_P", None),
        "repetition_penalty": max(globals().get("REPETITION_PENALTY", 1.1), 1.12),
    }
    return r7_short_hash(payload, 20), payload

def r8_continuation_cache_key(current_text, pack, reason="minlen"):
    fp, _payload = r8_continuation_fingerprint(pack=pack, current_text=current_text, reason=reason)
    pack_id = pack.get("pack_id", "GENERAL_WEBNOVEL") if isinstance(pack, dict) else "GENERAL_WEBNOVEL"
    return f"cont::pack={pack_id}::fp={fp}"

# AF1K R9: final-result cache for exact duplicate validation inputs.
if "R9_FINAL_RESULT_CACHE" not in globals():
    R9_FINAL_RESULT_CACHE = {}

def r9_final_result_fingerprint(pack=None, prompt=None):
    """Fast validation fingerprint.

    Unlike strict final cache, this deliberately ignores handler/repair phase
    by default so duplicate validation inputs can reuse the final result as
    cached validation data. Disable R9_ENABLE_SHARED_FINAL_RESULT_CACHE for
    faithful stochastic audits.
    """
    adapter_sha = None
    try:
        adapter_sha = (globals().get("ADAPTER_AUDIT") or {}).get("adapter_sha256")
    except Exception:
        adapter_sha = None
    pack_id = None
    if isinstance(pack, dict):
        pack_id = pack.get("pack_id") or pack.get("selected_pack_id") or pack.get("id")
    payload = {
        "policy": "R9_SHARED_FINAL_RESULT_CACHE_V1",
        "phase": None if globals().get("R9_FINAL_CACHE_IGNORE_PHASE", True) else globals().get("R7_CACHE_PHASE", "pre_handler"),
        "base_model": globals().get("BASE_MODEL_ID", None),
        "adapter_sha256": adapter_sha,
        "pack_schema": globals().get("PACK_SCHEMA_VERSION", None),
        "pack_id": pack_id,
        "prompt_hash": r7_short_hash(prompt, 20) if (prompt is not None and globals().get("R9_FINAL_CACHE_INCLUDE_PROMPT_HASH", True)) else None,
        "max_new_tokens": globals().get("MAX_NEW_TOKENS", None),
        "temperature": globals().get("TEMPERATURE", None),
        "top_p": globals().get("TOP_P", None),
        "repetition_penalty": globals().get("REPETITION_PENALTY", None),
        "model_cont_rounds": globals().get("MODEL_CONTINUATION_MAX_ROUNDS", None),
        "model_cont_tokens": globals().get("MODEL_CONTINUATION_MAX_NEW_TOKENS", None),
        # Handler/gate settings intentionally optional for speed.
        "quality_scanner": None if globals().get("R9_FINAL_CACHE_IGNORE_HANDLER_SETTINGS", True) else globals().get("QUALITY_SCANNER_VERSION", None),
        "repair_rounds": None if globals().get("R9_FINAL_CACHE_IGNORE_HANDLER_SETTINGS", True) else globals().get("QUALITY_ONLY_REPAIR_MAX_ROUNDS", None),
    }
    return r7_short_hash(payload, 20), payload

def r9_final_cache_key(user_input, pack=None, prompt=None):
    norm_input = r7_normalize_input(user_input)
    input_hash = r7_short_hash(norm_input, 20)
    pack_id = "UNKNOWN"
    if isinstance(pack, dict):
        pack_id = pack.get("pack_id") or pack.get("selected_pack_id") or pack.get("id") or "UNKNOWN"
    fp, _payload = r9_final_result_fingerprint(pack=pack, prompt=prompt)
    return f"r9final::input={input_hash}::pack={pack_id}::fp={fp}"

def r9_clone_final_cached_result(result, user_input, cache_key=None):
    import copy
    out = copy.deepcopy(result)
    out["input"] = user_input
    out["used_cache"] = True
    out["used_r9_final_result_cache"] = True
    out["r9_final_cache_key_reused"] = cache_key or out.get("r9_final_cache_key")
    out["r7_cache_phase"] = globals().get("R7_CACHE_PHASE", "pre_handler")
    out["r7_cache_note"] = "R9 duplicate-input final result cache; GPU generation and repair loop skipped."
    out["runtime_seconds"] = 0.0
    return out

def r7_reset_runtime_caches(phase=None, clear_result=False, clear_initial=True, clear_shared_raw=False, clear_continuation=False, clear_r9_final=False):
    global R7_CACHE_PHASE, R7_INITIAL_RAW_CACHE, R7_RESULT_CACHE, R8_RAW_GENERATION_CACHE, R8_CONTINUATION_CACHE, R9_FINAL_RESULT_CACHE
    if phase is not None:
        R7_CACHE_PHASE = phase
    if clear_initial:
        R7_INITIAL_RAW_CACHE = {}
    if clear_result:
        R7_RESULT_CACHE = {}
    if clear_shared_raw:
        R8_RAW_GENERATION_CACHE = {}
    if clear_continuation:
        R8_CONTINUATION_CACHE = {}
    if clear_r9_final:
        R9_FINAL_RESULT_CACHE = {}
    print(
        f"R7/R8 cache phase={R7_CACHE_PHASE}, "
        f"result_cache={len(R7_RESULT_CACHE)}, initial_cache={len(R7_INITIAL_RAW_CACHE)}, "
        f"raw_cache={len(globals().get('R8_RAW_GENERATION_CACHE', {}))}, "
        f"cont_cache={len(globals().get('R8_CONTINUATION_CACHE', {}))}, "
        f"r9_final_cache={len(globals().get('R9_FINAL_RESULT_CACHE', {}))}"
    )

def r7_clone_cached_result(result, user_input):
    import copy, time
    out = copy.deepcopy(result)
    out["input"] = user_input
    out["used_cache"] = True
    out["r7_cache_key_reused"] = out.get("r7_cache_key")
    out["r7_cache_phase"] = globals().get("R7_CACHE_PHASE", "pre_handler")
    out["r7_cache_note"] = "Exact-input cached validation row; GPU generation skipped."
    out["runtime_seconds"] = 0.0
    return out

def _r7_build_body_model_input(prompt):
    messages = [
        {"role": "system", "content": "너는 한국어 웹소설 본문 생성 엔진이다. 최종 출력은 본문만 제공한다."},
        {"role": "user", "content": prompt},
    ]
    if hasattr(tokenizer, "apply_chat_template"):
        return tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    return "System: " + messages[0]["content"] + "\nUser: " + messages[1]["content"] + "\nAssistant:"

def r7_batch_generate_model_inputs(model_inputs, max_new_tokens, temperature, top_p, repetition_penalty, batch_size=None):
    if DRY_RUN_WITH_DETERMINISTIC_TEXT:
        return [""] * len(model_inputs)
    import torch
    outs = []
    if batch_size is None:
        batch_size = int(globals().get("R7_BATCH_SIZE", 8))
    if tokenizer.pad_token_id is None:
        tokenizer.pad_token = tokenizer.eos_token
    old_padding_side = getattr(tokenizer, "padding_side", "right")
    tokenizer.padding_side = globals().get("R7_BATCH_PADDING_SIDE", "left")

    for start in range(0, len(model_inputs), batch_size):
        batch = model_inputs[start:start + batch_size]
        inputs = tokenizer(batch, return_tensors="pt", padding=True, truncation=False).to(model.device)
        ctx = torch.inference_mode() if globals().get("R7_USE_TORCH_INFERENCE_MODE", True) else torch.no_grad()
        with ctx:
            output = model.generate(
                **inputs,
                max_new_tokens=max_new_tokens,
                do_sample=True,
                temperature=temperature,
                top_p=top_p,
                repetition_penalty=repetition_penalty,
                pad_token_id=tokenizer.eos_token_id,
                use_cache=True,
            )
        prompt_len = inputs["input_ids"].shape[-1]
        for row in output:
            gen_ids = row[prompt_len:]
            outs.append(tokenizer.decode(gen_ids, skip_special_tokens=True).strip())
    tokenizer.padding_side = old_padding_side
    return outs

def batch_generate_body(prompts, packs, batch_size=None):
    if DRY_RUN_WITH_DETERMINISTIC_TEXT:
        return [deterministic_body(p) for p in packs]
    model_inputs = [_r7_build_body_model_input(prompt) for prompt in prompts]
    return r7_batch_generate_model_inputs(
        model_inputs,
        max_new_tokens=MAX_NEW_TOKENS,
        temperature=TEMPERATURE,
        top_p=TOP_P,
        repetition_penalty=REPETITION_PENALTY,
        batch_size=batch_size,
    )

def generate_body(prompt, pack):
    if DRY_RUN_WITH_DETERMINISTIC_TEXT:
        return deterministic_body(pack)

    import torch
    messages = [
        {"role": "system", "content": "너는 한국어 웹소설 본문 생성 엔진이다. 최종 출력은 본문만 제공한다."},
        {"role": "user", "content": prompt},
    ]
    if hasattr(tokenizer, "apply_chat_template"):
        model_input = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    else:
        model_input = "System: " + messages[0]["content"] + "\nUser: " + messages[1]["content"] + "\nAssistant:"

    inputs = tokenizer(model_input, return_tensors="pt").to(model.device)
    with (torch.inference_mode() if globals().get("R7_USE_TORCH_INFERENCE_MODE", True) else torch.no_grad()):
        output = model.generate(
            **inputs,
            max_new_tokens=MAX_NEW_TOKENS,
            do_sample=True,
            temperature=TEMPERATURE,
            top_p=TOP_P,
            repetition_penalty=REPETITION_PENALTY,
            pad_token_id=tokenizer.eos_token_id,
            use_cache=True,
        )
    gen_ids = output[0][inputs["input_ids"].shape[-1]:]
    return tokenizer.decode(gen_ids, skip_special_tokens=True).strip()

def generate_continuation(current_text, pack, reason="minlen"):
    """AF1J/R8: model-generated continuation for natural length recovery.

    R8 adds an optional continuation cache keyed by current-text tail and
    continuation generation settings. This targets repeated pre/post-handler
    validation cases where the same raw text needs the same continuation.
    """
    if DRY_RUN_WITH_DETERMINISTIC_TEXT:
        return ""

    if globals().get("R8_ENABLE_CONTINUATION_CACHE", True) and "r8_continuation_cache_key" in globals():
        ckey = r8_continuation_cache_key(current_text, pack, reason=reason)
        if ckey in globals().get("R8_CONTINUATION_CACHE", {}):
            if "R7_RUNTIME_STATS" in globals():
                R7_RUNTIME_STATS["continuation_cache_hits"] += 1
            return R8_CONTINUATION_CACHE[ckey]
    else:
        ckey = None

    import torch
    pack_id = pack.get("pack_id", "GENERAL_WEBNOVEL")
    min_chars = MIN_FINAL_CHARS_BY_PACK.get(pack_id, 500) if "MIN_FINAL_CHARS_BY_PACK" in globals() else 500
    remaining = max(120, min_chars - len(current_text or ""))

    system = (
        "너는 한국어 웹소설 본문 continuation 엔진이다. "
        "출력은 이어지는 본문만 작성한다. 요약/해설/목록/프롬프트 반복 금지."
    )
    r13_return_extra = ""
    if pack_id == "RETURN_FANTASY" and globals().get("R13_ENABLE_RETURN_FOCUS_REPAIR", True):
        r13_return_extra = """
- RETURN_FANTASY continuation: 회귀/첫 번째 삶/두 번째 삶/미래 오차/파멸 기억 중 하나를 이어받는다.
- 소재가 연회/찻잔/계약이어도 장면 중심은 기억과 현재의 차이, 그리고 선택 비용이어야 한다.
- 다른 장르의 탐정식 추리 결론이나 후견 계약물 중심으로 흐르지 않는다.
""".strip()

    user = f"""
[PACK]
{pack_id}

[USER_INPUT]
{pack.get("source_user_input", "")}

[CURRENT_TEXT]
{(current_text or "").strip()[-int(globals().get("R7_CONTINUATION_CONTEXT_CHARS", 1200)):]}

[CONTINUE_INSTRUCTIONS]
- 위 본문 바로 뒤에 자연스럽게 이어지는 문단만 작성.
- 같은 첫 문장/같은 시작 패턴 반복 금지.
- 새 사건 진행, 물성 변화, 인물 선택 중 최소 1개를 추가.
- 남은 길이 부족분은 약 {remaining}자 이상.
- 장르 규칙을 지키고 금지 표면어/프롬프트 잔여물 금지.
{r13_return_extra}
"""

    messages = [
        {"role": "system", "content": system},
        {"role": "user", "content": user.strip()},
    ]

    if hasattr(tokenizer, "apply_chat_template"):
        model_input = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    else:
        model_input = "System: " + messages[0]["content"] + "\nUser: " + messages[1]["content"] + "\nAssistant:"

    inputs = tokenizer(model_input, return_tensors="pt").to(model.device)
    with (torch.inference_mode() if globals().get("R7_USE_TORCH_INFERENCE_MODE", True) else torch.no_grad()):
        output = model.generate(
            **inputs,
            max_new_tokens=MODEL_CONTINUATION_MAX_NEW_TOKENS,
            do_sample=True,
            temperature=MODEL_CONTINUATION_TEMPERATURE,
            top_p=MODEL_CONTINUATION_TOP_P,
            repetition_penalty=max(REPETITION_PENALTY, 1.12),
            pad_token_id=tokenizer.eos_token_id,
            use_cache=True,
        )
    gen_ids = output[0][inputs["input_ids"].shape[-1]:]
    cont = tokenizer.decode(gen_ids, skip_special_tokens=True).strip()

    # Strip common continuation boilerplate if model echoes.
    cont = re.sub(r"^(이어지는\s*본문[:：]?|본문[:：]?|Assistant[:：]?)\s*", "", cont).strip()
    if globals().get("R8_ENABLE_CONTINUATION_CACHE", True) and ckey:
        if "R8_CONTINUATION_CACHE" not in globals():
            globals()["R8_CONTINUATION_CACHE"] = {}
        R8_CONTINUATION_CACHE[ckey] = cont
        if "R7_RUNTIME_STATS" in globals():
            R7_RUNTIME_STATS["continuation_cache_stores"] += 1
    return cont

# %%
#@title 10. V146BQ gate / AF1C Tower lore scanner / salvage repair / fallback
from collections import Counter, defaultdict
import json
import re
import hashlib

# Defensive defaults for rerunning this cell directly.
QUALITY_SCANNER_VERSION = "AF1K_R5_REPAIR_RECALIBRATE"

if "ENABLE_R5_MIXED_HIT_REPAIR" not in globals():
    ENABLE_R5_MIXED_HIT_REPAIR = True
if "R5_TOTAL_REPAIR_MAX_ROUNDS" not in globals():
    R5_TOTAL_REPAIR_MAX_ROUNDS = 4
if "R5_SURFACE_LORE_REPAIR_MAX_ROUNDS" not in globals():
    R5_SURFACE_LORE_REPAIR_MAX_ROUNDS = 2
if "R5_REPEATED_SENTENCE_KEEP_FIRST" not in globals():
    R5_REPEATED_SENTENCE_KEEP_FIRST = True
if "R5_TOWER_ANCHOR_DENSITY_REPAIR" not in globals():
    R5_TOWER_ANCHOR_DENSITY_REPAIR = True

if "MIN_FINAL_CHARS_BY_PACK" not in globals():
    MIN_FINAL_CHARS_BY_PACK = {
        "TOWER_SYSTEM_RULE": 700,
        "AETHER_WHALERS": 600,
        "ROMANTASY_HOUSE_CONTRACT": 600,
        "CLOSED_CIRCLE_MYSTERY": 600,
        "RETURN_FANTASY": 600,
        "GENERAL_WEBNOVEL": 500,
    }
if "MAX_ATTEMPTS" not in globals():
    MAX_ATTEMPTS = 2

if "ENABLE_MINLEN_ENFORCER" not in globals():
    ENABLE_MINLEN_ENFORCER = True
if "MINLEN_EXTENSION_MAX_ROUNDS" not in globals():
    MINLEN_EXTENSION_MAX_ROUNDS = 4
if "MINLEN_TARGET_MARGIN_CHARS" not in globals():
    MINLEN_TARGET_MARGIN_CHARS = 60
if "R16_TOWER_MINLEN_TARGET_MARGIN" not in globals():
    R16_TOWER_MINLEN_TARGET_MARGIN = 70
if "MINLEN_EXTEND_BEFORE_FALLBACK" not in globals():
    MINLEN_EXTEND_BEFORE_FALLBACK = True
if "MINLEN_EXTEND_AFTER_FALLBACK" not in globals():
    MINLEN_EXTEND_AFTER_FALLBACK = True

if "ENABLE_MODEL_CONTINUATION_FOR_MINLEN" not in globals():
    ENABLE_MODEL_CONTINUATION_FOR_MINLEN = True
if "MODEL_CONTINUATION_MAX_ROUNDS" not in globals():
    MODEL_CONTINUATION_MAX_ROUNDS = 2
if "MODEL_CONTINUATION_MAX_NEW_TOKENS" not in globals():
    MODEL_CONTINUATION_MAX_NEW_TOKENS = 260
if "MODEL_CONTINUATION_TEMPERATURE" not in globals():
    MODEL_CONTINUATION_TEMPERATURE = 0.82
if "MODEL_CONTINUATION_TOP_P" not in globals():
    MODEL_CONTINUATION_TOP_P = 0.92
if "ALLOW_DETERMINISTIC_MINLEN_EXTENSION" not in globals():
    ALLOW_DETERMINISTIC_MINLEN_EXTENSION = True
if "DETERMINISTIC_MINLEN_ONLY_AFTER_MODEL_CONTINUATION" not in globals():
    DETERMINISTIC_MINLEN_ONLY_AFTER_MODEL_CONTINUATION = True
if "ENABLE_NATURAL_RETRY_BEFORE_FALLBACK" not in globals():
    ENABLE_NATURAL_RETRY_BEFORE_FALLBACK = True
if "ENABLE_DUPLICATE_PREFIX_GUARD" not in globals():
    ENABLE_DUPLICATE_PREFIX_GUARD = True
if "DUPLICATE_PREFIX_CHARS" not in globals():
    DUPLICATE_PREFIX_CHARS = 180
if "DUPLICATE_PREFIX_MAX_SEEN" not in globals():
    DUPLICATE_PREFIX_MAX_SEEN = 1
if "DUPLICATE_PREFIX_REPAIR_MAX_ROUNDS" not in globals():
    DUPLICATE_PREFIX_REPAIR_MAX_ROUNDS = 2
if "SEEN_FINAL_PREFIXES" not in globals():
    SEEN_FINAL_PREFIXES = Counter()


if "OUTPUT_LENGTH_PRESET" not in globals():
    OUTPUT_LENGTH_PRESET = "standard"
if "LENGTH_PRESETS" not in globals():
    LENGTH_PRESETS = {
        "short": {
            "TOWER_SYSTEM_RULE": 520,
            "AETHER_WHALERS": 460,
            "ROMANTASY_HOUSE_CONTRACT": 440,
            "CLOSED_CIRCLE_MYSTERY": 440,
            "RETURN_FANTASY": 440,
            "GENERAL_WEBNOVEL": 420,
        },
        "standard": {
            "TOWER_SYSTEM_RULE": 700,
            "AETHER_WHALERS": 600,
            "ROMANTASY_HOUSE_CONTRACT": 600,
            "CLOSED_CIRCLE_MYSTERY": 600,
            "RETURN_FANTASY": 600,
            "GENERAL_WEBNOVEL": 500,
        },
        "long": {
            "TOWER_SYSTEM_RULE": 950,
            "AETHER_WHALERS": 850,
            "ROMANTASY_HOUSE_CONTRACT": 850,
            "CLOSED_CIRCLE_MYSTERY": 850,
            "RETURN_FANTASY": 850,
            "GENERAL_WEBNOVEL": 750,
        },
    }
if "CUSTOM_MIN_FINAL_CHARS_BY_PACK" not in globals():
    CUSTOM_MIN_FINAL_CHARS_BY_PACK = {
        "TOWER_SYSTEM_RULE": 700,
        "AETHER_WHALERS": 600,
        "ROMANTASY_HOUSE_CONTRACT": 600,
        "CLOSED_CIRCLE_MYSTERY": 600,
        "RETURN_FANTASY": 600,
        "GENERAL_WEBNOVEL": 500,
    }
if "apply_length_preset" not in globals():
    def apply_length_preset():
        global MIN_FINAL_CHARS_BY_PACK
        if globals().get("OUTPUT_LENGTH_PRESET", "standard") == "custom":
            MIN_FINAL_CHARS_BY_PACK = dict(globals().get("CUSTOM_MIN_FINAL_CHARS_BY_PACK", {}))
        else:
            presets = globals().get("LENGTH_PRESETS", {})
            MIN_FINAL_CHARS_BY_PACK = dict(presets.get(globals().get("OUTPUT_LENGTH_PRESET", "standard"), presets.get("standard", {})))
        return MIN_FINAL_CHARS_BY_PACK
if "MIN_FINAL_CHARS_BY_PACK" not in globals() or not MIN_FINAL_CHARS_BY_PACK:
    MIN_FINAL_CHARS_BY_PACK = apply_length_preset()

if "ENABLE_QUALITY_LIGHT_REPAIR" not in globals():
    ENABLE_QUALITY_LIGHT_REPAIR = True
if "QUALITY_ONLY_REPAIR_MAX_ROUNDS" not in globals():
    QUALITY_ONLY_REPAIR_MAX_ROUNDS = 2
if "REPEATED_PHRASE_DEFAULT_LIMIT" not in globals():
    REPEATED_PHRASE_DEFAULT_LIMIT = 4
if "REPEATED_PHRASE_LIMIT_BY_PACK" not in globals():
    REPEATED_PHRASE_LIMIT_BY_PACK = {
        "TOWER_SYSTEM_RULE": {"보상함": 5, "보상": 8}
    }


if "QUALITY_GATE_ENABLE" not in globals():
    QUALITY_GATE_ENABLE = True
if "MAX_REPEATED_SENTENCE_COUNT" not in globals():
    MAX_REPEATED_SENTENCE_COUNT = 1
if "MAX_REPEATED_PHRASE_COUNT" not in globals():
    MAX_REPEATED_PHRASE_COUNT = 3


PROMPT_RESIDUE_PATTERNS = [
    r"(?i)\bHuman\s*:",
    r"(?i)\bAssistant\s*:",
    r"(?i)\bSystem\s*:",
    r"(?i)\bUser\s*:",
    r"<\|im_start\|>",
    r"<\|im_end\|>",
    r"```",
    r"(?i)<xml",
    r"</\w+>",
    r"(?m)^\s*\{.*\}\s*$",
]
FOREIGN_OR_CODE_PATTERNS = [
    r"[\u4e00-\u9fff]{4,}",
    r"(?i)\bSELECT\b.+\bFROM\b",
    r"(?i)\bimport\s+\w+",
    r"(?i)\bdef\s+\w+\(",
    r"(?i)\bclass\s+\w+",
]

TOWER_FORBIDDEN_PATTERNS = [
    ("TOWER_RED_RESIDUE", r"붉은\s*(잉크|선|글씨|문장|표식)"),
    ("TOWER_DIRECT_REQUEST", r"탑[이은는가]*\s*(의뢰|퀘스트|임무)를?\s*(냈|내렸|발급|제시|부여)"),
    ("TOWER_INTERNAL_REQUEST_SHEET", r"(탑\s*내부|층\s*안|복도|문앞|문 앞).{0,20}(의뢰지|의뢰서|기한표)"),
    ("TOWER_MERCHANT_TICKET", r"(상인|상점|노점).{0,20}(입장권|통행권|통행증|탑\s*입장)"),
    ("TOWER_CASTLE_KEY_BLEED", r"(성문\s*열쇠|성문|왕성\s*열쇠|성채\s*열쇠)"),
    ("TOWER_STATUS_UI_COMBAT_ON", r"(보스전|전투|검격|피격|공격).{0,45}(상태창을\s*(켜|열|띄)|스탯창을\s*(켜|열|띄))"),
]

TOWER_REQUIRED_SOFT_SIGNALS = [
    "협회", "길드", "공시", "최고층", "갱신", "재입장", "통행증", "보상함", "공략 기록", "상태창 차단"
]

def repetition_run(text):
    chars = re.findall(r"[가-힣A-Za-z0-9]", text or "")
    best = 0
    cur = 0
    prev = None
    for ch in chars:
        if ch == prev:
            cur += 1
        else:
            cur = 1
            prev = ch
        best = max(best, cur)
    return best

def scan_surface(text):
    hits = []
    for pat in PROMPT_RESIDUE_PATTERNS:
        if re.search(pat, text or ""):
            hits.append("PROMPT_RESIDUE:" + pat)
    for pat in FOREIGN_OR_CODE_PATTERNS:
        if re.search(pat, text or ""):
            hits.append("FOREIGN_OR_CODE:" + pat)
    if "\ufffd" in (text or ""):
        hits.append("BROKEN_CHAR")
    if repetition_run(text) >= 8:
        hits.append("REPETITION_RUN")
    return hits

def scan_tower_lore(text):
    s = text or ""
    hits = []
    for code, pat in TOWER_FORBIDDEN_PATTERNS:
        if re.search(pat, s):
            hits.append(code)

    # If deadline pressure exists, highest-floor renewal must be visible.
    has_deadline = any(w in s for w in ["기한", "마감", "시한", "갱신 기한"])
    has_highest_floor = any(w in s for w in ["최고층", "최고 공략층", "최고 기록", "상층으로 갈수록", "상층"])
    if has_deadline and not has_highest_floor:
        hits.append("TOWER_DEADLINE_WITHOUT_HIGHEST_FLOOR_RENEWAL")

    # If entry/ticket appears, guild/association should be the issuer, not an undefined market object.
    has_ticket = any(w in s for w in ["입장권", "통행권", "통행증"])
    has_issuer = any(w in s for w in ["협회", "길드", "접수대", "발급", "공시"])
    if has_ticket and not has_issuer:
        hits.append("TOWER_ENTRY_PERMIT_WITHOUT_GUILD_OR_ASSOCIATION")

    # A Tower scene should anchor at least one corrected material signal.
    soft_count = sum(1 for w in TOWER_REQUIRED_SOFT_SIGNALS if w in s)
    if soft_count == 0:
        hits.append("TOWER_MISSING_CORRECTED_MATERIAL_ANCHOR")

    return hits


def split_korean_sentences(text):
    s = re.sub(r"\s+", " ", text or "").strip()
    if not s:
        return []
    parts = re.split(r"(?<=[.!?。！？다요죠까니다했다였다었다])\s+", s)
    return [p.strip() for p in parts if len(p.strip()) >= 18]


def _repeated_phrase_limit(pack_id, phrase):
    limits = globals().get("REPEATED_PHRASE_LIMIT_BY_PACK", {})
    return limits.get(pack_id, {}).get(phrase, globals().get("REPEATED_PHRASE_DEFAULT_LIMIT", 4))

def scan_quality_issues(text, pack=None):
    """AF1K_R4 quality scanner.

    Focus:
    - obvious josa/grammar residue
    - duplicated noun tokens
    - repeated long subject/anchor phrases
    - Tower-specific dungeon/castle bleed
    - semantic glitch phrases seen in naturalized continuation
    """
    if not globals().get("QUALITY_GATE_ENABLE", True):
        return []
    s = text or ""
    hits = []
    pack_id = (pack or {}).get("pack_id", "GENERAL_WEBNOVEL")

    # 1) Grammar/josa residue.
    grammar_bad = [
        ("GRAMMAR_JOSA_MARKER_I", r"(표시|문구|도장|기록|공시|통행증)이이\b"),
        ("GRAMMAR_DOUBLE_PARTICLE", r"(은는|이가|을를|과와|으로로|에에)\b"),
        ("GRAMMAR_BAD_EUL_FOR_VOWEL_NOUN", r"(표시|문구|공시|차이|계획|기회|위치|단서|기록표|갱신표)을\b"),
        ("GRAMMAR_BAD_EUN_FOR_VOWEL_NOUN", r"(표시|문구|공시|차이|계획|기회|위치|단서|기록표|갱신표)은\b"),
        ("GRAMMAR_AWKWARD_HIGHEST_TABLE", r"공략\s*최고층\s*갱신표의\s*갱신"),
        ("GRAMMAR_MISSING_SUBJECT_PARTICLE", r"차이\s+어떤\s+결과"),
    ]
    for code, pat in grammar_bad:
        if re.search(pat, s):
            hits.append(code)

    # 2) Exact weird phrase collisions. These are not style choices.
    odd_phrases = {
        "ODD_PHRASE:문제는_샘이": r"문제는\s+샘이",
        "ODD_PHRASE:안전구역의_재주": r"안전구역의\s+재주",
        "ODD_PHRASE:말보다_느렸다": r"문제는.{0,12}말보다\s+느렸다",
        "ODD_PHRASE:칼끝에_걸렸다": r"(아이템|단서|기록표).{0,12}칼끝에\s+걸렸다",
    }
    for code, pat in odd_phrases.items():
        if re.search(pat, s):
            hits.append(code)

    # 3) Duplicated adjacent nouns: 공략 공략, 기록 기록, etc.
    dup_noun_hits = re.findall(r"(?<![가-힣])([가-힣]{2,})\s+\1(?![가-힣])", s)
    if dup_noun_hits:
        hits.append("DUPLICATED_ADJACENT_TOKEN:" + ",".join(sorted(set(dup_noun_hits))[:5]))

    sentences = split_korean_sentences(s)
    sent_counts = Counter(sentences)
    if any(cnt > globals().get("MAX_REPEATED_SENTENCE_COUNT", 1) for cnt in sent_counts.values()):
        hits.append("REPEATED_SENTENCE")

    # 4) Repeated lead phrase. Catches "공략 기한을 넘긴 초보 파티..." style template looping.
    lead_counts = Counter()
    for sent in sentences:
        words = re.findall(r"[가-힣A-Za-z0-9]+", sent)
        if len(words) >= 4:
            lead = " ".join(words[:5])
            if len(lead) >= 10:
                lead_counts[lead] += 1
    for lead, cnt in lead_counts.items():
        if cnt >= 3:
            hits.append("REPEATED_LEAD_PHRASE:" + lead)

    # 5) Repeated long phrase n-grams. Generic but conservative.
    words_all = re.findall(r"[가-힣A-Za-z0-9]+", s)
    long_ng = Counter()
    for n in (3, 4, 5):
        for i in range(0, max(0, len(words_all) - n + 1)):
            phrase = " ".join(words_all[i:i+n])
            # Skip overly generic phrases.
            if len(phrase) >= 10 and not phrase.startswith(("그 ", "이 ", "저 ")):
                long_ng[phrase] += 1
    for phrase, cnt in long_ng.items():
        if cnt >= 4:
            hits.append("REPEATED_LONG_PHRASE:" + phrase)
            break

    # 6) Pack/domain phrase density.
    candidate_phrases = [
        "최고층 갱신표", "최고층 기록표", "공략 최고층 기록표", "공략 기록표",
        "협회 공시판", "입장 통행증", "이미 깬 층 귀환 불가",
        "공략 기록", "길드 접수증", "보상함", "보상",
        "상태창 차단", "천해석", "천령석", "부력낭",
        "약혼 계약서", "계약서", "봉랍", "연회장", "찻잔", "촛대", "알리바이",
    ]
    for ph in candidate_phrases:
        limit = _repeated_phrase_limit(pack_id, ph)
        if s.count(ph) > limit:
            hits.append("REPEATED_PHRASE:" + ph)

    if pack_id == "TOWER_SYSTEM_RULE":
        # Combined density for visually different variants of the same anchor.
        highest_refs = len(re.findall(r"최고층\s*(갱신표|기록표)|공략\s*최고층\s*기록표|공략\s*기록표", s))
        if highest_refs > 4:
            hits.append("TOWER_ANCHOR_DENSITY:최고층_기록계열")

        attack_refs = s.count("공략")
        if attack_refs > max(10, len(s) // 120):
            hits.append("TOWER_TOKEN_DENSITY:공략")

        tower_bleed = {
            "TOWER_DUNGEON_BLEED:열쇠구멍": r"열쇠구멍",
            "TOWER_DUNGEON_BLEED:봉인된_방": r"봉인된\s+방",
            "TOWER_DUNGEON_BLEED:성문_열쇠": r"성문\s*열쇠",
        }
        for code, pat in tower_bleed.items():
            if re.search(pat, s):
                hits.append(code)

    if len(s) < 500:
        anchor_count = sum(1 for ph in candidate_phrases if ph in s)
        if anchor_count >= 5:
            hits.append("KEYWORD_COMPRESSED_SHORT_OUTPUT")

    # Deduplicate while preserving order.
    out = []
    seen = set()
    for h in hits:
        if h not in seen:
            out.append(h)
            seen.add(h)
    return out

def strip_residue(text):
    s = str(text or "")
    s = re.sub(r"(?im)^\s*(Human|Assistant|System|User)\s*:\s*", "", s)
    s = s.replace("<|im_start|>", "").replace("<|im_end|>", "")
    s = s.replace("```", "")
    s = re.sub(r"(?is)<xml.*?</xml>", "", s)
    s = re.sub(r"(?is)<[^>]{1,40}>", "", s)
    s = re.sub(r"(?m)^\s*(GENRE_DATA|CONTEXTUAL_DATA|EVENT_FLOW_RAILS|OUTPUT_CONTRACT|USER_INPUT).*$", "", s)
    s = re.sub(r"\n{3,}", "\n\n", s)
    return s.strip()

def infer_pack_from_final_text(text, expected_pack_id):
    s = text or ""
    scores = {}
    for pack_id, spec in PACK_REGISTRY.items():
        if pack_id == "GENERAL_WEBNOVEL":
            continue
        scores[pack_id] = sum(1 for w in spec["genre_data"]["positive_signals"] if w in s)
    if not scores:
        return expected_pack_id
    best, score = max(scores.items(), key=lambda kv: kv[1])
    return best if score > 0 else expected_pack_id

def bq_salvage_repair(text, pack):
    original = text or ""
    s = strip_residue(original)

    expected = _expected_pack_id_for_gate(pack)
    if expected == "TOWER_SYSTEM_RULE":
        tower_replacements = {
            "붉은 잉크": "외부 공시",
            "붉은 선": "갱신 표시",
            "붉은 글씨": "갱신 문구",
            "붉은 문장": "갱신 문장",
            "의뢰지": "길드 접수증",
            "의뢰서": "길드 접수증",
            "기한표": "최고층 갱신표",
            "공략지": "공략 기록",
            "붉은 표식": "갱신 표시",
            "게시판": "협회 공시판",
            "홍차잔": "공략 기록",
            "찻잔": "입장 통행증",
            "봉랍": "협회 도장",
            "성문 열쇠": "입장 통행증",
            "성문": "탑 입구",
            "하층 상인": "협회 접수원",
            "상인이 통행권": "협회가 입장 통행증",
            "상인들이 공략자에게 통행권": "협회 접수대가 공략자에게 입장 통행증",
            "탑이 의뢰를": "길드가 소재 채집 의뢰를",
            "탑은 의뢰를": "길드는 소재 채집 의뢰를",
        }
        for a, b in tower_replacements.items():
            s = s.replace(a, b)

        # Push status UI toward off-before-combat semantics.
        s = re.sub(
            r"(보스전|전투)(.{0,30})(상태창을\s*(켜|열|띄웠|띄운다|띄웠다))",
            r"\1\2상태창 차단 설정을 확인했다",
            s,
        )

        # If deadline exists but highest-floor renewal is absent, add a compact corrective anchor.
        if any(w in s for w in ["기한", "마감", "시한"]) and not any(w in s for w in ["최고층", "최고 공략층", "최고 기록"]):
            s += "\n\n협회 공시판에는 최고층 갱신 기록이 함께 붙어 있었다. 상층으로 갈수록 갱신 기한은 널널했고, 하층에 머문 공략자들만 더 빠듯한 칸으로 밀려났다."

        # AF1E: length recovery is handled by fallback, not normal salvage.
    elif expected == "ROMANTASY_HOUSE_CONTRACT":
        s = s.replace("붉은 잉크 기한표", "봉랍이 찍힌 초대장").replace("상태창", "초대장")
    elif expected == "AETHER_WHALERS":
        s = s.replace("상태창", "계기판").replace("던전", "암괴 항로")
    elif expected == "CLOSED_CIRCLE_MYSTERY":
        s = s.replace("상태창", "회중시계").replace("퀘스트", "심문")

    s = re.sub(r"\n{3,}", "\n\n", s).strip()
    return s, (s != original)



def repair_quality_issues(text, pack, quality_hits):
    s = text or ""
    changed = False
    pack_id = pack.get("pack_id", "GENERAL_WEBNOVEL") if isinstance(pack, dict) else "GENERAL_WEBNOVEL"

    # Direct grammar/odd phrase repair. Keep this unconditional because scan hits
    # can be mixed with surface/lore hits and still contain simple repairable defects.
    replacements = [
        ("표시을", "표시를"),
        ("표시은", "표시는"),
        ("문구을", "문구를"),
        ("문구은", "문구는"),
        ("공시을", "공시를"),
        ("공시은", "공시는"),
        ("차이 어떤 결과", "차이가 어떤 결과"),
        ("표시이", "표시가"),
        ("문구이", "문구가"),
        ("도장이이", "도장이"),
        ("기록이이", "기록이"),
        ("공시이", "공시가"),
        ("통행증이이", "통행증이"),
        ("은는", "은"),
        ("이가", "이"),
        ("을를", "을"),
        ("과와", "과"),
        ("으로로", "으로"),
        ("에에", "에"),
        ("공략 공략", "공략"),
        ("계약서 계약서", "계약서"),
        ("공략 최고층 갱신표의 갱신", "최고층 갱신표의 새 기록"),
        ("문제는 샘이 말보다 느렸다", "문제는 공시가 말보다 먼저 바뀌었다"),
        ("문제는 샘이", "문제는 공시가"),
        ("안전구역의 재주", "안전구역의 위치"),
        ("칼끝에 걸렸다", "기록 끝에 남았다"),
        ("열쇠구멍", "층계문"),
        ("봉인된 방", "제한 구역"),
        ("성문 열쇠", "입장 통행증"),
    ]
    for a, b in replacements:
        if a in s:
            s = s.replace(a, b)
            changed = True

    # Adjacent duplicate token repair: 공략 공략 -> 공략.
    ns = re.sub(r"(?<![가-힣])([가-힣]{2,})\s+\1(?![가-힣])", r"\1", s)
    if ns != s:
        s = ns
        changed = True

    def dedupe_repeated_sentences(src):
        parts = split_korean_sentences(src)
        if not parts:
            return src, False
        out = src
        seen = set()
        changed_local = False
        # Remove exact repeated long sentences after the first.
        for sent in parts:
            if sent in seen and len(sent) >= 18:
                out = out.replace(sent, "", 1)
                changed_local = True
            seen.add(sent)
        out = re.sub(r"\s{2,}", " ", out)
        out = re.sub(r"\n{3,}", "\n\n", out).strip()
        return out, changed_local

    if any(h == "REPEATED_SENTENCE" for h in (quality_hits or [])) or s.count(".") > 3:
        s2, c = dedupe_repeated_sentences(s)
        if c:
            s = s2
            changed = True

    synonym_map = {
        "TOWER_SYSTEM_RULE": {
            "보상함": ["돌파 보상", "보상 내역", "지급 목록", "보상 목록", "층 돌파 보상"],
            "보상": ["지급 내역", "돌파 대가", "층 보수", "공시 보수"],
            "최고층 갱신표": ["최고층 기록표", "갱신 공시", "협회 기록표", "최고 기록 공시"],
            "최고층 기록표": ["갱신 공시", "협회 기록표", "최고 기록 공시", "층 기록 사본"],
            "공략 최고층 기록표": ["최고층 기록표", "갱신 공시", "협회 기록표"],
            "공략 기록표": ["기록 사본", "등반 사본", "층 기록"],
            "공략 기록": ["기록 사본", "등반 기록", "층 기록", "협회 기록", "기록문"],
            "협회 공시판": ["협회 게시대", "외부 공시", "공시대"],
            "공략 기한을 넘긴 초보 파티": ["그 파티", "하층 파티", "기한을 넘긴 일행", "초보 등반자들"],
        },
        "AETHER_WHALERS": {
            "천해석": ["부력석", "하늘바다석", "부력층"],
            "부력낭": ["부력 주머니", "부양낭", "뜸낭"],
        },
        "ROMANTASY_HOUSE_CONTRACT": {
            "계약서": ["계약 문서", "조항 문서", "서류", "합의문"],
            "봉랍": ["밀랍 인장", "가문 인장", "인장"],
        },
        "CLOSED_CIRCLE_MYSTERY": {
            "찻잔": ["잔", "차잔", "손잡이 달린 잔"],
            "촛대": ["은촛대", "촛불 받침", "촛불대"],
        },
    }

    def disperse_phrase(src, phrase, syns, limit):
        count = src.count(phrase)
        if count <= limit:
            return src, False
        pieces = src.split(phrase)
        out = [pieces[0]]
        repl_idx = 0
        for occurrence_idx in range(count):
            if occurrence_idx < limit:
                out.append(phrase)
            else:
                out.append(syns[repl_idx % len(syns)])
                repl_idx += 1
            out.append(pieces[occurrence_idx + 1])
        return "".join(out), True

    # Standard repeated phrase repair.
    for hit in quality_hits or []:
        if hit.startswith("REPEATED_PHRASE:"):
            phrase = hit.split(":", 1)[1]
            syns = synonym_map.get(pack_id, {}).get(phrase)
            if syns:
                limit = _repeated_phrase_limit(pack_id, phrase)
                # R5: for known over-triggered anchors, allow a tighter repair target.
                if pack_id == "TOWER_SYSTEM_RULE" and phrase in {"공략 기록", "공략 기록표", "최고층 갱신표", "최고층 기록표"}:
                    limit = min(limit, 2)
                if pack_id == "ROMANTASY_HOUSE_CONTRACT" and phrase == "계약서":
                    limit = min(limit, 2)
                s, c = disperse_phrase(s, phrase, syns, limit)
                changed = changed or c

        elif hit.startswith("REPEATED_LEAD_PHRASE:"):
            phrase = hit.split(":", 1)[1]
            syns = synonym_map.get(pack_id, {}).get(phrase, ["그 일행", "주인공", "그들"])
            s, c = disperse_phrase(s, phrase, syns, 1)
            changed = changed or c

        elif hit.startswith("REPEATED_LONG_PHRASE:"):
            phrase = hit.split(":", 1)[1]
            s, c = disperse_phrase(s, phrase, ["그 장면", "그 기록", "그 선택"], 2)
            changed = changed or c

        elif hit == "TOWER_ANCHOR_DENSITY:최고층_기록계열":
            tower_anchor_syns = ["갱신 공시", "협회 기록", "최고 기록", "기록 사본", "외부 공시"]
            for phrase in ["공략 최고층 기록표", "최고층 갱신표", "최고층 기록표", "공략 기록표"]:
                s, c = disperse_phrase(s, phrase, tower_anchor_syns, 2)
                changed = changed or c

        elif hit == "TOWER_TOKEN_DENSITY:공략":
            density_repls = [
                ("공략 최고층", "최고층"),
                ("공략 갱신", "갱신"),
                ("공략 기록표", "기록표"),
                ("공략 기록", "등반 기록"),
                ("공략 기한", "등반 기한"),
                ("공략자", "등반자"),
            ]
            for a, b in density_repls:
                if s.count("공략") <= max(8, len(s) // 140):
                    break
                if a in s:
                    s = s.replace(a, b, 1)
                    changed = True

    return re.sub(r"\n{3,}", "\n\n", s).strip(), changed

def is_quality_only_reject(gate):
    if gate.get("verdict") != "REJECT":
        return False
    return (
        bool(gate.get("quality_hits"))
        and not gate.get("surface_hits")
        and not gate.get("lore_hits")
        and not gate.get("empty_final")
        and not gate.get("too_short_final")
        and not gate.get("final_route_miss")
    )

def is_r5_repairable_reject(gate):
    if gate.get("verdict") != "REJECT":
        return False
    if gate.get("empty_final") or gate.get("too_short_final") or gate.get("final_route_miss"):
        return False
    # Repair known surface/lore/quality residue. Do not promise all hard failures are repairable.
    surface = gate.get("surface_hits", []) or []
    lore = gate.get("lore_hits", []) or []
    quality = gate.get("quality_hits", []) or []
    repairable_surface = all(
        h.startswith("FOREIGN_OR_CODE:") or h in {"BROKEN_CHAR", "REPETITION_RUN"} or h.startswith("PROMPT_RESIDUE:")
        for h in surface
    )
    repairable_lore = all(
        h in {
            "TOWER_RED_RESIDUE",
            "TOWER_INTERNAL_REQUEST_SHEET",
            "TOWER_CASTLE_KEY_BLEED",
            "TOWER_DIRECT_REQUEST",
            "TOWER_MERCHANT_TICKET",
            "TOWER_DEADLINE_WITHOUT_HIGHEST_FLOOR_RENEWAL",
            "TOWER_ENTRY_PERMIT_WITHOUT_GUILD_OR_ASSOCIATION",
        }
        for h in lore
    )
    return bool(quality or surface or lore) and repairable_surface and repairable_lore

def r5_strip_surface_artifacts(text):
    s = strip_residue(text)
    original = s

    # Remove obvious foreign/code artifacts while preserving Korean prose.
    s = re.sub(r"[\u4e00-\u9fff]{4,}", "", s)
    s = s.replace("\ufffd", "")
    s = re.sub(r"(?im)^\s*(SELECT\s+.+|FROM\s+.+|import\s+\w+|def\s+\w+\(|class\s+\w+).*$", "", s)
    s = re.sub(r"[▯■□◆◇●○]{2,}", "", s)
    s = re.sub(r"[|｜/\\_]{6,}", "", s)
    s = re.sub(r"\s{2,}", " ", s)
    s = re.sub(r"\n{3,}", "\n\n", s)
    return s.strip(), (s.strip() != original.strip())

def r5_lore_surface_quality_repair(text, pack, gate):
    s = text or ""
    changed_any = False

    # First pass: existing salvage has pack-specific lore replacements.
    s2, changed = bq_salvage_repair(s, pack)
    if changed:
        s, changed_any = s2, True

    # Extra Tower residue normalization.
    expected = _expected_pack_id_for_gate(pack)
    if expected == "TOWER_SYSTEM_RULE":
        tower_extra = [
            ("붉은 잉크", "외부 공시"),
            ("붉은 표식", "갱신 표시"),
            ("붉은 선", "갱신 표시"),
            ("붉은 글씨", "갱신 문구"),
            ("공략지", "공략 기록"),
            ("의뢰지", "길드 접수증"),
            ("의뢰서", "길드 접수증"),
            ("기한표", "최고층 갱신표"),
            ("성문 열쇠", "입장 통행증"),
            ("성문", "탑 입구"),
        ]
        for a, b in tower_extra:
            if a in s:
                s = s.replace(a, b)
                changed_any = True

    s2, changed = r5_strip_surface_artifacts(s)
    if changed:
        s, changed_any = s2, True

    # Quality repair even when surface/lore hits coexist.
    qhits = gate.get("quality_hits", []) or scan_quality_issues(s, pack)
    s2, changed = repair_quality_issues(s, pack, qhits)
    if changed:
        s, changed_any = s2, True

    # If deadline exists but highest-floor anchor was removed, re-anchor.
    if expected == "TOWER_SYSTEM_RULE":
        if any(w in s for w in ["기한", "마감", "시한"]) and not any(w in s for w in ["최고층", "최고 기록", "갱신 공시"]):
            s += "\n\n협회 공시에는 최고층 기록 갱신 내역도 함께 붙어 있었다. 상층으로 갈수록 기한은 널널했고, 하층에 머문 등반자들만 더 좁은 칸으로 밀려났다."
            changed_any = True

    return re.sub(r"\n{3,}", "\n\n", s).strip(), changed_any

def quality_light_repair_until_keep(text, pack, gate):
    if not globals().get("ENABLE_QUALITY_LIGHT_REPAIR", True):
        return text, gate, False, []
    s = text
    g = gate
    events = []
    changed_any = False
    max_rounds = globals().get("R5_TOTAL_REPAIR_MAX_ROUNDS", globals().get("QUALITY_ONLY_REPAIR_MAX_ROUNDS", 2))

    for i in range(max_rounds):
        repairable = is_quality_only_reject(g)
        if globals().get("ENABLE_R5_MIXED_HIT_REPAIR", True):
            repairable = repairable or is_r5_repairable_reject(g)
        if not repairable:
            break

        s2, changed = r5_lore_surface_quality_repair(s, pack, g)
        if not changed or s2 == s:
            break

        s = s2
        changed_any = True
        g = final_gate(s, pack)
        events.append({
            "round": i + 1,
            "surface_hits_after": g.get("surface_hits", []),
            "lore_hits_after": g.get("lore_hits", []),
            "quality_hits_after": g.get("quality_hits", []),
            "verdict_after": g.get("verdict"),
            "length_after": g.get("length_chars"),
        })
        if g.get("verdict") == "KEEP":
            break

    return s, g, changed_any, events

def _expected_pack_id_for_gate(pack):
    """R4_R2 defensive pack id resolver."""
    if isinstance(pack, dict):
        if pack.get("pack_id"):
            return pack["pack_id"]
        if pack.get("selected_pack_id"):
            return pack["selected_pack_id"]
        if pack.get("id"):
            return pack["id"]
    return "GENERAL_WEBNOVEL"


# AF1K R17: Tower no-reentry lore scanner.
def r17_tower_reentry_exception_allowed(text):
    exception_terms = globals().get("R17_TOWER_EXCEPTION_TERMS", ["예외", "이례", "특수 허가", "균열", "오류", "붕괴", "비정상"])
    return any(t in (text or "") for t in exception_terms)

def r17_tower_no_reentry_lore_hits(text, pack):
    if not globals().get("R17_TOWER_NO_REENTRY_DEFAULT", True):
        return []
    if not isinstance(pack, dict) or pack.get("pack_id") != "TOWER_SYSTEM_RULE":
        return []
    s = re.sub(r"\s+", " ", text or "")
    if r17_tower_reentry_exception_allowed(s):
        return []
    hits = []
    banned = globals().get("R17_TOWER_REENTRY_TERMS_BANNED_IN_NORMAL", ["재입장 제한", "재방문 제한", "하층 재입장", "반복 파밍 대신"])
    for term in banned:
        if term and term in s:
            hits.append("TOWER_REENTRY_ROUTINE_RESIDUE:" + term)
    # This one is especially important: if a cleared lower floor is treated as an available option.
    if ("이미 깬" in s or "이미 클리어" in s or "돌파한 하층" in s) and any(x in s for x in ["다시 들어", "다시 갈", "재입장", "재방문"]):
        hits.append("TOWER_CLEARED_FLOOR_REENTRY_OPTION")
    return sorted(set(hits))


def final_gate(text, pack):
    expected = _expected_pack_id_for_gate(pack)
    if "apply_length_preset" in globals():
        apply_length_preset()
    surface_hits = scan_surface(text)
    lore_hits = scan_tower_lore(text) if expected == "TOWER_SYSTEM_RULE" else []
    lore_hits.extend(r17_tower_no_reentry_lore_hits(text, pack) if "r17_tower_no_reentry_lore_hits" in globals() else [])
    quality_hits = scan_quality_issues(text, dict(pack, pack_id=expected) if isinstance(pack, dict) and not pack.get("pack_id") else pack)
    final_pack = infer_pack_from_final_text(text, expected)
    final_route_miss = (expected != "GENERAL_WEBNOVEL" and final_pack != expected)
    min_chars = MIN_FINAL_CHARS_BY_PACK.get(expected, 500)
    too_short_final = len((text or "").strip()) < min_chars
    empty_final = len((text or "").strip()) < 180
    hard_fail = bool(surface_hits) or bool(lore_hits) or bool(quality_hits) or empty_final or too_short_final

    if hard_fail:
        verdict = "REJECT"
    elif final_route_miss:
        verdict = "LIGHT_REPAIR"
    else:
        verdict = "KEEP"

    return {
        "verdict": verdict,
        "expected_pack": expected,
        "final_pack": final_pack,
        "final_route_miss": final_route_miss,
        "surface_hits": surface_hits,
        "lore_hits": lore_hits,
        "quality_hits": quality_hits,
        "empty_final": empty_final,
        "too_short_final": too_short_final,
        "min_chars": min_chars,
        "hard_fail": hard_fail,
        "length_chars": len(text or ""),
    }

def _pack_min_chars(pack):
    if "apply_length_preset" in globals():
        apply_length_preset()
    return MIN_FINAL_CHARS_BY_PACK.get(pack.get("pack_id", "GENERAL_WEBNOVEL"), 500)

def _extension_variant_index(pack, round_idx):
    seed = (pack.get("source_user_input", "") + "|" + pack.get("pack_id", "") + "|" + str(round_idx)).encode("utf-8")
    return int(hashlib.sha256(seed).hexdigest(), 16)

def make_genre_correct_extension(pack, current_text="", round_idx=0):
    """Return one genre-correct event-flow paragraph for min-length recovery.

    The extension is intentionally small and varied. It should continue the
    current scene instead of dumping keywords.
    """
    pack_id = pack.get("pack_id", "GENERAL_WEBNOVEL")
    idx = _extension_variant_index(pack, round_idx)
    user_hint = pack.get("source_user_input", "")

    tower = [
        "협회 접수원은 보상 내역보다 먼저 돌파 이력 봉인을 확인했다. 이미 돌파한 층을 반복해서 도는 길은 막혀 있었고, 새 최고층 기록 때문에 하층 통행증의 유효 시간도 줄어 있었다. 주인공은 상태창 차단 설정을 다시 눌렀다. 지금 필요한 것은 숫자가 아니라, 서로 다르게 남은 공략 기록 사이의 빈칸이었다.",
        "길드 공시판의 소재 채집 의뢰는 탑이 내린 명령이 아니었다. 바깥 사람들이 보상표를 보고 만든 거래였다. 문제는 그 거래를 감당할 실력이 없는 파티가 접수증을 받아 든 순간부터 시작됐다. 주인공은 최고층 갱신표의 날짜를 접어 넣고, 하층으로 돌아가는 길 대신 아직 확인되지 않은 문을 보았다.",
        "기록관의 사본에는 공식 공략문과 다른 줄이 하나 있었다. 같은 층을 돌파했는데도 보상함의 위치가 다르다면, 그것은 오기가 아니라 조건의 차이일 가능성이 컸다. 협회 도장은 조용히 말하고 있었다. 같은 길을 반복하는 자에게는 제한을, 다른 조건을 찾는 자에게는 다음 층을."
    ]
    aether = [
        "기관사는 증기 밸브를 반 칸만 돌렸다. 너무 닫으면 부력낭이 가라앉고, 너무 열면 권양기가 사슬을 토해 낸다. 선장은 고래의 그림자를 놓치지 않으면서도 천해석 층의 떨림을 먼저 들었다. 오늘의 사냥은 수익과 생존 사이에 걸린 얇은 밧줄이었다.",
        "공어 떼가 갑판을 스치고 지나가자 항해사는 암괴의 위치를 다시 불렀다. 지상식 나침반은 여전히 고집스럽게 북쪽을 가리켰지만, 천해의 바람은 북쪽을 믿지 않았다. 선원들은 고래보다 먼저 배를 살리는 쪽으로 몸을 기울였다.",
        "천령석실의 빛이 가늘어졌을 때, 아무도 큰소리로 겁먹었다고 말하지 않았다. 대신 포경창의 줄을 짧게 감고, 찢어진 부력낭 가장자리에 천해석 파편을 맞댔다. 하늘바다는 영웅담보다 손이 빠른 사람을 더 오래 살려 두었다."
    ]
    romantasy = [
        "그녀는 웃지 않았다. 웃음은 이 방에서 가장 값싼 방어였고, 값싼 방어는 오래 버티지 못한다. 대신 좌석표와 계약서의 날짜를 나란히 놓았다. 두 문서가 서로 다른 밤을 가리키는 순간, 연회장의 음악은 더 이상 축하가 아니었다.",
        "황녀의 시선이 장갑 위에 머물렀다. 가문 문장을 새긴 장갑은 예절의 장식이 아니라, 누가 이 계약의 증인이었는지를 말하는 물건이었다. 그녀가 침묵하면 소문이 이겼고, 말하면 동맹이 금이 갔다. 그래서 그녀는 가장 느린 문장을 골랐다.",
        "봉랍이 갈라지는 소리는 작았지만, 그 작은 소리에 후견인의 손끝이 멈췄다. 모두가 사랑 이야기를 기대한 자리에서 그녀가 꺼낸 것은 권리와 날짜, 그리고 지워진 이름이었다. 그 셋만으로도 연회장의 편은 다시 나뉘기 시작했다."
    ]
    mystery = [
        "탐정은 답을 서두르지 않았다. 폐쇄된 저택에서 빠른 결론은 대개 범인의 편이다. 그는 촛대의 위치와 찻잔의 온도, 그리고 장갑 단추가 풀린 손을 차례로 보았다. 사라진 열쇠보다 중요한 것은, 누가 열쇠를 찾는 척했는가였다.",
        "폭풍은 모두에게 같은 핑계를 주었다. 그래서 탐정은 날씨 이야기를 지웠다. 남은 것은 시간표와 젖은 발자국, 그리고 너무 완벽하게 맞아떨어지는 알리바이뿐이었다. 완벽한 진술은 진실이 아니라 연습의 냄새를 풍긴다.",
        "하녀가 잔을 치우려는 순간, 탐정은 손잡이의 방향을 보았다. 죽은 사람의 습관과 맞지 않는 사소한 방향. 저택의 누구도 그것을 증거라고 부르지 않았지만, 범인은 바로 그런 사소함을 가장 늦게 고친다."
    ]
    ret = [
        "주인공은 미래를 전부 믿지 않기로 했다. 한 번 실패한 기억은 경고이지만, 두 번째 삶에서는 함정이 될 수도 있다. 편지의 날짜가 하루 달라진 순간, 그는 복수의 순서를 접고 먼저 오차의 원인을 찾기로 했다.",
        "예정된 모욕이 사라진 연회장은 더 위험했다. 모욕이 없다는 것은 적이 사라졌다는 뜻이 아니라, 적이 먼저 움직였다는 뜻일 수 있었다. 그는 웃음 뒤에 숨은 침묵을 세었고, 첫 번째 삶에서 보지 못한 이름을 초대장 아래에서 발견했다.",
        "과거는 같은 얼굴로 돌아왔지만 같은 길로 돌아오지는 않았다. 손목의 상처와 탁자 위 동전 수가 기억과 달랐다. 주인공은 그 작은 차이를 무시하지 않았다. 멸망은 언제나 작은 오차를 밟고 온다."
    ]
    general = [
        "주인공은 문밖의 소리를 기다렸다. 기다림은 선택을 늦추는 일이 아니라, 선택의 값을 재는 일이었다. 방 안의 물건들은 저마다 다른 침묵을 갖고 있었고, 그중 하나만이 지금 이 장면의 규칙을 바꾸고 있었다.",
        "누군가는 거짓말을 하고 있었다. 그러나 거짓말의 문장은 아직 완성되지 않았다. 주인공은 가장 큰 단서가 아니라 가장 늦게 숨겨진 단서를 골랐다. 작은 물건 하나가 손안에 들어오자, 방 안의 시선들이 조금씩 방향을 바꾸었다.",
        "문고리가 다시 흔들렸다. 이제 물러나면 아무 일도 일어나지 않을 수 있었다. 하지만 아무 일도 일어나지 않는 길은 대개 누군가가 준비한 길이다. 주인공은 그 길을 피하기 위해, 가장 설명하기 어려운 선택을 했다."
    ]

    pool = {
        "TOWER_SYSTEM_RULE": tower,
        "AETHER_WHALERS": aether,
        "ROMANTASY_HOUSE_CONTRACT": romantasy,
        "CLOSED_CIRCLE_MYSTERY": mystery,
        "RETURN_FANTASY": ret,
        "GENERAL_WEBNOVEL": general,
    }.get(pack_id, general)

    return pool[idx % len(pool)]



# AF1K R13: RETURN_FANTASY focus repair.
RETURN_FANTASY_ANCHORS_R13 = ["회귀", "두 번째 삶", "첫 번째 삶", "미래", "파멸", "멸망", "기억", "오차", "예정", "다시 돌아"]
RETURN_FANTASY_BLEED_R13 = ["탐정", "알리바이", "용의자", "후견", "계약 조항", "공작가", "왕자", "황녀", "고래", "천해", "상태창", "공략 기록"]

def r13_return_focus_metrics(text):
    s = re.sub(r"\s+", " ", text or "").strip()
    first = s[:int(globals().get("R13_RETURN_FOCUS_FIRST_CHARS", 520))]
    anchors = [w for w in RETURN_FANTASY_ANCHORS_R13 if w in first]
    bleed = [w for w in RETURN_FANTASY_BLEED_R13 if w in first]
    return {
        "first_chars": len(first),
        "anchors_first": anchors,
        "bleed_first": bleed,
        "anchor_count_first": len(anchors),
        "bleed_count_first": len(bleed),
    }

def r13_make_return_focus_prelude(pack, text=""):
    user = pack.get("source_user_input", "")
    if "암살" in user or "하인" in user:
        return "두 번째 삶의 첫날, 주인공은 예정된 암살자가 오지 않았다는 사실보다 사라진 하인의 이름을 먼저 보았다. 첫 번째 삶의 기억과 다른 빈칸 하나가 미래 지식의 신뢰를 흔들었다."
    if "편지" in user or "날짜" in user:
        return "파멸 직전으로 돌아온 뒤, 그는 복수 상대의 이름보다 편지의 날짜가 하루 어긋났다는 사실을 먼저 확인했다. 첫 번째 삶의 기억은 지도였지만, 그 오차는 지도가 이미 낡았다는 증거였다."
    if "두 번째 삶" in user or "모욕" in user or "연회" in user:
        return "두 번째 삶의 연회는 기억보다 조용했다. 원래 있어야 할 모욕이 사라진 순간, 주인공은 미래가 저절로 고쳐진 것이 아니라 누군가 먼저 움직였다는 쪽을 택했다."
    return "주인공은 돌아온 시간을 전부 믿지 않았다. 첫 번째 삶의 기억과 지금 눈앞의 작은 차이가 어긋나는 순간, 복수보다 먼저 확인해야 할 것은 미래 지식의 균열이었다."

def r13_return_focus_repair(text, pack):
    if not globals().get("R13_ENABLE_RETURN_FOCUS_REPAIR", True):
        return text, False, None
    if not isinstance(pack, dict) or pack.get("pack_id") != "RETURN_FANTASY":
        return text, False, None

    metrics = r13_return_focus_metrics(text)
    weak_anchor = metrics["anchor_count_first"] < int(globals().get("R13_RETURN_FOCUS_MIN_ANCHORS_FIRST", 1))
    heavy_bleed = metrics["bleed_count_first"] > int(globals().get("R13_RETURN_FOCUS_MAX_BLEED_FIRST", 3))

    if not weak_anchor and not heavy_bleed:
        return text, False, {"changed": False, "metrics": metrics}

    prelude = r13_make_return_focus_prelude(pack, text)
    s = (text or "").strip()
    if s.startswith(prelude[:30]):
        return text, False, {"changed": False, "metrics": metrics, "reason": "already_prefixed"}

    repaired = (prelude + "\n\n" + s).strip() if s else prelude
    after = r13_return_focus_metrics(repaired)
    return repaired, True, {
        "changed": True,
        "reason": "weak_return_focus" if weak_anchor else "return_bleed_first",
        "metrics_before": metrics,
        "metrics_after": after,
    }



# AF1K R16: pack-specific minlen cushion.
def r16_minlen_margin_for_pack(pack):
    if isinstance(pack, dict) and pack.get("pack_id") == "TOWER_SYSTEM_RULE":
        return int(globals().get("R16_TOWER_MINLEN_TARGET_MARGIN", 70))
    return int(globals().get("MINLEN_TARGET_MARGIN_CHARS", 60))


def ensure_min_length(text, pack, reason=""):
    """AF1J: natural min-length recovery.

    1) Try model-generated continuation first.
    2) Use deterministic extension only if continuation cannot reach minimum.
    3) Track deterministic vs model continuation separately.
    """
    if not globals().get("ENABLE_MINLEN_ENFORCER", True):
        return text, False, []
    s = (text or "").strip()
    min_chars = _pack_min_chars(pack)
    target = min_chars + globals().get("MINLEN_TARGET_MARGIN_CHARS", 60)
    events = []

    # Already long enough: no intervention.
    if len(s) >= target:
        return s, False, events

    # Model continuation first: less template-like.
    if globals().get("ENABLE_MODEL_CONTINUATION_FOR_MINLEN", True) and "generate_continuation" in globals():
        for round_idx in range(globals().get("MODEL_CONTINUATION_MAX_ROUNDS", 2)):
            if len(s) >= target:
                break
            cont = generate_continuation(s, pack, reason=f"{reason}_model_continue_{round_idx+1}")
            cont = strip_residue(cont)
            cont, _ = bq_salvage_repair(cont, pack)
            if cont and cont not in s:
                s = (s + "\n\n" + cont).strip() if s else cont.strip()
                events.append({
                    "round": round_idx + 1,
                    "type": "model_continuation",
                    "chars_after": len(s),
                    "reason": reason,
                })

    if len(s) >= target:
        return s, bool(events), events

    # Deterministic extension as last resort.
    if not globals().get("ALLOW_DETERMINISTIC_MINLEN_EXTENSION", True):
        return s, bool(events), events

    max_rounds = globals().get("MINLEN_EXTENSION_MAX_ROUNDS", 4)
    det_round = 0
    while len(s) < target and det_round < max_rounds:
        ext = make_genre_correct_extension(pack, s, det_round)
        if ext and ext not in s:
            s = (s + "\n\n" + ext).strip() if s else ext.strip()
            events.append({
                "round": det_round + 1,
                "type": "deterministic_extension",
                "chars_after": len(s),
                "reason": reason,
            })
        det_round += 1

    return s, bool(events), events

def minlen_event_counts(events):
    c = Counter()
    for e in events or []:
        c[e.get("type", "unknown")] += 1
    return dict(c)

def _prefix_key(text):
    n = globals().get("DUPLICATE_PREFIX_CHARS", 180)
    return re.sub(r"\s+", " ", text or "").strip()[:n]

def duplicate_prefix_guard(text, pack):
    if not globals().get("ENABLE_DUPLICATE_PREFIX_GUARD", True):
        return text, False, []
    if "SEEN_FINAL_PREFIXES" not in globals():
        globals()["SEEN_FINAL_PREFIXES"] = Counter()

    events = []
    s = text or ""
    for round_idx in range(globals().get("DUPLICATE_PREFIX_REPAIR_MAX_ROUNDS", 2)):
        key = _prefix_key(s)
        if not key:
            break
        if SEEN_FINAL_PREFIXES.get(key, 0) < globals().get("DUPLICATE_PREFIX_MAX_SEEN", 1):
            break

        # Try model continuation/rewrite of opening if possible. Safer fallback: prepend a varied scene beat.
        if not DRY_RUN_WITH_DETERMINISTIC_TEXT and "generate_continuation" in globals():
            prompt_pack = dict(pack)
            cont = generate_continuation(
                "이전 시작부와 겹치지 않도록 장면의 첫 문단을 다른 감각/행동으로 다시 열어라.\n\n" + s[:1200],
                prompt_pack,
                reason="duplicate_prefix_repair",
            )
            cont = strip_residue(cont)
            if cont:
                # Use continuation as a fresh opening plus original later body tail.
                tail = "\n\n".join((s.split("\n\n")[1:] or [s]))
                s = (cont.strip() + "\n\n" + tail.strip()).strip()
                events.append({"round": round_idx + 1, "type": "model_prefix_repair", "chars_after": len(s)})
                continue

        ext = make_genre_correct_extension(pack, s, round_idx)
        s = (ext + "\n\n" + s).strip()
        events.append({"round": round_idx + 1, "type": "deterministic_prefix_repair", "chars_after": len(s)})

    return s, bool(events), events

def register_final_prefix(text):
    if "SEEN_FINAL_PREFIXES" not in globals():
        globals()["SEEN_FINAL_PREFIXES"] = Counter()
    key = _prefix_key(text)
    if key:
        SEEN_FINAL_PREFIXES[key] += 1

def deterministic_safe_fallback(pack, reason):
    return deterministic_body(pack)




def r7_prefill_cases(cases, label="prefill"):
    """Batch-generate first raw bodies for unique uncached inputs.

    R8: final result cache remains strict by phase/repair settings, but raw
    generation cache is shared across phases because raw model output does not
    depend on quality repair/gate handler settings.
    """
    if not globals().get("R7_ENABLE_BATCH_INITIAL_PREFILL", True):
        return {"label": label, "enabled": False, "unique": 0, "prefilled": 0}
    if DRY_RUN_WITH_DETERMINISTIC_TEXT:
        return {"label": label, "enabled": False, "dry_run": True, "unique": 0, "prefilled": 0}

    if "R7_RUNTIME_STATS" not in globals():
        globals()["R7_RUNTIME_STATS"] = Counter()
    if "R7_INITIAL_RAW_CACHE" not in globals():
        globals()["R7_INITIAL_RAW_CACHE"] = {}
    if "R8_RAW_GENERATION_CACHE" not in globals():
        globals()["R8_RAW_GENERATION_CACHE"] = {}

    unique_items = []
    seen_final = set()
    for case in list(cases or [])[:int(globals().get("R7_MAX_PREFILL_CASES_PER_CALL", 256))]:
        front = front_half(case)
        pack = front["pack"]
        prompt = build_event_rail_prompt(pack)
        final_key = r7_cache_key(case, pack=pack, prompt=prompt)
        raw_key = r8_raw_cache_key(case, pack=pack, prompt=prompt) if "r8_raw_cache_key" in globals() else final_key

        if final_key in seen_final:
            R7_RUNTIME_STATS["prefill_skip_duplicate_in_batch"] += 1
            continue
        seen_final.add(final_key)

        if globals().get("R7_ENABLE_EXACT_RESULT_CACHE", True) and final_key in globals().get("R7_RESULT_CACHE", {}):
            R7_RUNTIME_STATS["prefill_skip_result_cache"] += 1
            continue

        # R8 shared raw cache: use prior model raw output, but rerun repair/gate.
        if globals().get("R8_ENABLE_SHARED_RAW_GENERATION_CACHE", True) and raw_key in globals().get("R8_RAW_GENERATION_CACHE", {}):
            R7_INITIAL_RAW_CACHE[final_key] = {
                "front": front,
                "pack": pack,
                "prompt": prompt,
                "raw": R8_RAW_GENERATION_CACHE[raw_key],
                "label": label,
                "r8_raw_cache_key": raw_key,
                "r8_raw_cache_hit": True,
            }
            R7_RUNTIME_STATS["raw_generation_cache_hits"] += 1
            continue

        if final_key in R7_INITIAL_RAW_CACHE:
            R7_RUNTIME_STATS["prefill_skip_initial_cache"] += 1
            continue

        unique_items.append((case, final_key, raw_key, front, pack, prompt))

    if not unique_items:
        return {
            "label": label,
            "enabled": True,
            "unique": 0,
            "prefilled": 0,
            "raw_cache_size": len(globals().get("R8_RAW_GENERATION_CACHE", {})),
        }

    prompts = [it[5] for it in unique_items]
    packs = [it[4] for it in unique_items]
    raws = batch_generate_body(prompts, packs, batch_size=int(globals().get("R7_BATCH_SIZE", 8)))

    for (case, final_key, raw_key, front, pack, prompt), raw in zip(unique_items, raws):
        if globals().get("R8_ENABLE_SHARED_RAW_GENERATION_CACHE", True):
            R8_RAW_GENERATION_CACHE[raw_key] = raw
            R7_RUNTIME_STATS["raw_generation_cache_stores"] += 1
        R7_INITIAL_RAW_CACHE[final_key] = {
            "front": front,
            "pack": pack,
            "prompt": prompt,
            "raw": raw,
            "label": label,
            "r8_raw_cache_key": raw_key,
            "r8_raw_cache_hit": False,
        }

    R7_RUNTIME_STATS["prefill_calls"] += 1
    R7_RUNTIME_STATS["prefilled_unique_cases"] += len(unique_items)
    return {
        "label": label,
        "enabled": True,
        "unique": len(unique_items),
        "prefilled": len(unique_items),
        "raw_cache_size": len(globals().get("R8_RAW_GENERATION_CACHE", {})),
    }

def e2e_generate_one(user_input):
    import time, copy
    t0 = time.time()

    # R7_R3 strict cache key requires pack/prompt fingerprint, so build front
    # before cache lookup. This is CPU-cheap compared to GPU generation.
    front = front_half(user_input)
    pack = front["pack"]
    prompt = build_event_rail_prompt(pack)
    cache_key = r7_cache_key(user_input, pack=pack, prompt=prompt) if "r7_cache_key" in globals() else str(user_input)
    r9_key = r9_final_cache_key(user_input, pack=pack, prompt=prompt) if "r9_final_cache_key" in globals() else None

    # R9: duplicate validation rows are cache data. This is the aggressive path.
    if (
        globals().get("R9_ENABLE_SHARED_FINAL_RESULT_CACHE", True)
        and r9_key
        and "R9_FINAL_RESULT_CACHE" in globals()
        and r9_key in R9_FINAL_RESULT_CACHE
    ):
        if "R7_RUNTIME_STATS" in globals():
            R7_RUNTIME_STATS["r9_final_result_cache_hits"] += 1
        return r9_clone_final_cached_result(R9_FINAL_RESULT_CACHE[r9_key], user_input, cache_key=r9_key)

    if globals().get("R7_ENABLE_EXACT_RESULT_CACHE", True) and "R7_RESULT_CACHE" in globals() and cache_key in R7_RESULT_CACHE:
        if "R7_RUNTIME_STATS" in globals():
            R7_RUNTIME_STATS["result_cache_hits"] += 1
        return r7_clone_cached_result(R7_RESULT_CACHE[cache_key], user_input)

    prefilled = globals().get("R7_INITIAL_RAW_CACHE", {}).pop(cache_key, None) if globals().get("R7_ENABLE_BATCH_INITIAL_PREFILL", True) else None

    # R8 direct shared raw cache fallback. This happens when a loop did not run
    # r7_prefill_cases(), or when a post-handler phase can reuse prior raw output.
    if not prefilled and globals().get("R8_ENABLE_SHARED_RAW_GENERATION_CACHE", True) and "r8_raw_cache_key" in globals():
        raw_key = r8_raw_cache_key(user_input, pack=pack, prompt=prompt)
        if raw_key in globals().get("R8_RAW_GENERATION_CACHE", {}):
            prefilled = {
                "front": front,
                "pack": pack,
                "prompt": prompt,
                "raw": R8_RAW_GENERATION_CACHE[raw_key],
                "label": "direct_raw_cache",
                "r8_raw_cache_key": raw_key,
                "r8_raw_cache_hit": True,
            }
            if "R7_RUNTIME_STATS" in globals():
                R7_RUNTIME_STATS["raw_generation_cache_hits_direct"] += 1

    if prefilled:
        front = prefilled["front"]
        pack = prefilled["pack"]
        prompt = prefilled["prompt"]

    attempts = []
    used_batch_initial_prefill = bool(prefilled)
    used_r8_raw_cache = bool(prefilled and prefilled.get("r8_raw_cache_hit"))
    used_salvage = False
    used_fallback = False
    used_minlen_extension = False
    used_model_continuation = False
    used_deterministic_minlen_extension = False
    used_quality_light_repair = False
    used_duplicate_prefix_repair = False
    used_r13_return_focus_repair = False
    r13_return_focus_events = []
    minlen_extension_events = []
    duplicate_prefix_events = []
    quality_repair_events = []

    for attempt_no in range(1, MAX_ATTEMPTS + 1):
        raw = prefilled['raw'] if (attempt_no == 1 and prefilled) else generate_body(prompt, pack)
        repaired, changed = bq_salvage_repair(raw, pack)
        if "r13_return_focus_repair" in globals():
            repaired, r13_changed, r13_event = r13_return_focus_repair(repaired, pack)
            if r13_event:
                r13_return_focus_events.append(dict(r13_event, stage=f"attempt_{attempt_no}_pre_minlen"))
            used_r13_return_focus_repair = used_r13_return_focus_repair or r13_changed

        if globals().get("MINLEN_EXTEND_BEFORE_FALLBACK", True):
            repaired, ext_changed, ext_events = ensure_min_length(repaired, pack, reason=f"attempt_{attempt_no}_pre_gate")
            minlen_extension_events.extend(ext_events)
            event_counts = minlen_event_counts(ext_events)
            used_model_continuation = used_model_continuation or event_counts.get("model_continuation", 0) > 0
            used_deterministic_minlen_extension = used_deterministic_minlen_extension or event_counts.get("deterministic_extension", 0) > 0
            used_minlen_extension = used_minlen_extension or ext_changed

        gate = final_gate(repaired, pack)
        repaired, gate, q_changed, q_events = quality_light_repair_until_keep(repaired, pack, gate)
        used_quality_light_repair = used_quality_light_repair or q_changed
        quality_repair_events.extend(q_events)

        repaired, dup_changed, dup_events = duplicate_prefix_guard(repaired, pack)
        if dup_changed:
            used_duplicate_prefix_repair = True
            duplicate_prefix_events.extend(dup_events)
            gate = final_gate(repaired, pack)
            repaired, gate, q_changed2, q_events2 = quality_light_repair_until_keep(repaired, pack, gate)
            used_quality_light_repair = used_quality_light_repair or q_changed2
            quality_repair_events.extend(q_events2)

        used_salvage = used_salvage or changed
        attempts.append({
            "attempt": attempt_no,
            "raw": raw,
            "repaired": repaired,
            "salvage_changed": changed,
            "minlen_extended": ext_changed if 'ext_changed' in locals() else False,
            "minlen_event_counts": minlen_event_counts(ext_events if 'ext_events' in locals() else []),
            "quality_light_repaired": q_changed,
            "duplicate_prefix_repaired": dup_changed,
            "gate": gate,
        })

        if gate["verdict"] == "KEEP":
            break

    final_text = attempts[-1]["repaired"]
    final_gate_result = attempts[-1]["gate"]

    # Deterministic fallback only after natural attempts fail.
    if final_gate_result["verdict"] == "REJECT":
        fallback_text = deterministic_safe_fallback(pack, "final_gate_reject")
        fallback_repaired, fallback_changed = bq_salvage_repair(fallback_text, pack)
        if "r13_return_focus_repair" in globals():
            fallback_repaired, r13_changed, r13_event = r13_return_focus_repair(fallback_repaired, pack)
            if r13_event:
                r13_return_focus_events.append(dict(r13_event, stage="fallback_pre_minlen"))
            used_r13_return_focus_repair = used_r13_return_focus_repair or r13_changed

        if globals().get("MINLEN_EXTEND_AFTER_FALLBACK", True):
            fallback_repaired, ext_changed, ext_events = ensure_min_length(fallback_repaired, pack, reason="fallback_post_gate")
            minlen_extension_events.extend(ext_events)
            event_counts = minlen_event_counts(ext_events)
            used_model_continuation = used_model_continuation or event_counts.get("model_continuation", 0) > 0
            used_deterministic_minlen_extension = used_deterministic_minlen_extension or event_counts.get("deterministic_extension", 0) > 0
            used_minlen_extension = used_minlen_extension or ext_changed

        fallback_gate = final_gate(fallback_repaired, pack)
        fallback_repaired, fallback_gate, q_changed, q_events = quality_light_repair_until_keep(fallback_repaired, pack, fallback_gate)
        used_quality_light_repair = used_quality_light_repair or q_changed
        quality_repair_events.extend(q_events)

        fallback_repaired, dup_changed, dup_events = duplicate_prefix_guard(fallback_repaired, pack)
        if dup_changed:
            used_duplicate_prefix_repair = True
            duplicate_prefix_events.extend(dup_events)
            fallback_gate = final_gate(fallback_repaired, pack)

        final_text = fallback_repaired
        used_fallback = True
        used_salvage = used_salvage or fallback_changed
        final_gate_result = fallback_gate

    register_final_prefix(final_text)

    result = {
        "input": user_input,
        "front": front,
        "prompt": prompt,
        "final_text": final_text,
        "final_gate": final_gate_result,
        "attempts": attempts,
        "used_salvage": used_salvage,
        "used_fallback": used_fallback,
        "used_minlen_extension": used_minlen_extension,
        "used_model_continuation": used_model_continuation,
        "used_deterministic_minlen_extension": used_deterministic_minlen_extension,
        "minlen_extension_events": minlen_extension_events,
        "used_quality_light_repair": used_quality_light_repair,
        "quality_repair_events": quality_repair_events,
        "used_duplicate_prefix_repair": used_duplicate_prefix_repair,
        "duplicate_prefix_events": duplicate_prefix_events,
        "used_r13_return_focus_repair": used_r13_return_focus_repair,
        "r13_return_focus_events": r13_return_focus_events,
        "used_cache": False,
        "used_batch_initial_prefill": used_batch_initial_prefill,
        "used_r8_raw_generation_cache": used_r8_raw_cache,
        "r8_raw_cache_key": prefilled.get("r8_raw_cache_key") if prefilled else None,
        "r7_cache_phase": globals().get("R7_CACHE_PHASE", "pre_handler"),
        "r7_cache_key": cache_key,
        "r7_cache_fingerprint": r7_runtime_fingerprint(pack=pack, prompt=prompt)[1] if "r7_runtime_fingerprint" in globals() else None,
        "used_r9_final_result_cache": False,
        "r9_final_cache_key": r9_key,
        "r9_final_cache_fingerprint": r9_final_result_fingerprint(pack=pack, prompt=prompt)[1] if "r9_final_result_fingerprint" in globals() else None,
        "runtime_seconds": round(time.time() - t0, 3),
    }
    if "R7_RUNTIME_STATS" in globals():
        R7_RUNTIME_STATS["generated_cases"] += 1
        R7_RUNTIME_STATS["runtime_seconds_sum_x1000"] += int(result["runtime_seconds"] * 1000)
        if used_batch_initial_prefill:
            R7_RUNTIME_STATS["used_batch_initial_prefill"] += 1
        if used_r8_raw_cache:
            R7_RUNTIME_STATS["used_r8_raw_generation_cache"] += 1
        if used_r13_return_focus_repair:
            R7_RUNTIME_STATS["r13_return_focus_repair_rows"] += 1
    if globals().get("R7_ENABLE_EXACT_RESULT_CACHE", True):
        if "R7_RESULT_CACHE" not in globals():
            globals()["R7_RESULT_CACHE"] = {}
        R7_RESULT_CACHE[cache_key] = copy.deepcopy(result)
    if globals().get("R9_ENABLE_SHARED_FINAL_RESULT_CACHE", True) and r9_key:
        if "R9_FINAL_RESULT_CACHE" not in globals():
            globals()["R9_FINAL_RESULT_CACHE"] = {}
        R9_FINAL_RESULT_CACHE[r9_key] = copy.deepcopy(result)
        if "R7_RUNTIME_STATS" in globals():
            R7_RUNTIME_STATS["r9_final_result_cache_stores"] += 1
    return result



# AF1K R11: global duplicate result cache across cells.
if "R11_GLOBAL_DEDUP_RESULT_CACHE" not in globals():
    R11_GLOBAL_DEDUP_RESULT_CACHE = {}
if "R11_FINISH_EVENTS" not in globals():
    R11_FINISH_EVENTS = []

# AF1K R10: guaranteed duplicate-runner.
def r10_dedup_key_for_case(case):
    """Build a stable key before generation so duplicates are not rerun.

    It includes normalized input, selected pack and prompt hash. This makes
    duplicate rows cache data while preventing cross-pack prompt drift.
    """
    front = front_half(case)
    pack = front["pack"]
    prompt = build_event_rail_prompt(pack)
    norm_input = r7_normalize_input(case) if "r7_normalize_input" in globals() else re.sub(r"\s+", " ", str(case or "")).strip()
    key_payload = {
        "input": norm_input,
        "pack_id": pack.get("pack_id"),
        "prompt_hash": r7_short_hash(prompt, 20) if "r7_short_hash" in globals() else hashlib.sha256(prompt.encode("utf-8")).hexdigest()[:20],
        "base_model": globals().get("BASE_MODEL_ID", None),
        "adapter_sha256": (globals().get("ADAPTER_AUDIT") or {}).get("adapter_sha256") if isinstance(globals().get("ADAPTER_AUDIT"), dict) else None,
    }
    key = "r10dedup::" + (r7_short_hash(key_payload, 24) if "r7_short_hash" in globals() else hashlib.sha256(json.dumps(key_payload, ensure_ascii=False, sort_keys=True).encode("utf-8")).hexdigest()[:24])
    return key, front, pack, prompt

def r10_clone_duplicate_result(result, case, dedup_key):
    import copy
    out = copy.deepcopy(result)
    out["input"] = case
    out["used_cache"] = True
    out["used_r10_duplicate_row_cache"] = True
    out["r10_dedup_key_reused"] = dedup_key
    out["r7_cache_note"] = "R10 duplicate input row cloned; e2e generation skipped."
    out["runtime_seconds"] = 0.0
    return out

def r10_run_cases(cases, label="r10_cases", print_rows=True):
    """R11 hardened duplicate runner.

    Executes only unique case keys, clones duplicate rows, and can reuse
    duplicate results across separate cells. Fail-soft mode ensures the
    notebook can still package a result ZIP even if an individual row errors.
    """
    cases = list(cases or [])
    if "R7_RUNTIME_STATS" not in globals():
        globals()["R7_RUNTIME_STATS"] = Counter()
    if "R11_GLOBAL_DEDUP_RESULT_CACHE" not in globals():
        globals()["R11_GLOBAL_DEDUP_RESULT_CACHE"] = {}
    if "R11_FINISH_EVENTS" not in globals():
        globals()["R11_FINISH_EVENTS"] = []

    if not globals().get("R10_GUARANTEED_DEDUP_RUNNER", True):
        results = []
        if "r7_prefill_cases" in globals():
            print("R7 PREFILL:", r7_prefill_cases(cases, label=label))
        for i, case in enumerate(cases, 1):
            try:
                r = e2e_generate_one(case)
            except Exception as e:
                if not globals().get("R11_FAIL_SOFT_ROW_ERRORS", True):
                    raise
                r = {
                    "input": case,
                    "error": repr(e),
                    "used_cache": False,
                    "used_r10_duplicate_row_cache": False,
                    "used_r11_error_row": True,
                    "runtime_seconds": 0.0,
                    "final_text": "",
                    "final_gate": {
                        "verdict": "ERROR",
                        "hard_fail": True,
                        "surface_hits": ["EXCEPTION"],
                        "lore_hits": [],
                        "quality_hits": [],
                        "length_chars": 0,
                    },
                }
                R11_FINISH_EVENTS.append({"label": label, "case_index": i, "error": repr(e)})
            results.append(r)
        return results

    prepared = []
    unique_cases = []
    unique_seen = {}
    for case in cases:
        dkey, front, pack, prompt = r10_dedup_key_for_case(case)
        prepared.append((case, dkey, front, pack, prompt))
        if dkey not in unique_seen and not (
            globals().get("R11_GLOBAL_DEDUP_ACROSS_CELLS", True)
            and dkey in globals().get("R11_GLOBAL_DEDUP_RESULT_CACHE", {})
        ):
            unique_seen[dkey] = len(unique_cases)
            unique_cases.append(case)

    duplicate_rows = len(cases) - len(unique_cases)
    R7_RUNTIME_STATS["r10_total_rows_requested"] += len(cases)
    R7_RUNTIME_STATS["r10_unique_cases"] += len(unique_cases)
    R7_RUNTIME_STATS["r10_duplicate_rows"] += duplicate_rows

    if unique_cases and "r7_prefill_cases" in globals():
        print("R7 PREFILL UNIQUE:", r7_prefill_cases(unique_cases, label=label + "_unique"))
    elif print_rows:
        print(f"[{label}] all {len(cases)} rows served from duplicate cache or empty case list.")

    generated_by_key = {}
    for ui, case in enumerate(unique_cases, 1):
        dkey, _front, _pack, _prompt = r10_dedup_key_for_case(case)
        try:
            r = e2e_generate_one(case)
            r["used_r10_duplicate_row_cache"] = False
            r["used_r11_global_dedup_cache"] = False
            r["used_r11_error_row"] = False
            r["r10_dedup_key"] = dkey
        except Exception as e:
            if not globals().get("R11_FAIL_SOFT_ROW_ERRORS", True):
                raise
            r = {
                "input": case,
                "error": repr(e),
                "used_cache": False,
                "used_r10_duplicate_row_cache": False,
                "used_r11_global_dedup_cache": False,
                "used_r11_error_row": True,
                "r10_dedup_key": dkey,
                "runtime_seconds": 0.0,
                "final_text": "",
                "final_gate": {
                    "verdict": "ERROR",
                    "hard_fail": True,
                    "surface_hits": ["EXCEPTION"],
                    "lore_hits": [],
                    "quality_hits": [],
                    "length_chars": 0,
                },
            }
            R11_FINISH_EVENTS.append({"label": label, "unique_index": ui, "error": repr(e)})

        generated_by_key[dkey] = r
        if globals().get("R11_GLOBAL_DEDUP_ACROSS_CELLS", True):
            R11_GLOBAL_DEDUP_RESULT_CACHE[dkey] = r
            R7_RUNTIME_STATS["r11_global_dedup_stores"] += 1

        if print_rows:
            g = r.get("final_gate", {})
            print(f"[{label} UNIQUE {ui}/{len(unique_cases)}] {r.get('front', {}).get('pack', {}).get('pack_id', _pack.get('pack_id'))} {g.get('verdict')} len={g.get('length_chars')} fb={r.get('used_fallback')} err={r.get('used_r11_error_row')}")

    results = []
    seen_output = set()
    for i, (case, dkey, front, pack, prompt) in enumerate(prepared, 1):
        if dkey in generated_by_key and dkey not in seen_output:
            r = generated_by_key[dkey]
            seen_output.add(dkey)
        elif globals().get("R11_GLOBAL_DEDUP_ACROSS_CELLS", True) and dkey in R11_GLOBAL_DEDUP_RESULT_CACHE:
            r = r10_clone_duplicate_result(R11_GLOBAL_DEDUP_RESULT_CACHE[dkey], case, dkey)
            r["used_r11_global_dedup_cache"] = True
            R7_RUNTIME_STATS["r11_global_dedup_hits"] += 1
        elif dkey in generated_by_key:
            r = r10_clone_duplicate_result(generated_by_key[dkey], case, dkey)
            r["used_r11_global_dedup_cache"] = False
            R7_RUNTIME_STATS["r10_duplicate_clone_hits"] += 1
        else:
            # Should be unreachable, but keep finish-mode robust.
            r = {
                "input": case,
                "error": "R11_MISSING_DEDUP_RESULT",
                "used_cache": False,
                "used_r10_duplicate_row_cache": False,
                "used_r11_global_dedup_cache": False,
                "used_r11_error_row": True,
                "r10_dedup_key": dkey,
                "runtime_seconds": 0.0,
                "final_text": "",
                "final_gate": {
                    "verdict": "ERROR",
                    "hard_fail": True,
                    "surface_hits": ["R11_MISSING_DEDUP_RESULT"],
                    "lore_hits": [],
                    "quality_hits": [],
                    "length_chars": 0,
                },
            }
            R11_FINISH_EVENTS.append({"label": label, "row_index": i, "error": "R11_MISSING_DEDUP_RESULT"})

        results.append(r)
        if print_rows:
            g = r.get("final_gate", {})
            print(f"[{label} ROW {i}/{len(cases)}] {pack.get('pack_id')} {g.get('verdict')} cache={r.get('used_cache')} r10dup={r.get('used_r10_duplicate_row_cache')} r11global={r.get('used_r11_global_dedup_cache')} err={r.get('used_r11_error_row')}")

    return results

# %%
#@title 11. Single full E2E test

import json

RUN_SINGLE_FULL_E2E = False  #@param {type:"boolean"}
USER_INPUT = "게임빙의 조연 NPC가 탑 17층 공략 뒤 외부 협회 공시의 최고층 갱신 기한을 보고 루트를 바꾸는 장면"  #@param {type:"string"}

single_result = None

if RUN_SINGLE_FULL_E2E:
    single_result = e2e_generate_one(USER_INPUT)

    print("INPUT =", single_result["input"])
    print("PRIMARY_PACK =", single_result["front"]["pack"]["pack_id"])
    print("SELECTION =", json.dumps(single_result["front"]["selection"], ensure_ascii=False))
    print("CONTEXTUAL_DATA =", json.dumps(single_result["front"]["pack"]["contextual_data"], ensure_ascii=False))
    print("EVENT_FLOW_RAILS =", json.dumps(single_result["front"]["pack"]["event_flow_rails"], ensure_ascii=False))
    print("VERDICT =", single_result["final_gate"]["verdict"])
    print("FINAL_ROUTE_MISS =", single_result["final_gate"]["final_route_miss"])
    print("SURFACE_HITS =", single_result["final_gate"]["surface_hits"])
    print("USED_SALVAGE =", single_result["used_salvage"])
    print("USED_FALLBACK =", single_result["used_fallback"])
    print("\n--- FINAL TEXT ---\n")
    print(single_result["final_text"])
else:
    print("Skipped single full E2E. Set RUN_SINGLE_FULL_E2E = False for one model generation.")

# %%
#@title 12. Blind stress cases

BLIND_CASES = [
    "탑 4층 공략 뒤 외부 협회 공시판의 최고층 갱신 기한이 당겨지고, 하급 공략자가 보상보다 다음 층 통행 조건을 먼저 확인하는 장면",
    "길드 공시판의 12층 소재 채집 의뢰를 실력 부족한 파티가 수주해 보상 분배보다 생존 문제로 갈라지는 장면",
    "보스전 직전 상태창 차단 설정을 켠 주인공이 탑 시험 뒤 협회 기록관의 갱신표를 확인하는 장면",
    "이미 클리어한 하층으로는 돌아갈 수 없어 주인공이 다음 층 공략 루트를 다시 고르는 장면",
    "탑 입장 통행증 발급 기준이 바뀌어 협회 접수대에서 하급 공략자의 신청이 보류되는 장면",
    "같은 층의 공략 기록이 서로 다르게 남아 히든피스를 암시하고, 조연 공략자가 다음 문을 고르는 장면",

    "천해 위 비공선에서 천해석 부력낭이 찢어지고 포경 장비가 한쪽으로 쏠리는 장면",
    "천령석 코어가 떨리는 대형 군용선에서 기관사가 증기 압력을 낮추지 못하는 장면",
    "공어 어군이 비처럼 쏟아지는 천해 항로에서 선장이 지상식 나침반을 의심하는 장면",
    "부유암괴 사이를 지나던 소형선이 천해석만으로 버티다 난류에 밀리는 장면",
    "지상 전쟁 기술로 만든 프로펠러가 천해 난류에서 멈추고 고래기름 냄새가 번지는 장면",
    "천해 항구의 권양기 앞에서 포경선 선원이 천령석과 천해석을 헷갈린 신입을 꾸짖는 장면",

    "악역영애가 연회장에서 약혼 계약서의 세 번째 조항을 공개적으로 뒤집는 장면",
    "공작가 초대장 봉랍이 다른 색으로 찍혀 있어 황녀의 좌석 배치가 흔들리는 장면",
    "후견 계약을 앞둔 응접실에서 가문 문장을 단 장갑 하나가 사라지는 장면",
    "로판 악역영애가 미연시 게임빙의 사실을 숨긴 채 연회장에서 호감도 루트를 비트는 장면",
    "가문 계약서가 공개되는 밤, 주인공이 침묵하면 평판이 죽고 말하면 동맹이 깨지는 장면",
    "황태자와의 약혼 발표 직전 초대장 명단에서 이름 하나가 지워진 장면",

    "폭풍 때문에 고립된 저택에서 손님들의 알리바이가 시계 한 칸씩 어긋나는 추리 장면",
    "밀실 서재에서 촛대는 제자리에 있는데 찻잔 손잡이 방향만 바뀐 장면",
    "탐정이 용의자 여섯 명의 진술 중 하녀의 장갑 단추만 다시 묻는 장면",
    "크리스티풍 폐쇄 저택에서 사라진 열쇠보다 젖은 발자국의 위치가 더 이상한 장면",
    "저택 만찬 뒤 살인 사건이 벌어지고 모든 용의자가 같은 시간표를 들고 있는 장면",
    "탐정이 살인 현장보다 먼저 식지 않은 찻잔을 보고 질문 순서를 바꾸는 장면",

    "파멸 직전 회귀한 주인공이 과거 날짜가 하루 어긋난 것을 보고 첫 선택을 바꾸는 장면",
    "두 번째 삶을 시작한 후계자가 오래된 편지를 태우려다 미래와 다른 문장을 발견하는 장면",
    "회귀자가 알고 있던 암살 시각이 빗나가고, 낯익은 상처만 그대로 남은 장면",
    "멸망을 막으려는 주인공이 쉬운 복수 대신 아무도 믿지 않을 경고를 먼저 남기는 장면",
    "회귀 후 첫 연회에서 예정된 모욕이 일어나지 않아 주인공의 미래 지식이 흔들리는 장면",
    "과거로 돌아온 공략자가 탑의 첫 의뢰 보상이 기억과 달라진 걸 발견하는 장면",
]

print("blind_cases =", len(BLIND_CASES))

# %%
#@title 12B. AF1C Tower-focused lore stress cases

TOWER_FOCUSED_CASES_AF1C = [
    "탑 4층 공략 뒤 외부 협회 공시판의 최고층 갱신 기한이 당겨지고, 하급 공략자가 보상보다 다음 층 통행 조건을 먼저 확인하는 장면",
    "길드 공시판의 12층 소재 채집 의뢰를 실력 부족한 파티가 수주해 보상 분배보다 생존 문제로 갈라지는 장면",
    "보스전 직전 상태창 차단 설정을 켠 주인공이 탑 시험 뒤 협회 기록관의 갱신표를 확인하는 장면",
    "이미 클리어한 하층으로는 돌아갈 수 없어 주인공이 다음 층 공략 루트를 다시 고르는 장면",
    "탑 입장 통행증 발급 기준이 바뀌어 협회 접수대에서 하급 공략자의 신청이 보류되는 장면",
    "같은 층의 공략 기록이 서로 다르게 남아 히든피스를 암시하고, 조연 공략자가 다음 문을 고르는 장면",
]

RUN_TOWER_FOCUSED_STRESS = False  #@param {type:"boolean"}

tower_focused_results = []
if RUN_TOWER_FOCUSED_STRESS:
    tower_focused_results = r10_run_cases(TOWER_FOCUSED_CASES_AF1C, label="tower_focused")
else:
    print("Skipped Tower-focused stress. Set RUN_TOWER_FOCUSED_STRESS=True to run.")

# %%
#@title 12C. AF1E mixed fallback/length stress cases

AF1E_MIXED_LENGTH_CASES = [
    "천해 위 비공선에서 천해석 부력낭이 찢어지고 포경 장비가 한쪽으로 쏠리는 장면",
    "공어 어군이 비처럼 쏟아지는 천해 항로에서 선장이 지상식 나침반을 의심하는 장면",
    "악역영애가 연회장에서 약혼 계약서의 세 번째 조항을 공개적으로 뒤집는 장면",
    "후견 계약을 앞둔 응접실에서 가문 문장을 단 장갑 하나가 사라지는 장면",
    "폭풍 때문에 고립된 저택에서 손님들의 알리바이가 시계 한 칸씩 어긋나는 추리 장면",
    "탐정이 살인 현장보다 먼저 식지 않은 찻잔을 보고 질문 순서를 바꾸는 장면",
    "파멸 직전 회귀한 주인공이 과거 날짜가 하루 어긋난 것을 보고 첫 선택을 바꾸는 장면",
    "회귀 후 첫 연회에서 예정된 모욕이 일어나지 않아 주인공의 미래 지식이 흔들리는 장면",
]

RUN_AF1E_MIXED_LENGTH_STRESS = False  #@param {type:"boolean"}

af1e_mixed_results = []
if RUN_AF1E_MIXED_LENGTH_STRESS:
    af1e_mixed_results = r10_run_cases(AF1E_MIXED_LENGTH_CASES, label="af1e_mixed")
else:
    print("Skipped AF1E mixed stress. Set RUN_AF1E_MIXED_LENGTH_STRESS=True to run.")

# %%
#@title 12D. AF1G min-length enforcer stress cases

AF1G_MINLEN_STRESS_CASES = [
    "탑 4층 공략 뒤 외부 협회 공시판의 최고층 갱신 기한이 당겨지고, 하급 공략자가 보상보다 다음 층 통행 조건을 먼저 확인하는 장면",
    "길드 공시판의 12층 소재 채집 의뢰를 실력 부족한 파티가 수주해 보상 분배보다 생존 문제로 갈라지는 장면",
    "천해 위 비공선에서 천해석 부력낭이 찢어지고 포경 장비가 한쪽으로 쏠리는 장면",
    "공어 어군이 비처럼 쏟아지는 천해 항로에서 선장이 지상식 나침반을 의심하는 장면",
    "악역영애가 연회장에서 약혼 계약서의 세 번째 조항을 공개적으로 뒤집는 장면",
    "후견 계약을 앞둔 응접실에서 가문 문장을 단 장갑 하나가 사라지는 장면",
    "폭풍 때문에 고립된 저택에서 손님들의 알리바이가 시계 한 칸씩 어긋나는 추리 장면",
    "탐정이 살인 현장보다 먼저 식지 않은 찻잔을 보고 질문 순서를 바꾸는 장면",
    "파멸 직전 회귀한 주인공이 과거 날짜가 하루 어긋난 것을 보고 첫 선택을 바꾸는 장면",
    "회귀 후 첫 연회에서 예정된 모욕이 일어나지 않아 주인공의 미래 지식이 흔들리는 장면",
]

RUN_AF1G_MINLEN_STRESS = False  #@param {type:"boolean"}

af1g_minlen_results = []
if RUN_AF1G_MINLEN_STRESS:
    af1g_minlen_results = r10_run_cases(AF1G_MINLEN_STRESS_CASES, label="af1g_minlen")
else:
    print("Skipped AF1G minlen stress. Set RUN_AF1G_MINLEN_STRESS=True to run.")

# %%
#@title 12E. AF1H quality/length control quick check
import json

AF1H_QUICK_CHECK_CASES = [
    "탑 4층 공략 뒤 외부 협회 공시판의 최고층 갱신 기한이 당겨지고, 하급 공략자가 보상보다 다음 층 통행 조건을 먼저 확인하는 장면",
    "길드 공시판의 12층 소재 채집 의뢰를 실력 부족한 파티가 수주해 보상 분배보다 생존 문제로 갈라지는 장면",
    "천해 위 비공선에서 천해석 부력낭이 찢어지고 포경 장비가 한쪽으로 쏠리는 장면",
    "악역영애가 연회장에서 약혼 계약서의 세 번째 조항을 공개적으로 뒤집는 장면",
    "폭풍 때문에 고립된 저택에서 손님들의 알리바이가 시계 한 칸씩 어긋나는 추리 장면",
]

RUN_AF1H_QUICK_CHECK = False  #@param {type:"boolean"}

af1h_quick_results = []
if RUN_AF1H_QUICK_CHECK:
    print("OUTPUT_LENGTH_PRESET =", OUTPUT_LENGTH_PRESET)
    print("MIN_FINAL_CHARS_BY_PACK =", json.dumps(apply_length_preset(), ensure_ascii=False, indent=2))
    af1h_quick_results = r10_run_cases(AF1H_QUICK_CHECK_CASES, label="af1h_quick")
else:
    print("Skipped AF1H quick check. Set RUN_AF1H_QUICK_CHECK=True to run.")
    print("Current OUTPUT_LENGTH_PRESET =", globals().get("OUTPUT_LENGTH_PRESET", "standard"))
    print("Current MIN_FINAL_CHARS_BY_PACK =", json.dumps(globals().get("MIN_FINAL_CHARS_BY_PACK", {}), ensure_ascii=False, indent=2))

# %%
#@title 13. Run blind stress

RUN_BLIND_STRESS = False  #@param {type:"boolean"}
MAX_CASES = 30  #@param {type:"integer"}

blind_results = []

if RUN_BLIND_STRESS:
    cases = BLIND_CASES[:MAX_CASES]
    blind_results = r10_run_cases(cases, label="blind")
else:
    print("Skipped blind stress. Set RUN_BLIND_STRESS=True to run.")

# %%
#@title 13A-0. AF1K R19 run mode guide

print("""
R19 fast frontend default:

FAST DEFAULT, no model generation:
- RUN_SINGLE_FULL_E2E = False
- RUN_R14_ROTATING_BLIND = False
- RUN_R16_MAX_DIVERSITY_STRESS = False
- RUN_R18_GENRE_KNOWLEDGE_MAX_INPUTS = False
- RUN_AF1J_BALANCED_BLIND = False
- RUN_AF1K_POST_HANDLER_BLIND = False

Use these modes only when you intentionally want generation:

1) one sample:
   RUN_SINGLE_FULL_E2E = False

2) quick diversity:
   RUN_R18_GENRE_KNOWLEDGE_MAX_INPUTS = False
   R18_KNOWLEDGE_DIVERSITY_PROFILE = "quick_48"

3) full frontier:
   RUN_R18_GENRE_KNOWLEDGE_MAX_INPUTS = False
   R18_KNOWLEDGE_DIVERSITY_PROFILE = "frontier_120"

4) brutal max:
   RUN_R18_GENRE_KNOWLEDGE_MAX_INPUTS = False
   R18_KNOWLEDGE_DIVERSITY_PROFILE = "max_240"
""")

# %%
#@title 13A-2. AF1K R17 Tower no-reentry lore smoke

import json

RUN_R17_TOWER_NO_REENTRY_SMOKE = True  #@param {type:"boolean"}

R17_TOWER_NO_REENTRY_SMOKE_REPORT = None

def r19_tower_smoke_blob(pack):
    """Check generated pack substance, not the full prompt ban guidance."""
    payload = {
        "event_flow_rails": pack.get("event_flow_rails", {}),
        "materiality_rails": pack.get("materiality_rails", {}),
        "generated_pack_overlay": pack.get("generated_pack_overlay", {}),
        "genre_boundary": (pack.get("genre_data", {}) or {}).get("genre_boundary", ""),
        "pack_qa_report": pack.get("pack_qa_report", {}),
    }
    return json.dumps(payload, ensure_ascii=False)

if RUN_R17_TOWER_NO_REENTRY_SMOKE:
    smoke_cases = [
        "이미 클리어한 하층으로는 돌아갈 수 없어 주인공이 다음 층 공략 루트를 다시 고르는 장면",
        "탑 4층 공략 뒤 외부 협회 공시판의 최고층 갱신 기한이 당겨지고, 하급 공략자가 다음 층 통행 조건을 먼저 확인하는 장면",
        "특수 균열 때문에 예외적으로 클리어한 3층 문이 다시 열려 협회 기록관이 비정상 여부를 조사하는 장면",
    ]

    routine_terms = ["재입장 제한", "하층 재입장", "재방문 제한", "반복 파밍 대신", "쉬운 반복 파밍"]

    rows = []
    ok = True

    for case in smoke_cases:
        front = front_half(case)
        pack = front["pack"]
        prompt = build_event_rail_prompt(pack)
        generated_overlay = pack.get("generated_pack_overlay", {})
        qa = pack.get("pack_qa_report", {})

        rail_blob = r19_tower_smoke_blob(pack)
        rails_have_routine_reentry = any(term in rail_blob for term in routine_terms)
        prompt_mentions_ban_guidance = any(term in prompt for term in routine_terms)
        is_exception = any(
            x in case
            for x in globals().get(
                "R17_TOWER_EXCEPTION_TERMS",
                ["예외", "이례", "특수 허가", "균열", "오류", "붕괴", "비정상"],
            )
        )

        passed = (
            pack.get("pack_id") == "TOWER_SYSTEM_RULE"
            and (is_exception or not rails_have_routine_reentry)
            and qa.get("verdict") in ["PASS", "WATCH"]
        )

        ok = ok and passed
        rows.append({
            "input": case,
            "pack_id": pack.get("pack_id"),
            "pack_instance_id": generated_overlay.get("pack_instance_id"),
            "qa": qa,
            "rails_have_routine_reentry": rails_have_routine_reentry,
            "prompt_mentions_ban_guidance": prompt_mentions_ban_guidance,
            "exception_case": is_exception,
            "passed": passed,
        })

    R17_TOWER_NO_REENTRY_SMOKE_REPORT = {
        "passed": ok,
        "note": "R19 checks generated rails/materials, not full prompt ban guidance.",
        "rows": rows,
    }

    print(json.dumps(R17_TOWER_NO_REENTRY_SMOKE_REPORT, ensure_ascii=False, indent=2))
    assert ok, "R17 Tower no-reentry smoke failed."
else:
    print("Skipped R17 Tower no-reentry smoke.")

# %%
#@title 13A-1. AF1K R15 dynamic pack regeneration smoke test

import json

RUN_R15_PACK_REGEN_SMOKE = True  #@param {type:"boolean"}

R15_PACK_REGEN_SMOKE_REPORT = None

if RUN_R15_PACK_REGEN_SMOKE:
    smoke_cases = [
        "죽은 남작의 찻잔 손잡이 방향이 평소 습관과 달라 탐정이 차를 따른 순서를 다시 묻는 장면",
        "파멸 직전으로 돌아온 주인공이 복수 대상을 만나기 전 날짜가 하루 어긋난 편지를 발견하는 장면",
        "길드가 14층 소재 채집을 의뢰했지만 최고 기록 8층인 파티가 수락 여부를 두고 갈라지는 장면",
        "천해 난류 속에서 증기 권양기가 멈추고 선장이 고래보다 찢어진 부력낭을 먼저 살리는 장면",
        "연회장에서 약혼 발표 직전 좌석표가 바뀐 것을 본 영애가 축배 대신 조항의 날짜를 묻는 장면",
    ]
    rows = []
    ok = True
    ids = []
    for case in smoke_cases:
        front = front_half(case)
        pack = front["pack"]
        qa = pack.get("pack_qa_report", {})
        inst = pack.get("generated_pack_overlay", {})
        ids.append(inst.get("pack_instance_id"))
        passed = bool(inst.get("pack_instance_id")) and qa.get("verdict") in ["PASS", "WATCH"]
        ok = ok and passed
        rows.append({
            "input": case,
            "pack_id": pack.get("pack_id"),
            "pack_instance_id": inst.get("pack_instance_id"),
            "selected_materials": inst.get("selected_materials"),
            "event_delta": inst.get("event_delta"),
            "qa": qa,
            "passed": passed,
        })

    unique_ids = len(set(ids)) == len(ids)
    ok = ok and unique_ids

    R15_PACK_REGEN_SMOKE_REPORT = {
        "passed": ok,
        "unique_pack_instance_ids": unique_ids,
        "rows": rows,
    }
    print(json.dumps(R15_PACK_REGEN_SMOKE_REPORT, ensure_ascii=False, indent=2))
    if globals().get("R15_PACK_REGEN_SMOKE_REQUIRED", True):
        assert ok, "R15 dynamic pack regeneration smoke failed."
else:
    print("Skipped R15 pack regen smoke.")

# %%
#@title 13A0. AF1K R13 router smoke test

import json

RUN_R13_ROUTER_SMOKE = True  #@param {type:"boolean"}

R13_ROUTER_SMOKE_REPORT = None

if RUN_R13_ROUTER_SMOKE:
    smoke_cases = [
        ("죽은 남작의 찻잔 손잡이 방향이 평소 습관과 달라 탐정이 차를 따른 순서를 다시 묻는 장면", "CLOSED_CIRCLE_MYSTERY"),
        ("회귀 첫날 주인공이 예정된 암살자가 나타나지 않자 미래 지식보다 사라진 하인의 이름을 먼저 확인하는 장면", "RETURN_FANTASY"),
        ("파멸 직전으로 돌아온 주인공이 복수 대상을 만나기 전 날짜가 하루 어긋난 편지를 발견하는 장면", "RETURN_FANTASY"),
        ("두 번째 삶의 연회에서 원래 있어야 할 모욕이 사라져 주인공이 적이 먼저 움직였음을 깨닫는 장면", "RETURN_FANTASY"),
        ("연회장에서 약혼 발표 직전 좌석표가 바뀐 것을 본 영애가 축배 대신 조항의 날짜를 묻는 장면", "ROMANTASY_HOUSE_CONTRACT"),
    ]
    rows = []
    ok = True
    for case, expected in smoke_cases:
        front = front_half(case)
        got = front["pack"]["pack_id"]
        passed = (got == expected)
        ok = ok and passed
        rows.append({
            "input": case,
            "expected": expected,
            "got": got,
            "passed": passed,
            "selection": front["selection"],
            "overlay_tags": front["tag_bundle"]["overlay_tags"],
        })
    R13_ROUTER_SMOKE_REPORT = {"passed": ok, "rows": rows}
    print(json.dumps(R13_ROUTER_SMOKE_REPORT, ensure_ascii=False, indent=2))
    if globals().get("R13_ROUTER_SMOKE_REQUIRED", True):
        assert ok, "R13 router smoke failed."
else:
    print("Skipped R13 router smoke.")

# %%
#@title 13A1. AF1K R14 rotating blind holdout

from collections import Counter, defaultdict
import datetime
import json
import random
import re

RUN_R14_ROTATING_BLIND = False  #@param {type:"boolean"}

R14_ROTATING_BLIND_REPORT = None
r14_rotating_blind_results = []

def r14_make_seed():
    seed = globals().get("R14_ROTATING_BLIND_SEED", None)
    if seed is None:
        # KST timestamp seed: reproducible once logged, different across runs.
        now = datetime.datetime.utcnow() + datetime.timedelta(hours=9)
        seed = int(now.strftime("%Y%m%d%H%M%S"))
        globals()["R14_ROTATING_BLIND_SEED"] = seed
    return int(seed)


def r16_has_final_consonant(word):
    if not word:
        return False
    ch = str(word)[-1]
    code = ord(ch)
    if 0xAC00 <= code <= 0xD7A3:
        return ((code - 0xAC00) % 28) != 0
    # Latin/number fallback: treat most consonant-ending as batchim.
    return ch.lower()[-1:] not in "aeiou"

def r16_josa_ga(word):
    return "이" if r16_has_final_consonant(word) else "가"

def r16_josa_eun(word):
    return "은" if r16_has_final_consonant(word) else "는"

def r14_build_candidate_cases(seed=None):
    rng = random.Random(r14_make_seed() if seed is None else seed)

    banks = {
        "TOWER_SYSTEM_RULE": {
            "actors": ["신참 공략자", "중층 파티장", "협회 기록관", "통행증 담당자", "길드 의뢰 접수원"],
            "objects": ["돌파 이력 봉인", "최고층 갱신표", "상층 소재 의뢰서", "서로 다른 공략 기록", "만료 직전 통행증"],
            "pressures": ["하층 정체를 포기하는", "기한이 앞당겨진 이유를 따지는", "실력보다 높은 층 의뢰를 거절해야 하는", "숨은 조건을 의심하는"],
        },
        "AETHER_WHALERS": {
            "actors": ["비공선 항해사", "포경선 기관장", "천해 관측수", "지상 정찰병", "부력낭 수리공"],
            "objects": ["천해석 파편", "찢어진 부력낭", "멈춘 증기 권양기", "공어 비", "난류 지도"],
            "pressures": ["고래보다 선체를 먼저 살리는", "포격으로 오인한 현상을 천해 조류로 고치는", "기존 항로를 포기하는", "내연기관 실험을 중단하는"],
        },
        "ROMANTASY_HOUSE_CONTRACT": {
            "actors": ["악역영애", "공작가 후견인", "계약 증인", "연회장 시종", "가문 변호인"],
            "objects": ["봉랍 눌림", "좌석표 변경", "사라진 장갑", "계약서 세 번째 조항", "축배 전 서명란"],
            "pressures": ["감정보다 조항 날짜를 먼저 묻는", "약혼 발표를 거래 조건으로 되돌리는", "증언 순서를 바꾸는", "체면보다 문장 하나를 확인하는"],
        },
        "CLOSED_CIRCLE_MYSTERY": {
            "actors": ["탐정", "별장 주인", "남작의 하녀", "알리바이를 맞춘 손님", "젖은 발자국을 본 의사"],
            "objects": ["식지 않은 찻잔", "마른 창틀", "사라진 촛불", "손잡이 방향이 바뀐 컵", "잠긴 서랍"],
            "pressures": ["사라진 열쇠보다 배치를 먼저 보는", "모두의 알리바이에서 시간 차를 묻는", "증언보다 물건의 위치를 다시 확인하는", "닫힌 방의 순서를 뒤집는"],
        },
        "RETURN_FANTASY": {
            "actors": ["회귀한 주인공", "두 번째 삶의 귀족", "파멸을 기억하는 후계자", "미래 지식에 의존하던 책사", "첫 번째 삶에서 죽었던 하인"],
            "objects": ["하루 어긋난 편지", "사라진 예정된 모욕", "오지 않은 암살자", "첫 번째 삶의 명단", "기억과 다른 초대장"],
            "pressures": ["복수보다 기억의 오차를 먼저 확인하는", "미래 지식의 균열을 받아들이는", "원래 죽어야 할 사람이 살아 있는 이유를 찾는", "파멸 날짜가 바뀐 원인을 좇는"],
        },
        "GENERAL_WEBNOVEL": {
            "actors": ["방 안의 주인공", "낡은 건물의 관리인", "문밖의 감시자", "빗속의 증인", "작은 서랍을 여는 인물"],
            "objects": ["젖은 단추", "작은 서랍", "문틈 종이", "숨긴 물건", "멈춘 발소리"],
            "pressures": ["큰 문보다 작은 단서를 택하는", "누가 먼저 들어왔는지 추적하는", "시선이 바뀐 순간을 읽는", "선택의 비용을 확인하는"],
        },
    }

    candidates = []
    for pack_id, b in banks.items():
        for _ in range(8):
            actor = rng.choice(b["actors"])
            obj = rng.choice(b["objects"])
            pressure = rng.choice(b["pressures"])
            case = f"{actor}{r16_josa_ga(actor)} {obj} 때문에 {pressure} 장면"
            candidates.append({"expected_pack": pack_id, "input": case})

    rng.shuffle(candidates)
    return candidates

def r14_select_cases(n=None, seed=None):
    n = int(n or globals().get("R14_ROTATING_BLIND_CASES_N", 12))
    seed = r14_make_seed() if seed is None else int(seed)
    rng = random.Random(seed)
    candidates = r14_build_candidate_cases(seed)
    selected = []

    if globals().get("R14_ROTATING_BLIND_REQUIRE_PACK_COVERAGE", True):
        by_pack = defaultdict(list)
        for c in candidates:
            by_pack[c["expected_pack"]].append(c)
        for pack_id in sorted(by_pack):
            rng.shuffle(by_pack[pack_id])
            if by_pack[pack_id]:
                selected.append(by_pack[pack_id].pop())

    rest = [c for c in candidates if c not in selected]
    rng.shuffle(rest)
    for c in rest:
        if len(selected) >= n:
            break
        selected.append(c)

    return selected[:n]

if RUN_R14_ROTATING_BLIND and globals().get("R14_ENABLE_ROTATING_BLIND_HOLDOUT", True):
    seed = r14_make_seed()
    selected = r14_select_cases(globals().get("R14_ROTATING_BLIND_CASES_N", 12), seed)
    cases = [c["input"] for c in selected]

    print("R14 rotating blind seed:", seed)
    print("R14 rotating blind selected:")
    for i, c in enumerate(selected, 1):
        print(f"  {i:02d}. [{c['expected_pack']}] {c['input']}")

    r14_rotating_blind_results = r20_run_cases_with_budget(cases, label="r14_rotating_blind") if "r20_run_cases_with_budget" in globals() else r10_run_cases(cases, label="r14_rotating_blind")

    rows = []
    for meta, result in zip(selected, r14_rotating_blind_results):
        got = (
            result.get("front", {}).get("pack", {}).get("pack_id")
            or result.get("pack", {}).get("pack_id")
            or "UNKNOWN"
        )
        rows.append({
            "input": meta["input"],
            "expected_pack_family": meta["expected_pack"],
            "got_pack": got,
            "verdict": (result.get("final_gate", {}) or {}).get("verdict"),
            "used_cache": result.get("used_cache"),
            "used_r10_duplicate_row_cache": result.get("used_r10_duplicate_row_cache"),
            "used_r11_global_dedup_cache": result.get("used_r11_global_dedup_cache"),
        })

    R14_ROTATING_BLIND_REPORT = {
        "enabled": True,
        "seed": seed,
        "case_count": len(selected),
        "expected_pack_counts": dict(Counter(c["expected_pack"] for c in selected)),
        "got_pack_counts": dict(Counter(r["got_pack"] for r in rows)),
        "verdict_counts": dict(Counter(r["verdict"] for r in rows)),
        "rows": rows,
    }
    print(json.dumps(R14_ROTATING_BLIND_REPORT, ensure_ascii=False, indent=2))
else:
    R14_ROTATING_BLIND_REPORT = {"enabled": False}
    print("Skipped R14 rotating blind holdout.")

# %%
#@title 13A2. AF1K R16 max diversity front stress

from collections import Counter, defaultdict
import datetime
import json
import random
import re

RUN_R16_MAX_DIVERSITY_STRESS = False  #@param {type:"boolean"}

R16_MAX_DIVERSITY_REPORT = None
r16_max_diversity_results = []

def r16_seed():
    seed = globals().get("R16_DIVERSITY_SEED", None)
    if seed is None:
        now = datetime.datetime.utcnow() + datetime.timedelta(hours=9)
        seed = int(now.strftime("%Y%m%d%H%M%S"))
        globals()["R16_DIVERSITY_SEED"] = seed
    return int(seed)

def r16_target_n():
    prof = str(globals().get("R16_DIVERSITY_PROFILE", "frontier_48"))
    if prof == "quick_24":
        return 24
    if prof == "max_72":
        return 72
    return 48

def r16_final_consonant(word):
    if not word:
        return False
    ch = str(word)[-1]
    code = ord(ch)
    if 0xAC00 <= code <= 0xD7A3:
        return ((code - 0xAC00) % 28) != 0
    return ch.lower()[-1:] not in "aeiou"

def r16_ga(word):
    return "이" if r16_final_consonant(word) else "가"

def r16_eun(word):
    return "은" if r16_final_consonant(word) else "는"

def r16_build_banks():
    return {
        "TOWER_SYSTEM_RULE": {
            "actors": ["하급 공략자", "중층 파티장", "협회 기록관", "길드 의뢰 담당자", "상태창을 끈 조연 NPC", "통행증 심사관"],
            "objects": ["최고층 갱신표", "돌파 이력 봉인", "서로 다른 공략 기록", "상층 소재 의뢰서", "기한이 줄어든 통행증", "보상함 뒤의 측면 계단"],
            "actions": ["하층 정체를 포기하는", "무리한 의뢰 수락을 막는", "히든피스 조건을 의심하는", "보스전 직전 UI를 끄는", "상층 기한이 더 널널한 이유를 읽는"],
            "overlays": ["게임빙의 조연 NPC가", "회귀자가 아닌 신참이", "파티장이 대사 없이", ""],
        },
        "AETHER_WHALERS": {
            "actors": ["비공선 항해사", "포경선 기관장", "천해 관측수", "지상 정찰병", "부력낭 수리공", "고래기름 실험 기사"],
            "objects": ["천해석 파편", "찢어진 부력낭", "멈춘 증기 권양기", "공어 비", "난류 지도", "실험용 내연기관"],
            "actions": ["고래보다 선체를 먼저 살리는", "포격 오인을 천해 조류로 정정하는", "기존 항로를 버리는", "지상식 판단이 틀렸음을 인정하는", "천령석 코어와 천해석 부력을 구분하는"],
            "overlays": ["변방 선원이", "지상 전쟁 기술을 모르는 항해사가", "정찰병의 기록으로", ""],
        },
        "ROMANTASY_HOUSE_CONTRACT": {
            "actors": ["악역영애", "공작가 후견인", "계약 증인", "연회장 시종", "가문 변호인", "약혼 발표 직전의 영애"],
            "objects": ["봉랍 눌림", "좌석표 변경", "사라진 장갑", "계약서 세 번째 조항", "축배 전 서명란", "찻잔 받침의 얇은 고리"],
            "actions": ["감정보다 조항 날짜를 먼저 묻는", "약혼 발표를 거래 조건으로 되돌리는", "증언 순서를 바꾸는", "체면보다 서명 위치를 확인하는", "후견 계약의 비용을 공개하는"],
            "overlays": ["게임빙의 악역영애가", "회귀가 아닌 계약 당사자가", "대화 장면에서", ""],
        },
        "CLOSED_CIRCLE_MYSTERY": {
            "actors": ["탐정", "남작의 하녀", "별장 주인", "알리바이를 맞춘 손님", "젖은 발자국을 본 의사", "창틀을 닦던 시종"],
            "objects": ["식지 않은 찻잔", "마른 창틀", "사라진 촛불", "손잡이 방향이 바뀐 컵", "젖은 발자국", "잠긴 서랍"],
            "actions": ["사라진 열쇠보다 배치를 먼저 보는", "모두의 알리바이에서 시간 차를 묻는", "증언보다 물건의 위치를 다시 확인하는", "닫힌 방의 순서를 뒤집는", "공정한 단서만으로 다음 질문을 고르는"],
            "overlays": ["회귀 없이", "연회장 옆 별채에서", "대사 중심으로", ""],
        },
        "RETURN_FANTASY": {
            "actors": ["회귀한 주인공", "두 번째 삶의 귀족", "파멸을 기억하는 후계자", "미래 지식에 의존하던 책사", "첫 번째 삶에서 죽었던 하인", "복수를 미룬 주인공"],
            "objects": ["하루 어긋난 편지", "사라진 예정된 모욕", "오지 않은 암살자", "첫 번째 삶의 명단", "기억과 다른 초대장", "죽어야 할 사람이 남긴 서명"],
            "actions": ["복수보다 기억의 오차를 먼저 확인하는", "미래 지식의 균열을 받아들이는", "원래 죽어야 할 사람이 살아 있는 이유를 찾는", "파멸 날짜가 바뀐 원인을 좇는", "두 번째 삶의 선택 비용을 계산하는"],
            "overlays": ["연회장에서", "계약서 앞에서", "탐정처럼 단정하지 않고", ""],
        },
        "GENERAL_WEBNOVEL": {
            "actors": ["방 안의 주인공", "낡은 건물의 관리인", "문밖의 감시자", "빗속의 증인", "작은 서랍을 여는 인물", "단추를 숨긴 아이"],
            "objects": ["젖은 단추", "작은 서랍", "문틈 종이", "숨긴 물건", "멈춘 발소리", "방 안의 시선 변화"],
            "actions": ["큰 문보다 작은 단서를 택하는", "누가 먼저 들어왔는지 추적하는", "시선이 바뀐 순간을 읽는", "선택의 비용을 확인하는", "가장 위험한 물건을 숨기는"],
            "overlays": ["장르 표면어 없이", "짧은 대화 사이에서", "프롤로그 첫 장면으로", ""],
        },
    }

def r16_build_cases(seed=None, target_n=None):
    rng = random.Random(r16_seed() if seed is None else int(seed))
    banks = r16_build_banks()
    cases = []

    # Balanced core: pack coverage with different overlays.
    for pack_id, b in banks.items():
        combos = []
        for actor in b["actors"]:
            for obj in b["objects"]:
                for action in b["actions"]:
                    overlay = rng.choice(b["overlays"])
                    subj = f"{actor}{r16_ga(actor)}"
                    prefix = (overlay + " ") if overlay else ""
                    case = f"{prefix}{subj} {obj} 때문에 {action} 장면"
                    combos.append({"expected_pack_family": pack_id, "input": re.sub(r"\\s+", " ", case).strip(), "source": "pack_bank"})
        rng.shuffle(combos)
        cases.extend(combos[:8])

    # Ambiguity traps and negative controls.
    traps = [
        ("CLOSED_CIRCLE_MYSTERY", "죽은 남작의 찻잔 손잡이 방향이 평소 습관과 달라 탐정이 차를 따른 순서를 다시 묻는 장면"),
        ("GENERAL_WEBNOVEL", "작은 서랍을 여는 인물이 문틈 종이 때문에 큰 문보다 작은 선택을 택하는 장면"),
        ("RETURN_FANTASY", "연회장에서 두 번째 삶의 주인공이 원래 있어야 할 모욕이 사라진 이유를 확인하는 장면"),
        ("ROMANTASY_HOUSE_CONTRACT", "연회장에서 약혼 발표 직전 좌석표가 바뀌자 영애가 축배 대신 조항 날짜를 묻는 장면"),
        ("TOWER_SYSTEM_RULE", "게임빙의 조연 NPC가 보스전 직전 상태창을 끄고 협회 최고층 갱신표를 확인하는 장면"),
        ("AETHER_WHALERS", "지상 정찰병이 공어 비를 포격으로 오인하자 항해사가 천해 조류와 부력낭 손상을 먼저 확인하는 장면"),
        ("CLOSED_CIRCLE_MYSTERY", "회귀가 아니라 기억력이 좋은 탐정이 모두의 알리바이를 다시 묻는 장면"),
        ("RETURN_FANTASY", "탐정처럼 단정하지 않고 회귀한 주인공이 하루 어긋난 편지 때문에 복수를 미루는 장면"),
        ("TOWER_SYSTEM_RULE", "탑이 아니라 길드가 14층 소재 채집을 의뢰했지만 최고 기록 8층인 파티가 거절하는 장면"),
        ("ROMANTASY_HOUSE_CONTRACT", "후견 계약을 앞둔 응접실에서 사라진 장갑 하나 때문에 공작가 증언 순서가 바뀌는 장면"),
        ("GENERAL_WEBNOVEL", "문밖의 발소리가 멈춘 뒤 주인공이 방 안 시선 변화만으로 위험한 물건을 숨기는 장면"),
        ("AETHER_WHALERS", "소형 부유암괴 옆 천해석 파편이 떨리자 선원이 천령석 코어가 없음을 먼저 확인하는 장면"),
    ]
    cases.extend({"expected_pack_family": p, "input": t, "source": "ambiguity_trap"} for p, t in traps)

    # De-duplicate while preserving order after shuffle.
    rng.shuffle(cases)
    seen = set()
    unique = []
    for c in cases:
        key = re.sub(r"\s+", " ", c["input"]).strip()
        if key in seen:
            continue
        seen.add(key)
        c["input"] = key
        unique.append(c)

    n = int(target_n or r16_target_n())
    return unique[:n]

if RUN_R16_MAX_DIVERSITY_STRESS and globals().get("R16_ENABLE_MAX_DIVERSITY_SUITE", True):
    seed = r16_seed()
    selected = r16_build_cases(seed=seed, target_n=r16_target_n())
    cases = [c["input"] for c in selected]
    if globals().get("R16_REQUIRE_NO_DUPLICATE_INPUTS", True):
        assert len(cases) == len(set(cases)), "R16 diversity cases must be unique."

    print("R16 diversity profile:", globals().get("R16_DIVERSITY_PROFILE", "frontier_48"))
    print("R16 diversity seed:", seed)
    print("R16 selected cases:")
    for i, c in enumerate(selected, 1):
        print(f"  {i:02d}. [{c['expected_pack_family']}/{c['source']}] {c['input']}")

    r16_max_diversity_results = r20_run_cases_with_budget(cases, label="r16_max_diversity") if "r20_run_cases_with_budget" in globals() else r10_run_cases(cases, label="r16_max_diversity")

    rows = []
    for meta, result in zip(selected, r16_max_diversity_results):
        got = (
            result.get("front", {}).get("pack", {}).get("pack_id")
            or result.get("pack", {}).get("pack_id")
            or "UNKNOWN"
        )
        rows.append({
            "input": meta["input"],
            "source": meta["source"],
            "expected_pack_family": meta["expected_pack_family"],
            "got_pack": got,
            "verdict": (result.get("final_gate", {}) or {}).get("verdict"),
            "length_chars": (result.get("final_gate", {}) or {}).get("length_chars"),
            "used_fallback": result.get("used_fallback"),
            "used_deterministic_minlen_extension": result.get("used_deterministic_minlen_extension"),
            "pack_instance_id": ((result.get("front", {}).get("pack", {}).get("generated_pack_overlay", {}) or {}).get("pack_instance_id")),
        })

    R16_MAX_DIVERSITY_REPORT = {
        "enabled": True,
        "profile": globals().get("R16_DIVERSITY_PROFILE", "frontier_48"),
        "seed": seed,
        "case_count": len(selected),
        "unique_inputs": len(set(cases)),
        "expected_pack_counts": dict(Counter(c["expected_pack_family"] for c in selected)),
        "got_pack_counts": dict(Counter(r["got_pack"] for r in rows)),
        "source_counts": dict(Counter(c["source"] for c in selected)),
        "verdict_counts": dict(Counter(r["verdict"] for r in rows)),
        "fallback_count": sum(1 for r in rows if r["used_fallback"]),
        "deterministic_minlen_count": sum(1 for r in rows if r["used_deterministic_minlen_extension"]),
        "rows": rows,
    }
    print(json.dumps(R16_MAX_DIVERSITY_REPORT, ensure_ascii=False, indent=2))
else:
    R16_MAX_DIVERSITY_REPORT = {"enabled": False}
    print("Skipped R16 max diversity stress.")

# %%
#@title 13A2.5. AF1K R20 source preflight + cost guard

from pathlib import Path
import json

R20_SOURCE_PREFLIGHT_REPORT = None

def r20_existing_source_paths():
    paths = []
    for p in globals().get("R18_GENRE_KNOWLEDGE_SOURCE_PATHS", []):
        path = Path(p)
        if path.exists():
            try:
                size = path.stat().st_size if path.is_file() else None
            except Exception:
                size = None
            paths.append({"path": str(path), "is_dir": path.is_dir(), "size": size})
    return paths

def r20_profile_requested_n(profile=None):
    profile = str(profile or globals().get("R18_KNOWLEDGE_DIVERSITY_PROFILE", "quick_24"))
    table = {
        "smoke_12": 12,
        "quick_24": 24,
        "quick_48": 48,
        "frontier_60": 60,
        "frontier_120": 120,
        "max_240": 240,
    }
    return table.get(profile, 24)

def r20_cost_guard_target_n(profile=None, source_count=None):
    if not globals().get("R20_COST_GUARD_ENABLED", True):
        return r20_profile_requested_n(profile)
    source_count = len(r20_existing_source_paths()) if source_count is None else int(source_count)
    profile = str(profile or globals().get("R18_KNOWLEDGE_DIVERSITY_PROFILE", "quick_24"))
    requested = r20_profile_requested_n(profile)

    if source_count <= 0 and profile in ["frontier_60", "frontier_120", "max_240"]:
        fallback = globals().get("R20_NO_SOURCE_PROFILE_FALLBACK", "quick_24")
        if globals().get("R20_ABORT_ON_NO_SOURCE_FRONTIER", False):
            raise AssertionError("R20 source preflight: external source files missing; refusing frontier/max run.")
        globals()["R18_KNOWLEDGE_DIVERSITY_PROFILE"] = fallback
        requested = r20_profile_requested_n(fallback)

    cap = int(globals().get("R20_HARD_MAX_GENERATED_CASES", 72))
    if source_count <= 0:
        cap = min(cap, int(globals().get("R20_NO_SOURCE_MAX_CASES", 24)))
    elif profile in ["frontier_60", "frontier_120", "max_240"]:
        cap = min(cap, int(globals().get("R20_FRONTIER_MAX_GENERATED_CASES", 60)))
    else:
        cap = min(cap, int(globals().get("R20_DEFAULT_MAX_GENERATED_CASES", 24)))
    return max(1, min(requested, cap))

def r20_apply_case_budget(cases, label=""):
    cases = list(cases or [])
    if not globals().get("R20_COST_GUARD_ENABLED", True):
        return cases
    source_count = len(r20_existing_source_paths())
    target = r20_cost_guard_target_n(source_count=source_count)
    if len(cases) > target:
        print(f"R20 cost guard: truncating {label or 'cases'} from {len(cases)} to {target}.")
        return cases[:target]
    return cases

def r20_run_cases_with_budget(cases, label=""):
    return r10_run_cases(r20_apply_case_budget(cases, label=label), label=label)

R20_SOURCE_PREFLIGHT_REPORT = {
    "source_paths_found": r20_existing_source_paths(),
    "source_count": len(r20_existing_source_paths()),
    "requested_profile_before_guard": globals().get("R18_KNOWLEDGE_DIVERSITY_PROFILE", None),
    "effective_target_n": r20_cost_guard_target_n(),
    "effective_profile_after_guard": globals().get("R18_KNOWLEDGE_DIVERSITY_PROFILE", None),
    "hard_max_generated_cases": globals().get("R20_HARD_MAX_GENERATED_CASES", None),
    "no_source_max_cases": globals().get("R20_NO_SOURCE_MAX_CASES", None),
    "frontier_max_generated_cases": globals().get("R20_FRONTIER_MAX_GENERATED_CASES", None),
}
print(json.dumps(R20_SOURCE_PREFLIGHT_REPORT, ensure_ascii=False, indent=2))

# %%
#@title 13A3. AF1K R18 genre-knowledge max input diversity

from collections import Counter, defaultdict
from pathlib import Path
import csv
import datetime
import html
import io
import json
import random
import re
import zipfile

RUN_R18_GENRE_KNOWLEDGE_MAX_INPUTS = False  #@param {type:"boolean"}

R18_GENRE_KNOWLEDGE_REPORT = None
r18_genre_knowledge_results = []

def r18_seed():
    seed = globals().get("R18_KNOWLEDGE_DIVERSITY_SEED", None)
    if seed is None:
        now = datetime.datetime.utcnow() + datetime.timedelta(hours=9)
        seed = int(now.strftime("%Y%m%d%H%M%S"))
        globals()["R18_KNOWLEDGE_DIVERSITY_SEED"] = seed
    return int(seed)

def r18_target_n():
    profile = str(globals().get("R18_KNOWLEDGE_DIVERSITY_PROFILE", "frontier_120"))
    if profile == "smoke_12":
        return 12
    if profile == "quick_24":
        return 24
    if profile == "quick_48":
        return 48
    if profile == "frontier_60":
        return 60
    if profile == "max_240":
        return 240
    return 120

def r18_norm(s):
    return re.sub(r"\s+", " ", str(s or "")).strip()

def r18_final_consonant(word):
    if not word:
        return False
    ch = str(word)[-1]
    code = ord(ch)
    if 0xAC00 <= code <= 0xD7A3:
        return ((code - 0xAC00) % 28) != 0
    return ch.lower()[-1:] not in "aeiou"

def r18_ga(word):
    return "이" if r18_final_consonant(word) else "가"

def r18_eun(word):
    return "은" if r18_final_consonant(word) else "는"

def r18_strip_html(text):
    text = html.unescape(str(text or ""))
    text = re.sub(r"(?is)<script.*?</script>", " ", text)
    text = re.sub(r"(?is)<style.*?</style>", " ", text)
    text = re.sub(r"(?is)<[^>]+>", " ", text)
    return r18_norm(text)

def r18_read_text_from_file(path, max_chars=None):
    path = Path(path)
    max_chars = int(max_chars or globals().get("R18_SOURCE_TEXT_MAX_CHARS", 700000))
    if not path.exists():
        return ""
    if path.is_dir():
        chunks = []
        for p in sorted(path.rglob("*")):
            if p.is_file() and p.suffix.lower() in [".txt", ".md", ".html", ".htm", ".csv", ".json"]:
                chunks.append(r18_read_text_from_file(p, max_chars=max(1000, max_chars // 20)))
                if sum(len(c) for c in chunks) >= max_chars:
                    break
        return "\n".join(chunks)[:max_chars]

    suffix = path.suffix.lower()
    try:
        if suffix == ".zip":
            chunks = []
            with zipfile.ZipFile(path) as z:
                names = [n for n in z.namelist() if not n.endswith("/")]
                for n in names:
                    low = n.lower()
                    if not any(low.endswith(ext) for ext in [".html", ".htm", ".txt", ".md", ".csv", ".json"]):
                        continue
                    if "_files/" in n and not low.endswith((".txt", ".md", ".html", ".htm")):
                        continue
                    try:
                        data = z.read(n)
                        text = data[:400000].decode("utf-8", errors="ignore")
                    except Exception:
                        continue
                    if low.endswith((".html", ".htm")):
                        title = re.sub(r"\.[^.]+$", "", Path(n).name)
                        text = title + "\n" + r18_strip_html(text)
                    chunks.append(text)
                    if sum(len(c) for c in chunks) >= max_chars:
                        break
            return "\n".join(chunks)[:max_chars]

        if suffix == ".csv":
            # Use title/body only as term source, not direct examples.
            chunks = []
            with open(path, encoding="utf-8", errors="ignore", newline="") as f:
                reader = csv.DictReader(f)
                rows = 0
                for row in reader:
                    rows += 1
                    title = row.get("normalized_title") or row.get("cleaned_title") or row.get("raw_title") or ""
                    body = row.get("body_text") or ""
                    chunks.append(str(title)[:220])
                    if body:
                        chunks.append(str(body)[:500])
                    if rows >= 700 or sum(len(c) for c in chunks) >= max_chars:
                        break
            return "\n".join(chunks)[:max_chars]

        text = path.read_text(encoding="utf-8", errors="ignore")
        if suffix in [".html", ".htm"]:
            text = r18_strip_html(text)
        return text[:max_chars]
    except Exception as e:
        return f""

def r18_source_texts():
    out = {}
    for p in globals().get("R18_GENRE_KNOWLEDGE_SOURCE_PATHS", []):
        path = Path(p)
        if path.exists():
            txt = r18_read_text_from_file(path)
            if txt:
                out[str(path)] = txt
    return out

def r18_base_knowledge_from_registry():
    reservoir = {}
    for pack_id, pack in PACK_REGISTRY.items():
        gd = pack.get("genre_data", {})
        er = pack.get("event_flow_rails", {})
        reservoir[pack_id] = {
            "roles": list(gd.get("roles", [])),
            "materials": list(gd.get("material_pool", [])),
            "signals": list(gd.get("positive_signals", [])),
            "conventions": list(gd.get("genre_conventions", [])),
            "subgenres": list(gd.get("subgenres", [])),
            "flow_phrases": sum([list(er.get(k, [])) for k in er], []),
            "mined_terms": [],
            "source_hits": Counter(),
        }
    return reservoir

R18_PACK_KEYWORDS = {
    "TOWER_SYSTEM_RULE": ["탑", "등반", "층", "공략", "협회", "길드", "상태창", "랭커", "통행증", "최고층", "헌터", "던전", "미션"],
    "AETHER_WHALERS": ["천해", "비공선", "고래", "부력낭", "천해석", "천령석", "증기", "항해", "공어", "난류", "선장"],
    "ROMANTASY_HOUSE_CONTRACT": ["악역영애", "로판", "가문", "공작", "약혼", "후견", "계약", "연회", "봉랍", "귀족", "명가"],
    "CLOSED_CIRCLE_MYSTERY": ["추리", "미스터리", "탐정", "알리바이", "용의자", "밀실", "별장", "찻잔", "발자국", "단서"],
    "RETURN_FANTASY": ["회귀", "두 번째 삶", "전생", "미래 지식", "파멸", "멸망", "복수", "다시 태어", "예정된"],
    "GENERAL_WEBNOVEL": ["프롤로그", "문밖", "방 안", "선택", "비용", "단추", "서랍", "발소리", "시선", "대가"],
}

R18_STOP_TERMS = set("""
나무위키 문서 편집 역사 분류 최근 변경 파일 토론 외부 링크 관련 문서 개요 특징 작품
그리고 그러나 때문에 것이다 있다 없다 한다 대한 경우 장면 이야기 주인공 작품에서 웹소설 소설 장르
""".split())

def r18_extract_terms(text, max_terms=300):
    text = r18_strip_html(text)
    # Keep medium-length Korean terms/phrases. No direct sentence copying.
    candidates = re.findall(r"[가-힣A-Za-z0-9]{2,12}(?:\s+[가-힣A-Za-z0-9]{2,12}){0,2}", text)
    cnt = Counter()
    for c in candidates:
        c = r18_norm(c)
        if len(c) < 2 or len(c) > 24:
            continue
        if c in R18_STOP_TERMS:
            continue
        if any(stop == c for stop in R18_STOP_TERMS):
            continue
        # Avoid full article-like chunks; keep term-ish fragments.
        if len(c.split()) > 3:
            continue
        cnt[c] += 1
    return [t for t, _ in cnt.most_common(max_terms)]

def r18_assign_terms_to_packs(source_texts, reservoir):
    limit = int(globals().get("R18_MAX_TERMS_PER_PACK_FROM_SOURCES", 90))
    for source, text in source_texts.items():
        source_name = Path(source).name
        source_text = (source_name + "\n" + text[:200000])
        terms = r18_extract_terms(source_text, max_terms=500)
        low = source_text.lower()

        for pack_id, keywords in R18_PACK_KEYWORDS.items():
            score = 0
            for kw in keywords:
                if kw.lower() in low:
                    score += 1
            # Source filename is highly informative for crawled genre pages.
            for kw in keywords:
                if kw.lower() in source_name.lower():
                    score += 3
            if score <= 0:
                continue
            reservoir[pack_id]["source_hits"][source_name] += score

            selected = []
            for term in terms:
                if any(kw in term for kw in keywords) or score >= 3:
                    selected.append(term)
                if len(selected) >= limit:
                    break
            for term in selected:
                if term not in reservoir[pack_id]["mined_terms"]:
                    reservoir[pack_id]["mined_terms"].append(term)
                    if len(reservoir[pack_id]["mined_terms"]) >= limit:
                        break
    return reservoir

def r18_enrich_pack_reservoir(reservoir):
    # Hand-coded genre knowledge that should exist even if uploads are absent.
    extra = {
        "TOWER_SYSTEM_RULE": {
            "roles": ["저층 통과자", "상층 기록 보유자", "공략 기록 사본을 든 기록관", "상승 루트를 바꾼 파티장"],
            "materials": ["층 돌파 증표", "상승 경로 잠금", "최고층 기록 사본", "공략 허가표", "히든 조건 기록"],
            "conflicts": ["이미 클리어한 층으로 돌아갈 수 없어 다음 층 선택이 강제되는", "길드 의뢰 층수와 파티 최고 기록이 맞지 않는", "공식 기록과 사본 기록이 다른"],
        },
        "AETHER_WHALERS": {
            "roles": ["천해 항로사", "부력낭 재봉공", "고래기름 기관사", "천해석 감정사", "지상식 판단을 버린 정찰병"],
            "materials": ["부력낭 압력계", "천해석 균열", "증기 권양기 체인", "공어 떼", "부유암괴 그늘"],
            "conflicts": ["사냥보다 선체 복원을 먼저 택해야 하는", "지상 전쟁 상식이 천해에서 틀리는", "천령석 코어와 천해석 부력을 혼동하면 침몰하는"],
        },
        "ROMANTASY_HOUSE_CONTRACT": {
            "roles": ["계약 검토인", "후견 증인", "가문 인장 관리자", "연회장 좌석 담당 시종", "약혼 조건을 읽은 영애"],
            "materials": ["봉랍 가장자리 눌림", "초대장 명단", "서명란의 위치", "장갑 안쪽 자수", "축배 순서표"],
            "conflicts": ["사랑 고백보다 조항 해석이 먼저 폭발하는", "체면을 지키면 불리한 계약을 삼키는", "증언 순서가 가문 책임을 바꾸는"],
        },
        "CLOSED_CIRCLE_MYSTERY": {
            "roles": ["초대받지 않은 탐정", "알리바이를 외운 손님", "열쇠를 관리한 하녀", "창틀을 닦은 시종", "사망자의 습관을 아는 의사"],
            "materials": ["마른 창틀", "식지 않은 찻잔", "손잡이 방향", "젖은 발자국", "초가 하나 줄어든 촛대"],
            "conflicts": ["모두의 증언이 맞는데 물건 배치만 틀리는", "닫힌 방보다 시간표의 빈칸이 먼저 드러나는", "범인 지목보다 질문 순서가 중요해지는"],
        },
        "RETURN_FANTASY": {
            "roles": ["첫 번째 삶을 기억하는 귀족", "두 번째 삶의 책사", "죽었어야 할 하인", "복수를 미룬 후계자", "미래 지식이 흔들린 주인공"],
            "materials": ["하루 어긋난 편지", "사라진 예정된 모욕", "오지 않은 암살자", "기억과 다른 초대장", "첫 번째 삶의 사망자 명단"],
            "conflicts": ["미래 지식이 맞지 않아 복수를 미뤄야 하는", "원래 죽을 사람이 살아 있어 계획이 무너지는", "파멸을 피하려는 행동이 더 큰 변수를 부르는"],
        },
        "GENERAL_WEBNOVEL": {
            "roles": ["문틈을 보는 인물", "낡은 건물 관리인", "숨긴 물건을 가진 아이", "발소리를 세는 주인공", "시선 변화를 읽는 증인"],
            "materials": ["문틈 종이", "젖은 단추", "작은 서랍", "멈춘 발소리", "방 안의 시선"],
            "conflicts": ["큰 문보다 작은 물건을 택하는", "누가 먼저 움직였는지 단추 하나로 판단하는", "위험한 물건을 숨기자 시선이 바뀌는"],
        },
    }
    for pack_id, data in extra.items():
        if pack_id not in reservoir:
            continue
        for key, vals in data.items():
            reservoir[pack_id].setdefault(key, [])
            for v in vals:
                if v not in reservoir[pack_id][key]:
                    reservoir[pack_id][key].append(v)
    return reservoir

def r18_build_reservoir():
    reservoir = r18_base_knowledge_from_registry()
    reservoir = r18_enrich_pack_reservoir(reservoir)
    source_texts = r18_source_texts()
    reservoir = r18_assign_terms_to_packs(source_texts, reservoir)
    return reservoir, source_texts

def r18_pick(rng, arr, fallback):
    arr = [x for x in (arr or []) if x]
    return rng.choice(arr) if arr else fallback

def r18_pack_case_templates(pack_id):
    return {
        "TOWER_SYSTEM_RULE": [
            "{role}{ga} {mat} 때문에 {conflict} 장면",
            "게임빙의 조연 NPC가 {mat}을 보고 {conflict} 장면",
            "협회 공시 뒤 {role}{ga} 보상보다 다음 층 조건을 먼저 확인하는 장면",
        ],
        "AETHER_WHALERS": [
            "{role}{ga} {mat} 때문에 {conflict} 장면",
            "천해 난류 속에서 {mat}이 흔들리자 {role}{ga} {conflict} 장면",
            "지상식 판단이 빗나간 뒤 {role}{ga} {mat}을 먼저 확인하는 장면",
        ],
        "ROMANTASY_HOUSE_CONTRACT": [
            "{role}{ga} {mat} 때문에 {conflict} 장면",
            "연회장에서 {mat}이 드러나자 {role}{ga} {conflict} 장면",
            "후견 계약 직전 {role}{ga} 축배보다 {mat}을 먼저 확인하는 장면",
        ],
        "CLOSED_CIRCLE_MYSTERY": [
            "{role}{ga} {mat} 때문에 {conflict} 장면",
            "고립된 별장에서 {mat}이 맞지 않자 {role}{ga} 증언 순서를 다시 묻는 장면",
            "닫힌 방에서 {role}{ga} 사라진 열쇠보다 {mat}을 먼저 보는 장면",
        ],
        "RETURN_FANTASY": [
            "{role}{ga} {mat} 때문에 {conflict} 장면",
            "두 번째 삶에서 {mat}이 기억과 달라 {role}{ga} {conflict} 장면",
            "파멸 직전으로 돌아온 {role}{ga} 복수보다 {mat}을 먼저 확인하는 장면",
        ],
        "GENERAL_WEBNOVEL": [
            "{role}{ga} {mat} 때문에 {conflict} 장면",
            "비가 벽을 타는 건물에서 {role}{ga} {mat}만 보고 {conflict} 장면",
            "문밖의 기척이 멈춘 뒤 {role}{ga} {mat}을 숨기며 {conflict} 장면",
        ],
    }.get(pack_id, ["{role}{ga} {mat} 때문에 {conflict} 장면"])

def r18_build_cases_from_reservoir(reservoir, seed=None, target_n=None):
    rng = random.Random(r18_seed() if seed is None else int(seed))
    target_n = int(target_n or r18_target_n())
    cases = []

    # Strong coverage: each pack gets multiple cases from registry + mined + hand knowledge.
    per_pack_min = max(6, target_n // max(1, len(reservoir)) // 2)
    for pack_id, data in reservoir.items():
        roles = list(data.get("roles", [])) + list(data.get("signals", []))[:8]
        mats = list(data.get("materials", [])) + list(data.get("mined_terms", []))[:20]
        conflicts = list(data.get("conflicts", [])) + list(data.get("flow_phrases", []))[:10] + list(data.get("conventions", []))[:4]
        templates = r18_pack_case_templates(pack_id)
        local = []
        for _ in range(max(per_pack_min * 3, 24)):
            role = r18_pick(rng, roles, "주인공")
            mat = r18_pick(rng, mats, "작은 단서")
            conflict = r18_pick(rng, conflicts, "선택 비용을 확인하는")
            tmpl = rng.choice(templates)
            case = tmpl.format(role=role, ga=r18_ga(role), eun=r18_eun(role), mat=mat, conflict=conflict)
            case = r18_norm(case)
            if len(case) > 120:
                # Compress knowledge-derived long convention lines.
                case = r18_norm(case[:112] + " 장면")
            local.append({"expected_pack_family": pack_id, "input": case, "source": "knowledge_reservoir"})
        rng.shuffle(local)
        cases.extend(local[:per_pack_min])

    # Ambiguity traps, negative controls, and cross-genre overlays.
    traps = [
        ("CLOSED_CIRCLE_MYSTERY", "회귀가 아니라 기억력이 좋은 탐정이 남작의 찻잔 손잡이 방향을 다시 묻는 장면"),
        ("RETURN_FANTASY", "탐정처럼 단정하지 않고 회귀한 주인공이 하루 어긋난 편지 때문에 복수를 미루는 장면"),
        ("TOWER_SYSTEM_RULE", "한번 클리어한 하층으로는 돌아갈 수 없어 조연 NPC가 다음 층 통행 조건을 다시 계산하는 장면"),
        ("TOWER_SYSTEM_RULE", "특수 균열이라는 이례적 사건 때문에 클리어한 3층 문이 다시 열려 협회가 비정상 기록을 조사하는 장면"),
        ("ROMANTASY_HOUSE_CONTRACT", "회귀가 아닌 악역영애가 연회장 좌석표 변경 때문에 약혼 조항 날짜를 묻는 장면"),
        ("AETHER_WHALERS", "지상 정찰병이 공어 비를 포격으로 오인하자 항해사가 천해 조류와 부력낭 손상을 먼저 확인하는 장면"),
        ("GENERAL_WEBNOVEL", "장르 표면어 없이 문밖의 발소리가 멈춘 뒤 주인공이 젖은 단추를 숨기는 장면"),
        ("CLOSED_CIRCLE_MYSTERY", "연회장 옆 별채에서 탐정이 축배보다 마른 창틀과 젖은 발자국의 모순을 먼저 묻는 장면"),
        ("RETURN_FANTASY", "두 번째 삶의 연회에서 원래 있어야 할 모욕이 사라져 미래 지식의 균열을 확인하는 장면"),
        ("ROMANTASY_HOUSE_CONTRACT", "후견 계약을 앞둔 응접실에서 봉랍 가장자리 눌림 때문에 공작가 증언 순서가 바뀌는 장면"),
        ("AETHER_WHALERS", "소형 부유암괴 옆 천해석 파편이 떨리자 선원이 천령석 코어가 없음을 먼저 확인하는 장면"),
        ("GENERAL_WEBNOVEL", "작은 서랍을 여는 인물이 문틈 종이 때문에 큰 문보다 작은 선택을 택하는 장면"),
    ]
    cases.extend({"expected_pack_family": p, "input": t, "source": "ambiguity_trap"} for p, t in traps)

    # Fill to target with extra combinations.
    pack_ids = list(reservoir.keys())
    while len(cases) < target_n * 2:
        pack_id = rng.choice(pack_ids)
        data = reservoir[pack_id]
        role = r18_pick(rng, list(data.get("roles", [])) + list(data.get("signals", [])), "주인공")
        mat = r18_pick(rng, list(data.get("materials", [])) + list(data.get("mined_terms", [])), "단서")
        conflict = r18_pick(rng, list(data.get("conflicts", [])) + list(data.get("flow_phrases", [])), "선택 비용을 확인하는")
        tmpl = rng.choice(r18_pack_case_templates(pack_id))
        case = r18_norm(tmpl.format(role=role, ga=r18_ga(role), eun=r18_eun(role), mat=mat, conflict=conflict))
        if len(case) > 120:
            case = r18_norm(case[:112] + " 장면")
        cases.append({"expected_pack_family": pack_id, "input": case, "source": "knowledge_fill"})

    rng.shuffle(cases)
    seen = set()
    unique = []
    for c in cases:
        key = r18_norm(c["input"])
        if key in seen:
            continue
        seen.add(key)
        c["input"] = key
        unique.append(c)
        if len(unique) >= target_n:
            break
    return unique

if RUN_R18_GENRE_KNOWLEDGE_MAX_INPUTS and globals().get("R18_ENABLE_GENRE_KNOWLEDGE_RESERVOIR", True):
    seed = r18_seed()
    reservoir, source_texts = r18_build_reservoir()
    target_n = r20_cost_guard_target_n() if "r20_cost_guard_target_n" in globals() else r18_target_n()
    selected = r18_build_cases_from_reservoir(reservoir, seed=seed, target_n=target_n)
    cases = [c["input"] for c in selected]
    if globals().get("R18_REQUIRE_NO_DUPLICATE_INPUTS", True):
        assert len(cases) == len(set(cases)), "R18 knowledge cases must be unique."

    print("R18 knowledge diversity profile:", globals().get("R18_KNOWLEDGE_DIVERSITY_PROFILE", "frontier_120"))
    print("R18 knowledge diversity seed:", seed)
    print("R18 source files:", list(source_texts.keys()))
    print("R18 selected cases:")
    print_limit = int(globals().get("R20_PRINT_CASE_LIST_ONLY_FIRST", 30))
    for i, c in enumerate(selected[:print_limit], 1):
        print(f"  {i:03d}. [{c['expected_pack_family']}/{c['source']}] {c['input']}")
    if len(selected) > print_limit:
        print(f"  ... {len(selected) - print_limit} more cases hidden by R20_PRINT_CASE_LIST_ONLY_FIRST")

    r18_genre_knowledge_results = r20_run_cases_with_budget(cases, label="r18_genre_knowledge") if "r20_run_cases_with_budget" in globals() else r10_run_cases(cases, label="r18_genre_knowledge")

    rows = []
    for meta, result in zip(selected, r18_genre_knowledge_results):
        got = (
            result.get("front", {}).get("pack", {}).get("pack_id")
            or result.get("pack", {}).get("pack_id")
            or "UNKNOWN"
        )
        rows.append({
            "input": meta["input"],
            "source": meta["source"],
            "expected_pack_family": meta["expected_pack_family"],
            "got_pack": got,
            "verdict": (result.get("final_gate", {}) or {}).get("verdict"),
            "length_chars": (result.get("final_gate", {}) or {}).get("length_chars"),
            "used_fallback": result.get("used_fallback"),
            "used_deterministic_minlen_extension": result.get("used_deterministic_minlen_extension"),
            "pack_instance_id": ((result.get("front", {}).get("pack", {}).get("generated_pack_overlay", {}) or {}).get("pack_instance_id")),
        })

    R18_GENRE_KNOWLEDGE_REPORT = {
        "enabled": True,
        "profile": globals().get("R18_KNOWLEDGE_DIVERSITY_PROFILE", "frontier_120"),
        "seed": seed,
        "case_count": len(selected),
        "unique_inputs": len(set(cases)),
        "source_files": list(source_texts.keys()),
        "source_file_count": len(source_texts),
        "r20_source_preflight_report": globals().get("R20_SOURCE_PREFLIGHT_REPORT", None),
        "reservoir_summary": {
            pack_id: {
                "roles": len(data.get("roles", [])),
                "materials": len(data.get("materials", [])),
                "signals": len(data.get("signals", [])),
                "mined_terms": len(data.get("mined_terms", [])),
                "source_hits": dict(data.get("source_hits", {})),
            }
            for pack_id, data in reservoir.items()
        },
        "expected_pack_counts": dict(Counter(c["expected_pack_family"] for c in selected)),
        "got_pack_counts": dict(Counter(r["got_pack"] for r in rows)),
        "source_counts": dict(Counter(c["source"] for c in selected)),
        "verdict_counts": dict(Counter(r["verdict"] for r in rows)),
        "fallback_count": sum(1 for r in rows if r["used_fallback"]),
        "deterministic_minlen_count": sum(1 for r in rows if r["used_deterministic_minlen_extension"]),
        "rows": rows,
    }
    print(json.dumps(R18_GENRE_KNOWLEDGE_REPORT, ensure_ascii=False, indent=2))
else:
    R18_GENRE_KNOWLEDGE_REPORT = {"enabled": False}
    print("Skipped R18 genre-knowledge max input diversity.")

# %%
#@title 13A. AF1J balanced blind anti-overfit stress
from collections import Counter, defaultdict

AF1J_BALANCED_BLIND_CASES = [
    # Tower
    "초보 공략자가 이미 깬 3층 재입장을 거부당하고, 협회 접수원이 최고층 갱신 공시를 근거로 새 통행증을 발급하는 장면",
    "상층 공략 기록 두 장의 계단 위치가 달라서 파티장이 보상보다 숨은 조건을 먼저 의심하는 장면",
    "길드가 14층 소재 채집을 의뢰했지만 최고 기록 8층인 파티가 수락 여부를 두고 갈라지는 장면",
    # Aether
    "천해 난류 속에서 증기 권양기가 멈추고 선장이 고래보다 찢어진 부력낭을 먼저 살리는 장면",
    "지상에서 온 정찰병이 공어 비를 포격으로 착각하고 항해사가 천해 조류라고 정정하는 장면",
    "소형 부유암괴 옆에서 천해석 파편이 이상하게 떨려 선원이 기존 항로를 포기하는 장면",
    # Romantasy
    "후견 계약을 앞둔 응접실에서 사라진 장갑 한 짝 때문에 공작가의 증언 순서가 뒤바뀌는 장면",
    "연회장에서 약혼 발표 직전 좌석표가 바뀐 것을 본 영애가 축배 대신 조항의 날짜를 묻는 장면",
    "가문 문장이 찍힌 봉랍이 완전한데도 계약서 가장자리 눌림 때문에 합의가 의심받는 장면",
    # Mystery
    "고립된 별장에서 촛불 수가 하나 줄어든 뒤 탐정이 사라진 열쇠보다 식탁 배치를 먼저 보는 장면",
    "모두가 같은 알리바이를 가진 밤에 탐정이 젖은 발자국과 마른 창틀의 모순을 묻는 장면",
    "죽은 남작의 찻잔 손잡이 방향이 평소 습관과 달라 탐정이 차를 따른 순서를 다시 묻는 장면",
    # Return Fantasy
    "회귀 첫날 주인공이 예정된 암살자가 나타나지 않자 미래 지식보다 사라진 하인의 이름을 먼저 확인하는 장면",
    "파멸 직전으로 돌아온 주인공이 복수 대상을 만나기 전 날짜가 하루 어긋난 편지를 발견하는 장면",
    "두 번째 삶의 연회에서 원래 있어야 할 모욕이 사라져 주인공이 적이 먼저 움직였음을 깨닫는 장면",
    # General
    "닫힌 방에서 주인공이 큰 문이 아니라 아무도 보지 않은 작은 서랍을 열어 선택의 비용을 확인하는 장면",
    "비가 벽을 타고 흐르는 낡은 건물에서 주인공이 단추 하나로 누가 먼저 들어왔는지 추적하는 장면",
    "문밖의 발소리가 멈춘 뒤 주인공이 가장 위험한 물건을 숨기며 방 안의 시선 변화를 읽는 장면",
]

RUN_AF1J_BALANCED_BLIND = False  #@param {type:"boolean"}

af1i_blind_results = []
if RUN_AF1J_BALANCED_BLIND:
    SEEN_FINAL_PREFIXES = Counter()
    af1i_blind_results = r10_run_cases(AF1J_BALANCED_BLIND_CASES, label="af1j_balanced_blind")
else:
    print("Skipped AF1J balanced blind. Set RUN_AF1J_BALANCED_BLIND = False to run.")

# %%
#@title 13B. AF1K R3 overfit diagnostic
import re
import hashlib

from collections import Counter, defaultdict
from pathlib import Path
import json, re, hashlib, math

if "OVERFIT_REQUIRE_BLIND_FOR_PASS" not in globals():
    OVERFIT_REQUIRE_BLIND_FOR_PASS = True
if "OVERFIT_KEEP_DROP_WARN" not in globals():
    OVERFIT_KEEP_DROP_WARN = 0.08
if "OVERFIT_KEEP_DROP_FAIL" not in globals():
    OVERFIT_KEEP_DROP_FAIL = 0.15
if "OVERFIT_FALLBACK_WARN" not in globals():
    OVERFIT_FALLBACK_WARN = 0.35
if "OVERFIT_FALLBACK_FAIL" not in globals():
    OVERFIT_FALLBACK_FAIL = 0.55
if "OVERFIT_MINLEN_WARN" not in globals():
    OVERFIT_MINLEN_WARN = 0.60
if "OVERFIT_MINLEN_FAIL" not in globals():
    OVERFIT_MINLEN_FAIL = 0.85
if "OVERFIT_DUP_PREFIX_WARN" not in globals():
    OVERFIT_DUP_PREFIX_WARN = 0.12
if "OVERFIT_DUP_PREFIX_FAIL" not in globals():
    OVERFIT_DUP_PREFIX_FAIL = 0.25
if "OVERFIT_NGRAM_OVERLAP_WARN" not in globals():
    OVERFIT_NGRAM_OVERLAP_WARN = 0.38
if "OVERFIT_NGRAM_OVERLAP_FAIL" not in globals():
    OVERFIT_NGRAM_OVERLAP_FAIL = 0.52
if "R5_DIAGNOSTIC_MINLEN_FAILS_ON_DETERMINISTIC_ONLY" not in globals():
    R5_DIAGNOSTIC_MINLEN_FAILS_ON_DETERMINISTIC_ONLY = True
if "R5_TOTAL_MINLEN_RATE_WATCH_ONLY" not in globals():
    R5_TOTAL_MINLEN_RATE_WATCH_ONLY = True

def _rlist(x):
    if isinstance(x, dict):
        return [x]
    if isinstance(x, list):
        return [r for r in x if isinstance(r, dict)]
    return []

def _gate(r):
    return r.get("final_gate", {}) or {}

def _text(r):
    return (r.get("final_text") or "").strip()

def _input(r):
    return (r.get("input") or "").strip()

def _pack_id(r):
    return (
        r.get("front", {}).get("pack", {}).get("pack_id")
        or r.get("pack", {}).get("pack_id")
        or "UNKNOWN"
    )

def collect_result_pools():
    pools = {"calibration": [], "blind": [], "unknown": []}

    calibration_names = [
        "single_result",
        "tower_focused_results",
        "af1e_mixed_results",
        "af1g_minlen_results",
        "af1h_quick_results",
    ]
    blind_names = [
        "blind_results",
        "holdout_results",
        "unseen_results",
        "af1i_blind_results",
        "af1j_balanced_blind_results",
        "af1k_post_handler_blind_results",
        "r14_rotating_blind_results",
        "r16_max_diversity_results",
        "r18_genre_knowledge_results",
    ]

    for name in calibration_names:
        pools["calibration"].extend(_rlist(globals().get(name)))
    for name in blind_names:
        pools["blind"].extend(_rlist(globals().get(name)))

    if "all_results" in globals() and isinstance(all_results, list):
        known_ids = {id(r) for r in pools["calibration"] + pools["blind"]}
        pools["unknown"].extend([r for r in all_results if isinstance(r, dict) and id(r) not in known_ids])

    return pools

def tokenize_ko_light(text):
    return re.findall(r"[가-힣A-Za-z0-9]+", text or "")

def ngrams(tokens, n=3):
    if len(tokens) < n:
        return set()
    return set(tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1))

def summarize_pool(results, label):
    total = len(results)
    if total == 0:
        return {
            "label": label, "total": 0,
            "keep_rate": None, "light_repair_rate": None, "reject_rate": None,
            "fallback_rate": None, "minlen_rate": None,
            "model_continuation_rate": None, "deterministic_minlen_rate": None,
            "quality_repair_rate": None, "duplicate_prefix_repair_rate": None,
            "route_miss_rate": None, "too_short_rate": None, "hit_rate": None,
            "duplicate_prefix_rate": None, "duplicate_exact_rate": None,
            "avg_length": None, "pack_counts": {}, "verdict_counts": {},
        }

    verdicts = Counter(_gate(r).get("verdict") for r in results)
    packs = Counter(_pack_id(r) for r in results)

    fallback = sum(bool(r.get("used_fallback")) for r in results)
    minlen = sum(bool(r.get("used_minlen_extension")) for r in results)
    model_cont = sum(bool(r.get("used_model_continuation")) for r in results)
    det_minlen = sum(bool(r.get("used_deterministic_minlen_extension")) for r in results)
    qrepair = sum(bool(r.get("used_quality_light_repair")) for r in results)
    dup_repair = sum(bool(r.get("used_duplicate_prefix_repair")) for r in results)
    route_miss = sum(bool(_gate(r).get("final_route_miss")) for r in results)
    too_short = sum(bool(_gate(r).get("too_short_final")) for r in results)

    hit_count = 0
    lengths = []
    prefix_counts = Counter()
    exact_counts = Counter()

    for r in results:
        g = _gate(r)
        hit_count += len(g.get("surface_hits", []) or []) + len(g.get("lore_hits", []) or []) + len(g.get("quality_hits", []) or [])
        txt = re.sub(r"\s+", " ", _text(r))
        if txt:
            prefix_counts[txt[:180]] += 1
            exact_counts[hashlib.sha256(txt.encode("utf-8")).hexdigest()] += 1
        lengths.append(g.get("length_chars") or len(_text(r)))

    dup_prefix_items = sum(c for c in prefix_counts.values() if c > 1)
    dup_exact_items = sum(c for c in exact_counts.values() if c > 1)

    return {
        "label": label,
        "total": total,
        "keep_rate": verdicts.get("KEEP", 0) / total,
        "light_repair_rate": verdicts.get("LIGHT_REPAIR", 0) / total,
        "reject_rate": verdicts.get("REJECT", 0) / total,
        "fallback_rate": fallback / total,
        "minlen_rate": minlen / total,
        "model_continuation_rate": model_cont / total,
        "deterministic_minlen_rate": det_minlen / total,
        "quality_repair_rate": qrepair / total,
        "duplicate_prefix_repair_rate": dup_repair / total,
        "route_miss_rate": route_miss / total,
        "too_short_rate": too_short / total,
        "hit_rate": hit_count / total,
        "duplicate_prefix_rate": dup_prefix_items / total,
        "duplicate_exact_rate": dup_exact_items / total,
        "avg_length": round(sum(lengths) / total, 1),
        "pack_counts": dict(packs),
        "verdict_counts": dict(verdicts),
    }

def ngram_overlap_score(reference_results, target_results, n=3):
    ref = set()
    tgt = set()
    for r in reference_results:
        ref |= ngrams(tokenize_ko_light(_text(r)), n=n)
    for r in target_results:
        tgt |= ngrams(tokenize_ko_light(_text(r)), n=n)
    if not tgt:
        return None
    return len(ref & tgt) / max(1, len(tgt))

def input_output_copy_score(results, n=3):
    scores = []
    for r in results:
        ing = ngrams(tokenize_ko_light(_input(r)), n=n)
        outg = ngrams(tokenize_ko_light(_text(r)), n=n)
        if outg:
            scores.append(len(ing & outg) / len(outg))
    return sum(scores) / len(scores) if scores else None

def judge_overfit(calibration_results, blind_results, unknown_results=None):
    cal = summarize_pool(calibration_results, "calibration")
    blind = summarize_pool(blind_results, "blind")
    unknown = summarize_pool(unknown_results or [], "unknown")

    issues = []
    verdict = "PASS"

    def add(level, code, detail):
        nonlocal verdict
        issues.append({"level": level, "code": code, "detail": detail})
        if level == "FAIL":
            verdict = "FAIL"
        elif level == "WATCH" and verdict != "FAIL":
            verdict = "WATCH"

    if globals().get("OVERFIT_REQUIRE_BLIND_FOR_PASS", True) and blind["total"] == 0:
        add("WATCH", "NO_BLIND_SET", "blind/unseen result pool이 없음. calibration-only 성공은 일반화 증거가 아님.")

    if cal["total"] and blind["total"]:
        keep_drop = (cal["keep_rate"] or 0) - (blind["keep_rate"] or 0)
        if keep_drop >= globals().get("OVERFIT_KEEP_DROP_FAIL", 0.15):
            add("FAIL", "KEEP_RATE_DROP", f"blind KEEP rate drop = {keep_drop:.3f}")
        elif keep_drop >= globals().get("OVERFIT_KEEP_DROP_WARN", 0.08):
            add("WATCH", "KEEP_RATE_DROP", f"blind KEEP rate drop = {keep_drop:.3f}")

    dep = blind if blind["total"] else cal
    dep_label = dep["label"]

    det_ml = dep.get("deterministic_minlen_rate")
    if det_ml is not None:
        if det_ml >= globals().get("OVERFIT_MINLEN_FAIL", 0.85):
            add("FAIL", "HIGH_DETERMINISTIC_MINLEN_DEPENDENCY", f"{dep_label} deterministic min-length extension rate = {det_ml:.3f}")
        elif det_ml >= globals().get("OVERFIT_MINLEN_WARN", 0.60):
            add("WATCH", "HIGH_DETERMINISTIC_MINLEN_DEPENDENCY", f"{dep_label} deterministic min-length extension rate = {det_ml:.3f}")

    fb = dep.get("fallback_rate")
    if fb is not None:
        if fb >= globals().get("OVERFIT_FALLBACK_FAIL", 0.55):
            add("FAIL", "HIGH_FALLBACK_DEPENDENCY", f"{dep_label} fallback rate = {fb:.3f}")
        elif fb >= globals().get("OVERFIT_FALLBACK_WARN", 0.35):
            add("WATCH", "HIGH_FALLBACK_DEPENDENCY", f"{dep_label} fallback rate = {fb:.3f}")

    ml = dep.get("minlen_rate")
    if ml is not None:
        # R5: total minlen often means model-continuation length recovery, not
        # deterministic template dependence. Deterministic minlen remains the
        # fail-capable signal above; total minlen is watch-only by default.
        if globals().get("R5_TOTAL_MINLEN_RATE_WATCH_ONLY", True):
            if ml >= globals().get("OVERFIT_MINLEN_WARN", 0.60):
                add("WATCH", "HIGH_TOTAL_MINLEN_DEPENDENCY", f"{dep_label} total minlen recovery rate = {ml:.3f}")
        else:
            if ml >= globals().get("OVERFIT_MINLEN_FAIL", 0.85):
                add("FAIL", "HIGH_MINLEN_DEPENDENCY", f"{dep_label} minlen extension rate = {ml:.3f}")
            elif ml >= globals().get("OVERFIT_MINLEN_WARN", 0.60):
                add("WATCH", "HIGH_MINLEN_DEPENDENCY", f"{dep_label} minlen extension rate = {ml:.3f}")

    dp = dep.get("duplicate_prefix_rate")
    if dp is not None:
        if dp >= globals().get("OVERFIT_DUP_PREFIX_FAIL", 0.25):
            add("FAIL", "DUPLICATE_PREFIX_RATE", f"{dep_label} duplicate prefix rate = {dp:.3f}")
        elif dp >= globals().get("OVERFIT_DUP_PREFIX_WARN", 0.12):
            add("WATCH", "DUPLICATE_PREFIX_RATE", f"{dep_label} duplicate prefix rate = {dp:.3f}")

    overlap = None
    if cal["total"] and blind["total"]:
        overlap = ngram_overlap_score(calibration_results, blind_results, n=3)
        if overlap is not None:
            if overlap >= globals().get("OVERFIT_NGRAM_OVERLAP_FAIL", 0.52):
                add("FAIL", "HIGH_CALIBRATION_BLIND_NGRAM_OVERLAP", f"3-gram overlap = {overlap:.3f}")
            elif overlap >= globals().get("OVERFIT_NGRAM_OVERLAP_WARN", 0.38):
                add("WATCH", "HIGH_CALIBRATION_BLIND_NGRAM_OVERLAP", f"3-gram overlap = {overlap:.3f}")

    copy_score = input_output_copy_score(blind_results if blind["total"] else calibration_results, n=3)

    return {
        "verdict": verdict,
        "issues": issues,
        "calibration": cal,
        "blind": blind,
        "unknown": unknown,
        "calibration_to_blind_ngram_overlap": overlap,
        "input_output_copy_score": copy_score,
    }

_pools = collect_result_pools()
OVERFIT_DIAGNOSTIC_REPORT = judge_overfit(_pools["calibration"], _pools["blind"], _pools["unknown"])

print("OVERFIT VERDICT:", OVERFIT_DIAGNOSTIC_REPORT["verdict"])
print(json.dumps(OVERFIT_DIAGNOSTIC_REPORT, ensure_ascii=False, indent=2))

try:
    out_dir = Path(globals().get("OUTPUT_DIR", "/content"))
    out_dir.mkdir(parents=True, exist_ok=True)
    diag_path = out_dir / "overfit_diagnostic.json"
    diag_path.write_text(json.dumps(OVERFIT_DIAGNOSTIC_REPORT, ensure_ascii=False, indent=2), encoding="utf-8")
    print("Saved:", diag_path)
except Exception as e:
    print("Could not save overfit diagnostic:", repr(e))

# %%
#@title 13C. AF1K integrated overfit handler

# Run AFTER the overfit diagnostic cell.
# It reads OVERFIT_DIAGNOSTIC_REPORT and adjusts runtime settings.
# It does not train or change adapter weights.

from collections import Counter
import json
from pathlib import Path

if "OVERFIT_HANDLER_MODE" not in globals():
    OVERFIT_HANDLER_MODE = "balanced"
if "APPLY_OVERFIT_HANDLER" not in globals():
    APPLY_OVERFIT_HANDLER = True
if "RESET_PREFIX_MEMORY_AFTER_HANDLER" not in globals():
    RESET_PREFIX_MEMORY_AFTER_HANDLER = True
if "TARGET_FALLBACK_RATE_HANDLER" not in globals():
    TARGET_FALLBACK_RATE_HANDLER = 0.35
if "TARGET_MINLEN_RATE_HANDLER" not in globals():
    TARGET_MINLEN_RATE_HANDLER = 0.60
if "TARGET_DUP_PREFIX_RATE_HANDLER" not in globals():
    TARGET_DUP_PREFIX_RATE_HANDLER = 0.12
if "TARGET_NGRAM_OVERLAP_HANDLER" not in globals():
    TARGET_NGRAM_OVERLAP_HANDLER = 0.38

def _af1k_get_diag():
    diag = globals().get("OVERFIT_DIAGNOSTIC_REPORT")
    if isinstance(diag, dict):
        return diag

    candidates = []
    if "OUTPUT_DIR" in globals():
        candidates.append(Path(OUTPUT_DIR) / "overfit_diagnostic.json")
    candidates.extend([
        Path("/content/overfit_diagnostic.json"),
        Path("/content/typewriter_v146br_full_e2e_event_rail_outputs/overfit_diagnostic.json"),
    ])
    for p in candidates:
        try:
            if p.exists():
                return json.loads(p.read_text(encoding="utf-8"))
        except Exception:
            pass
    return None

def _af1k_clamp(v, lo, hi):
    return max(lo, min(hi, v))

def _af1k_issue_codes(diag):
    return sorted([i.get("code") for i in (diag or {}).get("issues", []) if isinstance(i, dict) and i.get("code")])

def recommend_overfit_actions(diag):
    if not isinstance(diag, dict):
        return {
            "status": "NO_DIAGNOSTIC",
            "reason": "OVERFIT_DIAGNOSTIC_REPORT가 없음. 먼저 overfit diagnostic 셀을 실행하세요.",
            "actions": [],
            "notes": ["진단 결과가 없어서 설정을 바꾸지 않았습니다."],
        }

    blind = diag.get("blind") or {}
    mode = globals().get("OVERFIT_HANDLER_MODE", "balanced")

    fallback_rate = blind.get("fallback_rate")
    minlen_rate = blind.get("deterministic_minlen_rate")
    if minlen_rate is None:
        minlen_rate = blind.get("minlen_rate")
    dup_prefix_rate = blind.get("duplicate_prefix_rate")
    overlap = diag.get("calibration_to_blind_ngram_overlap")
    qrepair_rate = blind.get("quality_repair_rate")

    if mode == "conservative":
        attempt_bump, token_bump, det_rounds, model_rounds = 1, 128, 2, 1
        temp, top_p, margin_reduce = 0.78, 0.90, 20
    elif mode == "aggressive":
        attempt_bump, token_bump, det_rounds, model_rounds = 2, 384, 1, 3
        temp, top_p, margin_reduce = 0.86, 0.94, 60
    else:
        attempt_bump, token_bump, det_rounds, model_rounds = 1, 256, 1, 2
        temp, top_p, margin_reduce = 0.82, 0.92, 40

    actions = []
    notes = []

    if fallback_rate is not None and fallback_rate > globals().get("TARGET_FALLBACK_RATE_HANDLER", 0.35):
        actions += [
            ("MAX_ATTEMPTS", _af1k_clamp(int(globals().get("MAX_ATTEMPTS", 2)) + attempt_bump, 3, 5)),
            ("ENABLE_NATURAL_RETRY_BEFORE_FALLBACK", True),
            ("MODEL_CONTINUATION_MAX_ROUNDS", max(int(globals().get("MODEL_CONTINUATION_MAX_ROUNDS", 1)), model_rounds)),
        ]
        notes.append(f"fallback_rate={fallback_rate:.3f}: fallback 전 자연 생성/continuation 기회 강화")

    if minlen_rate is not None and minlen_rate > globals().get("TARGET_MINLEN_RATE_HANDLER", 0.60):
        actions += [
            ("MAX_NEW_TOKENS", _af1k_clamp(int(globals().get("MAX_NEW_TOKENS", 768)) + token_bump, 768, 1400)),
            ("ENABLE_MODEL_CONTINUATION_FOR_MINLEN", True),
            ("MODEL_CONTINUATION_MAX_NEW_TOKENS", _af1k_clamp(int(globals().get("MODEL_CONTINUATION_MAX_NEW_TOKENS", 260)) + 80, 260, 520)),
            ("MODEL_CONTINUATION_TEMPERATURE", temp),
            ("MODEL_CONTINUATION_TOP_P", top_p),
            ("ALLOW_DETERMINISTIC_MINLEN_EXTENSION", True),
            ("MINLEN_EXTENSION_MAX_ROUNDS", det_rounds),
            ("MINLEN_TARGET_MARGIN_CHARS", max(0, int(globals().get("MINLEN_TARGET_MARGIN_CHARS", 60)) - margin_reduce)),
        ]
        notes.append(f"minlen/deterministic_rate={minlen_rate:.3f}: 모델 continuation 우선, deterministic extension 축소")

    if dup_prefix_rate is not None and dup_prefix_rate >= globals().get("TARGET_DUP_PREFIX_RATE_HANDLER", 0.12):
        actions += [
            ("ENABLE_DUPLICATE_PREFIX_GUARD", True),
            ("DUPLICATE_PREFIX_CHARS", max(int(globals().get("DUPLICATE_PREFIX_CHARS", 180)), 220)),
            ("DUPLICATE_PREFIX_MAX_SEEN", 0 if mode == "aggressive" else 1),
            ("DUPLICATE_PREFIX_REPAIR_MAX_ROUNDS", 2 if mode != "conservative" else 1),
        ]
        notes.append(f"duplicate_prefix_rate={dup_prefix_rate:.3f}: prefix guard 강화")

    if overlap is not None and overlap >= globals().get("TARGET_NGRAM_OVERLAP_HANDLER", 0.38):
        actions += [
            ("TEMPERATURE", max(float(globals().get("TEMPERATURE", 0.72)), temp)),
            ("TOP_P", max(float(globals().get("TOP_P", 0.88)), top_p)),
            ("REPETITION_PENALTY", max(float(globals().get("REPETITION_PENALTY", 1.08)), 1.12 if mode != "conservative" else 1.10)),
            ("ENABLE_DUPLICATE_PREFIX_GUARD", True),
        ]
        notes.append(f"calibration/blind_overlap={overlap:.3f}: 다양성/반복 억제 강화")

    if qrepair_rate is not None and qrepair_rate > 0.25:
        actions += [
            ("QUALITY_ONLY_REPAIR_MAX_ROUNDS", 1),
            ("ENABLE_NATURAL_RETRY_BEFORE_FALLBACK", True),
        ]
        notes.append(f"quality_repair_rate={qrepair_rate:.3f}: quality 치환 의존 축소")

    action_map = {}
    for k, v in actions:
        action_map[k] = v

    return {
        "status": "OK",
        "mode": mode,
        "verdict_before": diag.get("verdict"),
        "issue_codes": _af1k_issue_codes(diag),
        "metrics": {
            "blind_fallback_rate": fallback_rate,
            "blind_minlen_or_deterministic_minlen_rate": minlen_rate,
            "blind_duplicate_prefix_rate": dup_prefix_rate,
            "calibration_to_blind_ngram_overlap": overlap,
            "blind_quality_repair_rate": qrepair_rate,
        },
        "actions": list(action_map.items()),
        "notes": notes or ["강한 과적합 처리 액션 없음."],
    }

def apply_overfit_actions(plan):
    applied = []
    if not globals().get("APPLY_OVERFIT_HANDLER", True):
        return applied

    for name, value in plan.get("actions", []):
        old = globals().get(name, None)
        globals()[name] = value
        applied.append({"name": name, "old": old, "new": value})

    if globals().get("RESET_PREFIX_MEMORY_AFTER_HANDLER", True):
        globals()["SEEN_FINAL_PREFIXES"] = Counter()
        applied.append({"name": "SEEN_FINAL_PREFIXES", "old": "preserved/unknown", "new": "Counter() reset"})

    return applied

_diag = _af1k_get_diag()
OVERFIT_HANDLER_PLAN = recommend_overfit_actions(_diag)
OVERFIT_HANDLER_APPLIED = apply_overfit_actions(OVERFIT_HANDLER_PLAN)
OVERFIT_HANDLER_REPORT = {
    "plan": OVERFIT_HANDLER_PLAN,
    "applied": OVERFIT_HANDLER_APPLIED,
    "active_settings_after": {
        "MAX_ATTEMPTS": globals().get("MAX_ATTEMPTS"),
        "MAX_NEW_TOKENS": globals().get("MAX_NEW_TOKENS"),
        "TEMPERATURE": globals().get("TEMPERATURE"),
        "TOP_P": globals().get("TOP_P"),
        "REPETITION_PENALTY": globals().get("REPETITION_PENALTY"),
        "MODEL_CONTINUATION_MAX_ROUNDS": globals().get("MODEL_CONTINUATION_MAX_ROUNDS"),
        "MODEL_CONTINUATION_MAX_NEW_TOKENS": globals().get("MODEL_CONTINUATION_MAX_NEW_TOKENS"),
        "MINLEN_EXTENSION_MAX_ROUNDS": globals().get("MINLEN_EXTENSION_MAX_ROUNDS"),
        "MINLEN_TARGET_MARGIN_CHARS": globals().get("MINLEN_TARGET_MARGIN_CHARS"),
        "DUPLICATE_PREFIX_CHARS": globals().get("DUPLICATE_PREFIX_CHARS"),
        "DUPLICATE_PREFIX_MAX_SEEN": globals().get("DUPLICATE_PREFIX_MAX_SEEN"),
    },
}

print("OVERFIT HANDLER STATUS:", OVERFIT_HANDLER_PLAN.get("status"))
print("MODE:", OVERFIT_HANDLER_PLAN.get("mode"))
print("VERDICT BEFORE:", OVERFIT_HANDLER_PLAN.get("verdict_before"))
print("ISSUES:", OVERFIT_HANDLER_PLAN.get("issue_codes"))
print("\nMETRICS:")
print(json.dumps(OVERFIT_HANDLER_PLAN.get("metrics", {}), ensure_ascii=False, indent=2))
print("\nNOTES:")
for n in OVERFIT_HANDLER_PLAN.get("notes", []):
    print("-", n)
print("\nAPPLIED:")
print(json.dumps(OVERFIT_HANDLER_APPLIED, ensure_ascii=False, indent=2))

try:
    out_dir = Path(globals().get("OUTPUT_DIR", "/content"))
    out_dir.mkdir(parents=True, exist_ok=True)
    handler_path = out_dir / "overfit_handler_report.json"
    handler_path.write_text(json.dumps(OVERFIT_HANDLER_REPORT, ensure_ascii=False, indent=2), encoding="utf-8")
    print("\nSaved:", handler_path)
except Exception as e:
    print("\nCould not save overfit handler report:", repr(e))

# %%
#@title 13D. AF1K post-handler balanced blind rerun

if "r7_reset_runtime_caches" in globals() and globals().get("R7_RESET_CACHE_ON_HANDLER", True):
    r7_reset_runtime_caches(phase="post_handler", clear_result=False, clear_initial=True)

from collections import Counter, defaultdict
import json

AF1K_POST_HANDLER_BLIND_CASES = [
    "초보 공략자가 이미 깬 3층 재입장을 거부당하고, 협회 접수원이 최고층 갱신 공시를 근거로 새 통행증을 발급하는 장면",
    "상층 공략 기록 두 장의 계단 위치가 달라서 파티장이 보상보다 숨은 조건을 먼저 의심하는 장면",
    "길드가 14층 소재 채집을 의뢰했지만 최고 기록 8층인 파티가 수락 여부를 두고 갈라지는 장면",
    "천해 난류 속에서 증기 권양기가 멈추고 선장이 고래보다 찢어진 부력낭을 먼저 살리는 장면",
    "지상에서 온 정찰병이 공어 비를 포격으로 착각하고 항해사가 천해 조류라고 정정하는 장면",
    "소형 부유암괴 옆에서 천해석 파편이 이상하게 떨려 선원이 기존 항로를 포기하는 장면",
    "후견 계약을 앞둔 응접실에서 사라진 장갑 한 짝 때문에 공작가의 증언 순서가 뒤바뀌는 장면",
    "연회장에서 약혼 발표 직전 좌석표가 바뀐 것을 본 영애가 축배 대신 조항의 날짜를 묻는 장면",
    "가문 문장이 찍힌 봉랍이 완전한데도 계약서 가장자리 눌림 때문에 합의가 의심받는 장면",
    "고립된 별장에서 촛불 수가 하나 줄어든 뒤 탐정이 사라진 열쇠보다 식탁 배치를 먼저 보는 장면",
    "모두가 같은 알리바이를 가진 밤에 탐정이 젖은 발자국과 마른 창틀의 모순을 묻는 장면",
    "죽은 남작의 찻잔 손잡이 방향이 평소 습관과 달라 탐정이 차를 따른 순서를 다시 묻는 장면",
    "회귀 첫날 주인공이 예정된 암살자가 나타나지 않자 미래 지식보다 사라진 하인의 이름을 먼저 확인하는 장면",
    "파멸 직전으로 돌아온 주인공이 복수 대상을 만나기 전 날짜가 하루 어긋난 편지를 발견하는 장면",
    "두 번째 삶의 연회에서 원래 있어야 할 모욕이 사라져 주인공이 적이 먼저 움직였음을 깨닫는 장면",
    "닫힌 방에서 주인공이 큰 문이 아니라 아무도 보지 않은 작은 서랍을 열어 선택의 비용을 확인하는 장면",
    "비가 벽을 타고 흐르는 낡은 건물에서 주인공이 단추 하나로 누가 먼저 들어왔는지 추적하는 장면",
    "문밖의 발소리가 멈춘 뒤 주인공이 가장 위험한 물건을 숨기며 방 안의 시선 변화를 읽는 장면",
]

RUN_AF1K_POST_HANDLER_BLIND = False  #@param {type:"boolean"}

af1k_post_handler_blind_results = []
if RUN_AF1K_POST_HANDLER_BLIND:
    SEEN_FINAL_PREFIXES = Counter()
    print("Handler-applied settings:")
    print(json.dumps(globals().get("OVERFIT_HANDLER_REPORT", {}).get("active_settings_after", {}), ensure_ascii=False, indent=2))
    af1k_post_handler_blind_results = r10_run_cases(AF1K_POST_HANDLER_BLIND_CASES, label="af1k_post_handler_blind")
    # R12: keep post-handler pool separate; 13D2 refreshes final diagnostic explicitly.
    POST_HANDLER_BLIND_ACTIVE_RESULTS = af1k_post_handler_blind_results
else:
    print("Skipped AF1K post-handler blind. Set RUN_AF1K_POST_HANDLER_BLIND = False to run.")

# %%
#@title 13D2. AF1K R12 post-handler diagnostic refresh

from collections import Counter, defaultdict
from pathlib import Path
import json, re, hashlib, math

RUN_R12_POST_HANDLER_DIAGNOSTIC = True  #@param {type:"boolean"}

OVERFIT_DIAGNOSTIC_REPORT_POST_HANDLER = None

if RUN_R12_POST_HANDLER_DIAGNOSTIC:
    assert "judge_overfit" in globals(), "Run 13B overfit diagnostic once before 13D2."
    assert "collect_result_pools" in globals(), "Run 13B overfit diagnostic once before 13D2."

    calibration = []
    for _name in [
        "single_result",
        "tower_focused_results",
        "af1e_mixed_results",
        "af1g_minlen_results",
        "af1h_quick_results",
    ]:
        calibration.extend(_rlist(globals().get(_name)))

    # Prefer post-handler pool after handler has been applied.
    post_blind = _rlist(globals().get("af1k_post_handler_blind_results"))
    if not post_blind:
        post_blind = _rlist(globals().get("POST_HANDLER_BLIND_ACTIVE_RESULTS"))
    if not post_blind:
        post_blind = _rlist(globals().get("af1i_blind_results"))
    if not post_blind:
        post_blind = _rlist(globals().get("af1j_balanced_blind_results"))
    if globals().get("R14_ROTATING_BLIND_INCLUDE_IN_ACCEPTANCE", True):
        post_blind = list(post_blind) + _rlist(globals().get("r14_rotating_blind_results"))
        if globals().get("R16_DIVERSITY_INCLUDE_IN_ACCEPTANCE", True):
            post_blind = list(post_blind) + _rlist(globals().get("r16_max_diversity_results"))
        if globals().get("R18_INCLUDE_IN_ACCEPTANCE", True):
            post_blind = list(post_blind) + _rlist(globals().get("r18_genre_knowledge_results"))

    OVERFIT_DIAGNOSTIC_REPORT_POST_HANDLER = judge_overfit(calibration, post_blind, [])

    if globals().get("R12_USE_POST_HANDLER_DIAG_AS_FINAL", True):
        OVERFIT_DIAGNOSTIC_REPORT_PRE_HANDLER = globals().get("OVERFIT_DIAGNOSTIC_REPORT")
        OVERFIT_DIAGNOSTIC_REPORT = OVERFIT_DIAGNOSTIC_REPORT_POST_HANDLER

    print("R12 POST-HANDLER OVERFIT VERDICT:", OVERFIT_DIAGNOSTIC_REPORT_POST_HANDLER.get("verdict"))
    print(json.dumps(OVERFIT_DIAGNOSTIC_REPORT_POST_HANDLER, ensure_ascii=False, indent=2))

    try:
        out_dir = Path(globals().get("OUTPUT_DIR", "/content"))
        out_dir.mkdir(parents=True, exist_ok=True)
        p = out_dir / "overfit_diagnostic_post_handler.json"
        p.write_text(json.dumps(OVERFIT_DIAGNOSTIC_REPORT_POST_HANDLER, ensure_ascii=False, indent=2), encoding="utf-8")
        if globals().get("R12_USE_POST_HANDLER_DIAG_AS_FINAL", True):
            (out_dir / "overfit_diagnostic.json").write_text(json.dumps(OVERFIT_DIAGNOSTIC_REPORT, ensure_ascii=False, indent=2), encoding="utf-8")
        print("Saved:", p)
    except Exception as e:
        print("Could not save R12 post-handler diagnostic:", repr(e))
else:
    print("Skipped R12 post-handler diagnostic refresh.")

# %%
#@title 13E. AF1K R4 quality scanner smoke test

from collections import Counter, defaultdict
import json, re

RUN_AF1K_R4_QUALITY_SMOKE = True  #@param {type:"boolean"}

AF1K_R4_BAD_TOWER_SAMPLE = """공략 기한을 넘긴 초보 파티는 최고층 갱신표의 새 기록 표시을 먼저 확인했다. 하층 마물이 집결한 열쇠구멍 앞에서 기록원은 손을 뻗지 않고 거리를 쟀다. 최고층 갱신표의 새 기록 표시은 누구의 사정도 읽지 않았다. 공략 기한을 넘긴 초보 파티는 그대로 서 있지 못했다. 원래 주인공으로 계산되었던 아이템이 공략 공략 기록표의 칼끝에 걸렸다. 탑 밖의 사람들은 마지막 결정을 늦추었다. 하지만 공략 기한을 넘긴 초보 파티의 문제는 샘이 말보다 느렸다. 안전구역의 재주와 다음 층 문은 같은 쪽을 향했다. 공략 기한을 넘긴 초보 파티가 보상란을 먼저 읽었다."""

AF1K_R4_QUALITY_SMOKE_REPORT = None

if RUN_AF1K_R4_QUALITY_SMOKE:
    test_pack = dict(PACK_REGISTRY["TOWER_SYSTEM_RULE"])
    test_pack["pack_id"] = "TOWER_SYSTEM_RULE"
    test_pack["source_user_input"] = "R4 quality smoke tower sample"
    hits_before = scan_quality_issues(AF1K_R4_BAD_TOWER_SAMPLE, test_pack)
    repaired, changed = repair_quality_issues(AF1K_R4_BAD_TOWER_SAMPLE, test_pack, hits_before)
    hits_after = scan_quality_issues(repaired, test_pack)
    gate_before = final_gate(AF1K_R4_BAD_TOWER_SAMPLE, test_pack)
    gate_after = final_gate(repaired, test_pack)

    AF1K_R4_QUALITY_SMOKE_REPORT = {
        "hits_before": hits_before,
        "changed": changed,
        "hits_after": hits_after,
        "gate_before": gate_before,
        "gate_after": gate_after,
        "repaired_text": repaired,
    }

    print(json.dumps(AF1K_R4_QUALITY_SMOKE_REPORT, ensure_ascii=False, indent=2))

    # Do not hard assert zero after repair because length may still be too short;
    # but the original bad text must be caught by quality scanner.
    assert hits_before, "R4 quality smoke failed: bad sample produced no quality hits."
else:
    print("Skipped AF1K R4 quality scanner smoke test.")

# %%
#@title 13F. AF1K R5 repair/recalibration smoke test

from collections import Counter, defaultdict
import json
import re

# R19_R3: this cell is diagnostic only. It must never block long stress runs.
RUN_AF1K_R5_REPAIR_SMOKE = True  #@param {type:"boolean"}
AF1K_R5_REPAIR_SMOKE_STRICT_ASSERT = False  #@param {type:"boolean"}

AF1K_R5_MIXED_BAD_SAMPLE_BASE = """붉은 잉크로 적힌 공략지에는 이미 같은 문장이 적혀 있었다. 공략 기록은 공략 기록의 위치를 다시 가리켰다. 공략 기록은 공략 기록의 위치를 다시 가리켰다. 표시은 늦었고 계약서 계약서 같은 말이 끼어들었다. 하층 통행증은 \ufffd 표식 옆에서 흔들렸고, 斷絶異常記錄殘像 같은 글자가 문장 사이에 남았다."""

AF1K_R5_SMOKE_SAFE_PAD = """협회 접수원은 보상 내역보다 먼저 다음 층 통행 조건을 확인했다. 이미 클리어한 층으로 돌아가는 길은 닫혀 있었고, 최고층 기록 갱신 때문에 남은 선택지는 위쪽 루트뿐이었다. 주인공은 상태창 차단 설정을 다시 확인했다. 지금 필요한 것은 숫자가 아니라, 서로 다르게 남은 기록 사이의 빈칸이었다.

길드 공시판의 소재 채집 의뢰는 탑이 내린 명령이 아니었다. 바깥 사람들이 보상표를 보고 만든 거래였다. 문제는 그 거래를 감당할 실력이 없는 파티가 접수증을 받아 든 순간부터 시작됐다. 협회 도장은 조용히 말하고 있었다. 같은 길을 반복하는 자가 아니라 다른 조건을 찾는 자에게 다음 층이 열린다고."""

def _r5_smoke_pad_to_min_chars(base_text, pack, margin=80):
    min_chars = MIN_FINAL_CHARS_BY_PACK.get(pack.get("pack_id", "GENERAL_WEBNOVEL"), 500)
    s = str(base_text or "")
    while len(s.strip()) < min_chars + margin:
        s += "\n\n" + AF1K_R5_SMOKE_SAFE_PAD
    return s

def _r19r3_gate_hit_summary(gate):
    gate = gate or {}
    return {
        "verdict": gate.get("verdict"),
        "surface_hits": gate.get("surface_hits") or [],
        "lore_hits": gate.get("lore_hits") or [],
        "quality_hits": gate.get("quality_hits") or [],
        "too_short_final": bool(gate.get("too_short_final")),
        "hard_fail": bool(gate.get("hard_fail")),
        "length_chars": gate.get("length_chars"),
        "min_chars": gate.get("min_chars"),
    }

def _r19r3_smoke_status(g0, g1, changed, error=None):
    if error:
        return "ERROR_DIAGNOSTIC_ONLY"
    g0 = g0 or {}
    g1 = g1 or {}
    before_reject = g0.get("verdict") == "REJECT"
    after_clean_hits = not (g1.get("surface_hits") or g1.get("lore_hits") or g1.get("quality_hits"))
    after_keep = g1.get("verdict") == "KEEP"
    after_improved = (g1.get("verdict") != "REJECT") or after_clean_hits
    if before_reject and (after_keep or after_clean_hits or after_improved):
        return "PASS_OR_IMPROVED"
    if bool(changed):
        return "CHANGED_BUT_STILL_WATCH"
    return "WATCH_DIAGNOSTIC_ONLY"

AF1K_R5_REPAIR_SMOKE_REPORT = None

if RUN_AF1K_R5_REPAIR_SMOKE:
    try:
        test_pack = dict(PACK_REGISTRY["TOWER_SYSTEM_RULE"])
        test_pack["pack_id"] = "TOWER_SYSTEM_RULE"
        test_pack["source_user_input"] = "R5 repair smoke tower sample"

        smoke_text = _r5_smoke_pad_to_min_chars(AF1K_R5_MIXED_BAD_SAMPLE_BASE, test_pack)
        g0 = final_gate(smoke_text, test_pack)
        repaired, g1, changed, events = quality_light_repair_until_keep(smoke_text, test_pack, g0)
        status = _r19r3_smoke_status(g0, g1, changed)

        AF1K_R5_REPAIR_SMOKE_REPORT = {
            "blocking": False,
            "strict_assert": bool(AF1K_R5_REPAIR_SMOKE_STRICT_ASSERT),
            "status": status,
            "changed": bool(changed),
            "changed_requirement": "not_required_nonblocking_diagnostic",
            "smoke_text_length": len(smoke_text),
            "gate_before_summary": _r19r3_gate_hit_summary(g0),
            "gate_after_summary": _r19r3_gate_hit_summary(g1),
            "events": events,
            "remaining_surface_hits": g1.get("surface_hits") or [],
            "remaining_lore_hits": g1.get("lore_hits") or [],
            "remaining_quality_hits": g1.get("quality_hits") or [],
            "recommendation": "Continue stress run. Treat this smoke as a diagnostic report, not a blocker.",
            "gate_before": g0,
            "gate_after": g1,
        }
        print(json.dumps(AF1K_R5_REPAIR_SMOKE_REPORT, ensure_ascii=False, indent=2))

        if AF1K_R5_REPAIR_SMOKE_STRICT_ASSERT:
            assert status in ["PASS_OR_IMPROVED", "CHANGED_BUT_STILL_WATCH"], "R5 strict smoke failed. Disable strict assert for stress runs."
    except Exception as e:
        AF1K_R5_REPAIR_SMOKE_REPORT = {
            "blocking": False,
            "strict_assert": bool(AF1K_R5_REPAIR_SMOKE_STRICT_ASSERT),
            "status": "ERROR_DIAGNOSTIC_ONLY",
            "error": repr(e),
            "recommendation": "Continue stress run; this smoke is diagnostic only.",
        }
        print(json.dumps(AF1K_R5_REPAIR_SMOKE_REPORT, ensure_ascii=False, indent=2))
        if AF1K_R5_REPAIR_SMOKE_STRICT_ASSERT:
            raise
else:
    AF1K_R5_REPAIR_SMOKE_REPORT = {"blocking": False, "status": "SKIPPED"}
    print("Skipped AF1K R5 repair smoke test.")

# %%
#@title 13F2. AF1K R11 finish-mode self-test

from collections import Counter, defaultdict
import json, re, hashlib

RUN_R11_SELF_TEST = True  #@param {type:"boolean"}

R11_SELF_TEST_REPORT = None

if RUN_R11_SELF_TEST:
    # No GPU call. This validates the duplicate-key/clone machinery exists and can preserve row count.
    assert "r10_run_cases" in globals(), "R11 requires r10_run_cases."
    assert "r10_dedup_key_for_case" in globals(), "R11 requires r10_dedup_key_for_case."
    assert "r10_clone_duplicate_result" in globals(), "R11 requires r10_clone_duplicate_result."

    _case = "R11 self-test duplicate case: 탑 공략 뒤 협회 통행증을 다시 확인하는 장면"
    _k1, _front1, _pack1, _prompt1 = r10_dedup_key_for_case(_case)
    _k2, _front2, _pack2, _prompt2 = r10_dedup_key_for_case(_case)
    assert _k1 == _k2, "R11 dedup key must be stable for same input."

    _fake = {
        "input": _case,
        "final_text": "테스트 본문",
        "final_gate": {"verdict": "KEEP", "length_chars": 5},
        "used_cache": False,
        "runtime_seconds": 12.3,
        "front": _front1,
    }
    _clone = r10_clone_duplicate_result(_fake, _case, _k1)
    assert _clone.get("used_cache") is True, "R11 clone must mark used_cache=True."
    assert _clone.get("runtime_seconds") == 0.0, "R11 clone must have zero runtime."

    R11_SELF_TEST_REPORT = {
        "dedup_key_stable": True,
        "clone_marks_cache": True,
        "clone_runtime_zero": True,
        "r11_today_finish_mode": globals().get("R11_TODAY_FINISH_MODE", None),
        "r11_global_dedup_across_cells": globals().get("R11_GLOBAL_DEDUP_ACROSS_CELLS", None),
        "default_run_balanced_blind": globals().get("R11_DEFAULT_RUN_BALANCED_BLIND", None),
        "default_run_post_handler_blind": globals().get("R11_DEFAULT_RUN_POST_HANDLER_BLIND", None),
    }
    print(json.dumps(R11_SELF_TEST_REPORT, ensure_ascii=False, indent=2))
else:
    print("Skipped R11 self-test.")

# %%
#@title 13G. AF1K R7 runtime/cache report

from collections import Counter, defaultdict
import json, statistics, math

def r7_collect_all_result_rows():
    pools = []
    for name in [
        "single_result",
        "tower_focused_results",
        "af1h_quick_results",
        "af1g_minlen_results",
        "af1e_mixed_results",
        "blind_results",
        "af1i_blind_results",
        "af1j_balanced_blind_results",
        "af1k_post_handler_blind_results",
    ]:
        x = globals().get(name)
        if isinstance(x, dict):
            pools.append(x)
        elif isinstance(x, list):
            pools.extend([r for r in x if isinstance(r, dict)])
    return pools

R7_RUNTIME_REPORT = {
    "runtime_stats": dict(globals().get("R7_RUNTIME_STATS", Counter())),
    "result_cache_size": len(globals().get("R7_RESULT_CACHE", {})),
    "initial_raw_cache_remaining": len(globals().get("R7_INITIAL_RAW_CACHE", {})),
    "cache_phase": globals().get("R7_CACHE_PHASE", None),
    "settings": {
        "R7_ENABLE_EXACT_RESULT_CACHE": globals().get("R7_ENABLE_EXACT_RESULT_CACHE", None),
        "R7_ENABLE_BATCH_INITIAL_PREFILL": globals().get("R7_ENABLE_BATCH_INITIAL_PREFILL", None),
        "R7_BATCH_SIZE": globals().get("R7_BATCH_SIZE", None),
        "R7_BATCH_PADDING_SIDE": globals().get("R7_BATCH_PADDING_SIDE", None),
        "R7_STRICT_CACHE_KEY": globals().get("R7_STRICT_CACHE_KEY", None),
        "R7_CACHE_INCLUDE_PROMPT_HASH": globals().get("R7_CACHE_INCLUDE_PROMPT_HASH", None),
        "R7_CACHE_INCLUDE_RUNTIME_FINGERPRINT": globals().get("R7_CACHE_INCLUDE_RUNTIME_FINGERPRINT", None),
        "R8_ENABLE_SHARED_RAW_GENERATION_CACHE": globals().get("R8_ENABLE_SHARED_RAW_GENERATION_CACHE", None),
        "R8_ENABLE_CONTINUATION_CACHE": globals().get("R8_ENABLE_CONTINUATION_CACHE", None),
        "R9_ENABLE_SHARED_FINAL_RESULT_CACHE": globals().get("R9_ENABLE_SHARED_FINAL_RESULT_CACHE", None),
        "R9_FINAL_CACHE_IGNORE_PHASE": globals().get("R9_FINAL_CACHE_IGNORE_PHASE", None),
        "R9_FINAL_CACHE_IGNORE_HANDLER_SETTINGS": globals().get("R9_FINAL_CACHE_IGNORE_HANDLER_SETTINGS", None),
        "R10_GUARANTEED_DEDUP_RUNNER": globals().get("R10_GUARANTEED_DEDUP_RUNNER", None),
        "R10_BALANCED_FAST_MODE": globals().get("R10_BALANCED_FAST_MODE", None),
        "R11_TODAY_FINISH_MODE": globals().get("R11_TODAY_FINISH_MODE", None),
        "R11_GLOBAL_DEDUP_ACROSS_CELLS": globals().get("R11_GLOBAL_DEDUP_ACROSS_CELLS", None),
        "R11_FAIL_SOFT_ROW_ERRORS": globals().get("R11_FAIL_SOFT_ROW_ERRORS", None),
        "R12_USE_POST_HANDLER_DIAG_AS_FINAL": globals().get("R12_USE_POST_HANDLER_DIAG_AS_FINAL", None),
        "MAX_NEW_TOKENS": globals().get("MAX_NEW_TOKENS", None),
        "MODEL_CONTINUATION_MAX_ROUNDS": globals().get("MODEL_CONTINUATION_MAX_ROUNDS", None),
        "MODEL_CONTINUATION_MAX_NEW_TOKENS": globals().get("MODEL_CONTINUATION_MAX_NEW_TOKENS", None),
    },
}

_rows = r7_collect_all_result_rows()
R7_RUNTIME_REPORT["row_count_seen"] = len(_rows)
R7_RUNTIME_REPORT["cache_hit_rows"] = sum(1 for r in _rows if r.get("used_cache"))
R7_RUNTIME_REPORT["batch_prefill_rows"] = sum(1 for r in _rows if r.get("used_batch_initial_prefill"))
_times = [r.get("runtime_seconds") for r in _rows if isinstance(r.get("runtime_seconds"), (int, float)) and not r.get("used_cache")]
R7_RUNTIME_REPORT["non_cache_runtime_seconds_sum"] = round(sum(_times), 3) if _times else 0
R7_RUNTIME_REPORT["non_cache_runtime_seconds_avg"] = round(sum(_times)/len(_times), 3) if _times else None

print(json.dumps(R7_RUNTIME_REPORT, ensure_ascii=False, indent=2))
R7_RUNTIME_REPORT["raw_generation_cache_size"] = len(globals().get("R8_RAW_GENERATION_CACHE", {}))
R7_RUNTIME_REPORT["continuation_cache_size"] = len(globals().get("R8_CONTINUATION_CACHE", {}))
R7_RUNTIME_REPORT["raw_cache_hit_rows"] = sum(1 for r in _rows if r.get("used_r8_raw_generation_cache"))

R7_RUNTIME_REPORT["r9_final_cache_size"] = len(globals().get("R9_FINAL_RESULT_CACHE", {}))
R7_RUNTIME_REPORT["r9_final_cache_hit_rows"] = sum(1 for r in _rows if r.get("used_r9_final_result_cache"))

R7_RUNTIME_REPORT["r10_duplicate_clone_rows"] = sum(1 for r in _rows if r.get("used_r10_duplicate_row_cache"))
R7_RUNTIME_REPORT["r10_duplicate_clone_hit_counter"] = dict(globals().get("R7_RUNTIME_STATS", {})).get("r10_duplicate_clone_hits", 0)

R7_RUNTIME_REPORT["r11_global_dedup_cache_size"] = len(globals().get("R11_GLOBAL_DEDUP_RESULT_CACHE", {}))
R7_RUNTIME_REPORT["r11_global_dedup_hit_rows"] = sum(1 for r in _rows if r.get("used_r11_global_dedup_cache"))
R7_RUNTIME_REPORT["r11_error_rows"] = sum(1 for r in _rows if r.get("used_r11_error_row"))
R7_RUNTIME_REPORT["r11_finish_events"] = globals().get("R11_FINISH_EVENTS", [])

R7_RUNTIME_REPORT["r12_post_handler_diag_verdict"] = (globals().get("OVERFIT_DIAGNOSTIC_REPORT_POST_HANDLER") or {}).get("verdict")

# %%
#@title 13H. AF1K R12 today-finish acceptance gate

from collections import Counter, defaultdict
import json, math

RUN_R12_ACCEPTANCE_GATE = True  #@param {type:"boolean"}

def r12_collect_all_result_rows_for_acceptance():
    rows = []
    for name in [
        "single_result",
        "tower_focused_results",
        "af1e_mixed_results",
        "af1g_minlen_results",
        "af1h_quick_results",
        "blind_results",
        "af1i_blind_results",
        "af1j_balanced_blind_results",
        "af1k_post_handler_blind_results",
        "r14_rotating_blind_results",
        "r16_max_diversity_results",
        "r18_genre_knowledge_results",
    ]:
        x = globals().get(name)
        if isinstance(x, dict):
            rows.append(x)
        elif isinstance(x, list):
            rows.extend([r for r in x if isinstance(r, dict)])
    return rows

def r12_acceptance_judge(rows, diag=None):
    total = len(rows)
    verdicts = Counter((r.get("final_gate", {}) or {}).get("verdict", "UNKNOWN") for r in rows)
    error_rows = sum(1 for r in rows if r.get("used_r11_error_row") or (r.get("final_gate", {}) or {}).get("verdict") == "ERROR")
    reject_rows = verdicts.get("REJECT", 0) + verdicts.get("ERROR", 0)
    route_miss_rows = sum(1 for r in rows if (r.get("final_gate", {}) or {}).get("final_route_miss"))
    dedup_hit_rows = sum(1 for r in rows if r.get("used_r10_duplicate_row_cache") or r.get("used_r11_global_dedup_cache") or r.get("used_r9_final_result_cache"))
    det_rows = sum(1 for r in rows if r.get("used_deterministic_minlen_extension"))
    reject_rate = reject_rows / total if total else 1.0
    route_miss_rate = route_miss_rows / total if total else 1.0
    det_rate = det_rows / total if total else 1.0

    diag_verdict = (diag or {}).get("verdict")
    issues = (diag or {}).get("issues", []) if isinstance(diag, dict) else []
    fail_issues = [i for i in issues if isinstance(i, dict) and i.get("level") == "FAIL"]

    blockers = []
    warnings = []

    if error_rows > globals().get("R12_ACCEPT_MAX_ERROR_ROWS", 0):
        blockers.append(f"ERROR_ROWS:{error_rows}")
    if reject_rate > globals().get("R12_ACCEPT_MAX_REJECT_RATE", 0.06):
        blockers.append(f"REJECT_RATE:{reject_rate:.3f}")
    if route_miss_rate > globals().get("R12_ACCEPT_MAX_ROUTE_MISS_RATE", 0.08):
        blockers.append(f"ROUTE_MISS_RATE:{route_miss_rate:.3f}")
    if det_rate > globals().get("R12_ACCEPT_MAX_DETERMINISTIC_MINLEN_RATE", 0.55):
        if det_rate <= globals().get("R12_WATCH_MAX_DETERMINISTIC_MINLEN_RATE", 0.75):
            warnings.append(f"DET_MINLEN_RATE:{det_rate:.3f}")
        else:
            blockers.append(f"DET_MINLEN_RATE:{det_rate:.3f}")
    if globals().get("R12_ACCEPT_REQUIRE_DEDUP_HITS", True) and total > 20 and dedup_hit_rows == 0:
        blockers.append("NO_DEDUP_HITS")
    if diag_verdict == "FAIL" and fail_issues:
        # R12 allows a WATCH-level deterministic dependency, but FAIL remains blocker.
        blockers.append("OVERFIT_DIAGNOSTIC_FAIL")

    if blockers:
        decision = "REJECT_NEXT_PATCH"
    elif warnings or diag_verdict == "WATCH":
        decision = "WATCH_ADOPTABLE"
    else:
        decision = "ADOPT"

    return {
        "decision": decision,
        "total_rows": total,
        "verdict_counts": dict(verdicts),
        "error_rows": error_rows,
        "reject_rows": reject_rows,
        "reject_rate": reject_rate,
        "route_miss_rows": route_miss_rows,
        "route_miss_rate": route_miss_rate,
        "deterministic_minlen_rows": det_rows,
        "deterministic_minlen_rate": det_rate,
        "dedup_hit_rows": dedup_hit_rows,
        "diagnostic_verdict": diag_verdict,
        "diagnostic_fail_issues": fail_issues,
        "blockers": blockers,
        "warnings": warnings,
    }

R12_ACCEPTANCE_REPORT = None
if RUN_R12_ACCEPTANCE_GATE:
    _rows = r12_collect_all_result_rows_for_acceptance()
    _diag = globals().get("OVERFIT_DIAGNOSTIC_REPORT_POST_HANDLER") or globals().get("OVERFIT_DIAGNOSTIC_REPORT")
    R12_ACCEPTANCE_REPORT = r12_acceptance_judge(_rows, _diag)
    print("R12 TODAY-FINISH DECISION:", R12_ACCEPTANCE_REPORT["decision"])
    print(json.dumps(R12_ACCEPTANCE_REPORT, ensure_ascii=False, indent=2))
else:
    print("Skipped R12 acceptance gate.")

# %%
#@title 14. Save artifacts and package result ZIP
import json

# AF1D-hardened: does not assume single/stress cells were all run.
from pathlib import Path
import datetime
import json
import zipfile
import shutil
from collections import Counter

if "KST_NOW" not in globals():
    KST_NOW = datetime.datetime.utcnow() + datetime.timedelta(hours=9)
if "VERSION" not in globals():
    VERSION = "TYPEWRITER_GITHUB_SPLIT_ADAPTER_UI_COLAB_R1_R3_NONBLOCKING_SMOKE_R4_STRICT_CACHE_WARNFIX_R3_STRICT_CACHE_KEY_R3_CELL_ORDER_FIX"
if "LOCAL_RESULTS_ROOT" not in globals():
    LOCAL_RESULTS_ROOT = Path("/content/typewriter_v146br_full_e2e_event_rail_outputs")
LOCAL_RESULTS_ROOT.mkdir(parents=True, exist_ok=True)
if "RESULTS_ROOT" not in globals():
    RESULTS_ROOT = Path("/content/drive/MyDrive/TypeWriter/results_v146br_full_e2e_event_rail")
if "ADAPTER_AUDIT" not in globals():
    ADAPTER_AUDIT = {}
if "BASE_MODEL_ID" not in globals():
    BASE_MODEL_ID = "Qwen/Qwen2.5-7B-Instruct"
if "PACK_SCHEMA_VERSION" not in globals():
    PACK_SCHEMA_VERSION = "v146br_event_rail_pack_schema_af1"
if "DRY_RUN_WITH_DETERMINISTIC_TEXT" not in globals():
    DRY_RUN_WITH_DETERMINISTIC_TEXT = False
if "blind_results" not in globals():
    blind_results = []
if "tower_focused_results" not in globals():
    tower_focused_results = []
if "af1h_quick_results" not in globals():
    af1h_quick_results = []
if "af1g_minlen_results" not in globals():
    af1g_minlen_results = []
if "af1e_mixed_results" not in globals():
    af1e_mixed_results = []
if "r14_rotating_blind_results" not in globals():
    r14_rotating_blind_results = []
if "r16_max_diversity_results" not in globals():
    r16_max_diversity_results = []
if "r18_genre_knowledge_results" not in globals():
    r18_genre_knowledge_results = []

def summarize_results(results):
    verdicts = Counter()
    packs = Counter()
    surface_hits = Counter()
    lore_hits = Counter()
    quality_hits = Counter()
    safe_fallback_count = 0
    salvage_count = 0
    minlen_extension_count = 0
    model_continuation_count = 0
    deterministic_minlen_extension_count = 0
    duplicate_prefix_repair_count = 0
    quality_light_repair_count = 0
    r13_return_focus_repair_count = 0
    hard_fail_count = 0
    empty_final_count = 0
    too_short_final_count = 0
    final_route_miss_count = 0

    for r in results:
        if not isinstance(r, dict):
            continue
        gate = r.get("final_gate", {})
        verdicts[gate.get("verdict", "UNKNOWN")] += 1
        if "front" in r:
            packs[r["front"]["pack"]["pack_id"]] += 1
        if r.get("used_fallback"):
            safe_fallback_count += 1
        if r.get("used_salvage"):
            salvage_count += 1
        if r.get("used_minlen_extension"):
            minlen_extension_count += 1
        if r.get("used_model_continuation"):
            model_continuation_count += 1
        if r.get("used_deterministic_minlen_extension"):
            deterministic_minlen_extension_count += 1
        if r.get("used_duplicate_prefix_repair"):
            duplicate_prefix_repair_count += 1
        if r.get("used_quality_light_repair"):
            quality_light_repair_count += 1
        if r.get("used_r13_return_focus_repair"):
            r13_return_focus_repair_count += 1
        if gate.get("hard_fail"):
            hard_fail_count += 1
        if gate.get("empty_final"):
            empty_final_count += 1
        if gate.get("too_short_final"):
            too_short_final_count += 1
        if gate.get("final_route_miss"):
            final_route_miss_count += 1
        for h in gate.get("surface_hits", []):
            surface_hits[h] += 1
        for h in gate.get("lore_hits", []):
            lore_hits[h] += 1
        for h in gate.get("quality_hits", []):
            quality_hits[h] += 1

    return {
        "total": len(results),
        "verdict_counts": dict(verdicts),
        "pack_counts": dict(packs),
        "surface_hit_counts": dict(surface_hits),
        "lore_hit_counts": dict(lore_hits),
        "quality_hit_counts": dict(quality_hits),
        "safe_fallback_count": safe_fallback_count,
        "salvage_repair_count": salvage_count,
        "minlen_extension_count": minlen_extension_count,
        "model_continuation_count": model_continuation_count,
        "deterministic_minlen_extension_count": deterministic_minlen_extension_count,
        "duplicate_prefix_repair_count": duplicate_prefix_repair_count,
        "quality_light_repair_count": quality_light_repair_count,
        "r13_return_focus_repair_count": r13_return_focus_repair_count,
        "hard_fail_count": hard_fail_count,
        "empty_final_count": empty_final_count,
        "too_short_final_count": too_short_final_count,
        "final_route_miss_count": final_route_miss_count,
    }

def compact_result(r):
    if not isinstance(r, dict):
        return {"error": "non_dict_result", "repr": repr(r)}
    out = {
        "input": r.get("input"),
        "final_text": r.get("final_text"),
        "final_gate": r.get("final_gate"),
        "used_salvage": r.get("used_salvage"),
        "used_fallback": r.get("used_fallback"),
        "used_minlen_extension": r.get("used_minlen_extension"),
        "used_model_continuation": r.get("used_model_continuation"),
        "used_deterministic_minlen_extension": r.get("used_deterministic_minlen_extension"),
        "used_duplicate_prefix_repair": r.get("used_duplicate_prefix_repair"),
        "minlen_extension_events": r.get("minlen_extension_events"),
        "used_quality_light_repair": r.get("used_quality_light_repair"),
        "quality_repair_events": r.get("quality_repair_events"),
        "duplicate_prefix_events": r.get("duplicate_prefix_events"),
        "used_cache": r.get("used_cache"),
        "used_batch_initial_prefill": r.get("used_batch_initial_prefill"),
        "used_r8_raw_generation_cache": r.get("used_r8_raw_generation_cache"),
        "r8_raw_cache_key": r.get("r8_raw_cache_key"),
        "used_r9_final_result_cache": r.get("used_r9_final_result_cache"),
        "used_r10_duplicate_row_cache": r.get("used_r10_duplicate_row_cache"),
        "r10_dedup_key": r.get("r10_dedup_key"),
        "r10_dedup_key_reused": r.get("r10_dedup_key_reused"),
        "used_r11_global_dedup_cache": r.get("used_r11_global_dedup_cache"),
        "used_r11_error_row": r.get("used_r11_error_row"),
        "used_r13_return_focus_repair": r.get("used_r13_return_focus_repair"),
        "r13_return_focus_events": r.get("r13_return_focus_events"),
        "r9_final_cache_key": r.get("r9_final_cache_key"),
        "r9_final_cache_key_reused": r.get("r9_final_cache_key_reused"),
        "r9_final_cache_fingerprint": r.get("r9_final_cache_fingerprint"),
        "r7_cache_phase": r.get("r7_cache_phase"),
        "runtime_seconds": r.get("runtime_seconds"),
        "r7_cache_note": r.get("r7_cache_note"),
        "r7_cache_key": r.get("r7_cache_key"),
        "r7_cache_key_reused": r.get("r7_cache_key_reused"),
        "r7_cache_fingerprint": r.get("r7_cache_fingerprint"),
    }
    if "front" in r:
        out["selection"] = r["front"]["selection"]
        out["pack"] = r["front"]["pack"]
        out["prompt"] = r.get("prompt")
    if "error" in r:
        out["error"] = r["error"]
    return out

all_results = []
if isinstance(globals().get("single_result"), dict):
    all_results.append(globals()["single_result"])
all_results.extend([r for r in globals().get("tower_focused_results", []) if isinstance(r, dict)])
all_results.extend([r for r in globals().get("af1h_quick_results", []) if isinstance(r, dict)])
all_results.extend([r for r in globals().get("af1g_minlen_results", []) if isinstance(r, dict)])
all_results.extend([r for r in globals().get("af1e_mixed_results", []) if isinstance(r, dict)])
all_results.extend([r for r in globals().get("blind_results", []) if isinstance(r, dict)])
all_results.extend([r for r in globals().get("af1i_blind_results", []) if isinstance(r, dict)])
all_results.extend([r for r in globals().get("af1j_balanced_blind_results", []) if isinstance(r, dict)])
all_results.extend([r for r in globals().get("af1k_post_handler_blind_results", []) if isinstance(r, dict)])

if not all_results:
    raise RuntimeError(
        "No results to package. Run cell 11 Single full E2E test, "
        "or run Tower-focused/blind stress first."
    )

primary_result = all_results[0]
summary = summarize_results(all_results)

RUN_ID = KST_NOW.strftime("%Y%m%d_%H%M%S_KST")
RUN_DIR = LOCAL_RESULTS_ROOT / f"{VERSION}_RESULT_{RUN_ID}"
RUN_DIR.mkdir(parents=True, exist_ok=True)

summary_payload = {
    "version": VERSION,
    "created_kst": KST_NOW.isoformat(timespec="seconds"),
    "adapter_audit": ADAPTER_AUDIT,
    "base_model_id": BASE_MODEL_ID,
    "resolved_base_model_source": globals().get("RESOLVED_BASE_MODEL_SOURCE", BASE_MODEL_ID),
    "drive_base_model_dir": str(globals().get("DRIVE_BASE_MODEL_DIR", "")),
    "drive_hf_home": str(globals().get("DRIVE_HF_HOME", "")),
    "runner_gate": "V146BQ_AF1K_R5_REPAIR_RECALIBRATE",
    "pack_schema_version": PACK_SCHEMA_VERSION,
    "summary": summary,
    "dry_run": DRY_RUN_WITH_DETERMINISTIC_TEXT,
    "max_new_tokens": globals().get("MAX_NEW_TOKENS", None),
    "enable_minlen_enforcer": globals().get("ENABLE_MINLEN_ENFORCER", None),
    "minlen_extension_max_rounds": globals().get("MINLEN_EXTENSION_MAX_ROUNDS", None),
    "output_length_preset": globals().get("OUTPUT_LENGTH_PRESET", None),
    "min_final_chars_by_pack": globals().get("MIN_FINAL_CHARS_BY_PACK", {}),
    "enable_quality_light_repair": globals().get("ENABLE_QUALITY_LIGHT_REPAIR", None),
    "quality_scanner_version": globals().get("QUALITY_SCANNER_VERSION", None),
    "af1k_r4_quality_smoke_report": globals().get("AF1K_R4_QUALITY_SMOKE_REPORT", None),
    "af1k_r5_repair_smoke_report": globals().get("AF1K_R5_REPAIR_SMOKE_REPORT", None),
    "overfit_diagnostic": globals().get("OVERFIT_DIAGNOSTIC_REPORT", None),
    "overfit_handler_report": globals().get("OVERFIT_HANDLER_REPORT", None),
    "r5_r2_smoke_fix": {
        "smoke_sample_padded_above_min_chars": True,
        "too_short_precondition_assert": True
    },
    "r7_runtime_report": globals().get("R7_RUNTIME_REPORT", None),
    "r20_source_preflight_report": globals().get("R20_SOURCE_PREFLIGHT_REPORT", None),
    "r18_genre_knowledge_report": globals().get("R18_GENRE_KNOWLEDGE_REPORT", None),
    "r17_tower_no_reentry_smoke_report": globals().get("R17_TOWER_NO_REENTRY_SMOKE_REPORT", None),
    "r16_max_diversity_report": globals().get("R16_MAX_DIVERSITY_REPORT", None),
    "r15_pack_regen_smoke_report": globals().get("R15_PACK_REGEN_SMOKE_REPORT", None),
    "r15_pack_generation_report": {
        "enabled": globals().get("R15_ENABLE_DYNAMIC_PACK_REGEN", None),
        "mode": globals().get("R15_PACK_REGEN_MODE", None),
        "pack_instance_count": len(set([(_r.get("front", {}).get("pack", {}).get("generated_pack_overlay", {}) or {}).get("pack_instance_id") for _r in all_results if isinstance(_r, dict)])) if "all_results" in locals() else None,
        "pack_qa_counts": dict(Counter([((_r.get("front", {}).get("pack", {}).get("pack_qa_report", {}) or {}).get("verdict", "UNKNOWN")) for _r in all_results if isinstance(_r, dict)])) if "all_results" in locals() else None,
    },
    "r14_rotating_blind_report": globals().get("R14_ROTATING_BLIND_REPORT", None),
    "r13_router_smoke_report": globals().get("R13_ROUTER_SMOKE_REPORT", None),
    "r13_return_focus_report": {
        "enabled": globals().get("R13_ENABLE_RETURN_FOCUS_REPAIR", None),
        "repair_rows": sum(1 for _r in all_results if isinstance(_r, dict) and _r.get("used_r13_return_focus_repair")) if "all_results" in locals() else None,
        "strict_regression_router": globals().get("R13_STRICT_REGRESSION_ROUTER", None)
    },
    "r12_acceptance_report": globals().get("R12_ACCEPTANCE_REPORT", None),
    "r12_post_handler_diagnostic": globals().get("OVERFIT_DIAGNOSTIC_REPORT_POST_HANDLER", None),
    "r11_finish_report": {
        "today_finish_mode": globals().get("R11_TODAY_FINISH_MODE", None),
        "target_profile": globals().get("R11_TARGET_PROFILE", None),
        "global_dedup_cache_size": len(globals().get("R11_GLOBAL_DEDUP_RESULT_CACHE", {})),
        "global_dedup_hits": dict(globals().get("R7_RUNTIME_STATS", {})).get("r11_global_dedup_hits", 0),
        "error_rows": sum(1 for _r in all_results if isinstance(_r, dict) and _r.get("used_r11_error_row")) if "all_results" in locals() else None,
        "finish_events": globals().get("R11_FINISH_EVENTS", []),
        "self_test": globals().get("R11_SELF_TEST_REPORT", None)
    },
    "r10_dedup_report": {
        "guaranteed_dedup_runner": globals().get("R10_GUARANTEED_DEDUP_RUNNER", None),
        "balanced_fast_mode": globals().get("R10_BALANCED_FAST_MODE", None),
        "duplicate_clone_hits": dict(globals().get("R7_RUNTIME_STATS", {})).get("r10_duplicate_clone_hits", 0),
        "duplicate_rows": dict(globals().get("R7_RUNTIME_STATS", {})).get("r10_duplicate_rows", 0),
        "unique_cases": dict(globals().get("R7_RUNTIME_STATS", {})).get("r10_unique_cases", 0)
    },
    "r9_ultrafast_report": {
        "final_result_cache_size": len(globals().get("R9_FINAL_RESULT_CACHE", {})),
        "enable_shared_final_result_cache": globals().get("R9_ENABLE_SHARED_FINAL_RESULT_CACHE", None),
        "ignore_phase": globals().get("R9_FINAL_CACHE_IGNORE_PHASE", None),
        "ignore_handler_settings": globals().get("R9_FINAL_CACHE_IGNORE_HANDLER_SETTINGS", None),
        "ultrafast_mode": globals().get("R9_ULTRAFAST_MODE", None)
    },
    "r8_cache_report": {
        "raw_generation_cache_size": len(globals().get("R8_RAW_GENERATION_CACHE", {})),
        "continuation_cache_size": len(globals().get("R8_CONTINUATION_CACHE", {})),
        "enable_shared_raw_generation_cache": globals().get("R8_ENABLE_SHARED_RAW_GENERATION_CACHE", None),
        "enable_continuation_cache": globals().get("R8_ENABLE_CONTINUATION_CACHE", None)
    },
    "r7_runtime_settings": {
        "enable_exact_result_cache": globals().get("R7_ENABLE_EXACT_RESULT_CACHE", None),
        "r7_strict_cache_key": globals().get("R7_STRICT_CACHE_KEY", None),
        "include_prompt_hash": globals().get("R7_CACHE_INCLUDE_PROMPT_HASH", None),
        "include_runtime_fingerprint": globals().get("R7_CACHE_INCLUDE_RUNTIME_FINGERPRINT", None),
        "enable_batch_initial_prefill": globals().get("R7_ENABLE_BATCH_INITIAL_PREFILL", None),
        "batch_size": globals().get("R7_BATCH_SIZE", None),
        "cache_phase": globals().get("R7_CACHE_PHASE", None)
    },
    "r5_repair_recalibration": {
        "enable_r5_mixed_hit_repair": globals().get("ENABLE_R5_MIXED_HIT_REPAIR", None),
        "r5_total_repair_max_rounds": globals().get("R5_TOTAL_REPAIR_MAX_ROUNDS", None),
        "r5_total_minlen_rate_watch_only": globals().get("R5_TOTAL_MINLEN_RATE_WATCH_ONLY", None)
    },
    "model_continuation_max_rounds": globals().get("MODEL_CONTINUATION_MAX_ROUNDS", None),
    "allow_deterministic_minlen_extension": globals().get("ALLOW_DETERMINISTIC_MINLEN_EXTENSION", None),
    "enable_duplicate_prefix_guard": globals().get("ENABLE_DUPLICATE_PREFIX_GUARD", None),
}

(RUN_DIR / "summary.json").write_text(json.dumps(summary_payload, ensure_ascii=False, indent=2), encoding="utf-8")
if globals().get("OVERFIT_HANDLER_REPORT", None) is not None:
    (RUN_DIR / "overfit_handler_report.json").write_text(
        json.dumps(OVERFIT_HANDLER_REPORT, ensure_ascii=False, indent=2),
        encoding="utf-8"
    )
if globals().get("OVERFIT_DIAGNOSTIC_REPORT", None) is not None:
    (RUN_DIR / "overfit_diagnostic.json").write_text(
        json.dumps(OVERFIT_DIAGNOSTIC_REPORT, ensure_ascii=False, indent=2),
        encoding="utf-8"
    )
(RUN_DIR / "results.jsonl").write_text(
    "\n".join(json.dumps(compact_result(r), ensure_ascii=False) for r in all_results) + "\n",
    encoding="utf-8"
)

if primary_result.get("final_text"):
    (RUN_DIR / "primary_final_text.txt").write_text(primary_result["final_text"], encoding="utf-8")
if "front" in primary_result:
    (RUN_DIR / "primary_pack.json").write_text(json.dumps(primary_result["front"]["pack"], ensure_ascii=False, indent=2), encoding="utf-8")
if primary_result.get("prompt"):
    (RUN_DIR / "primary_prompt.txt").write_text(primary_result["prompt"], encoding="utf-8")

report = f"""# {VERSION} result

## Summary

```json
{json.dumps(summary_payload, ensure_ascii=False, indent=2)}
```

## Primary input

```text
{primary_result.get("input", "")}
```

## Selected pack

```text
{primary_result.get("front", {}).get("pack", {}).get("pack_id", "unknown")}
```

## Final text

{primary_result.get("final_text", "")}
"""
(RUN_DIR / "report.md").write_text(report, encoding="utf-8")

zip_path = LOCAL_RESULTS_ROOT / f"{VERSION}_RESULT_{RUN_ID}.zip"
with zipfile.ZipFile(zip_path, "w", zipfile.ZIP_DEFLATED) as z:
    for p in RUN_DIR.rglob("*"):
        z.write(p, p.relative_to(RUN_DIR.parent))

print("RUN_DIR =", RUN_DIR)
print("RESULT_ZIP =", zip_path)
print("summary =", json.dumps(summary, ensure_ascii=False, indent=2))

try:
    RESULTS_ROOT.mkdir(parents=True, exist_ok=True)
    drive_zip = RESULTS_ROOT / zip_path.name
    shutil.copy2(zip_path, drive_zip)
    print("DRIVE_RESULT_ZIP =", drive_zip)
except Exception as e:
    print("Drive copy skipped:", repr(e))

# %%
#@title TypeWriter Minimal UI: input → output only

# Run this cell after the model/adapter is loaded and e2e_generate_one() is defined.

try:
    import gradio as gr
except Exception:
    # !pip -q install gradio
    import gradio as gr

def typewriter_generate(user_input):
    user_input = (user_input or "").strip()

    if not user_input:
        return "입력을 넣어줘."

    try:
        result = e2e_generate_one(user_input)
        return result.get("final_text", "").strip() or "[EMPTY OUTPUT]"
    except Exception as e:
        return f"[ERROR]\n{repr(e)}"

with gr.Blocks(title="TypeWriter") as demo:
    gr.Markdown("## TypeWriter")

    user_input = gr.Textbox(
        label="입력",
        placeholder="예: 탑 17층 공략 뒤 협회 공시의 최고층 갱신 기한을 보고 루트를 바꾸는 장면",
        lines=4,
    )

    run_btn = gr.Button("생성")

    output = gr.Textbox(
        label="출력",
        lines=22,
    )

    run_btn.click(
        fn=typewriter_generate,
        inputs=user_input,
        outputs=output,
    )

demo.queue()
demo.launch(share=True, debug=False)
